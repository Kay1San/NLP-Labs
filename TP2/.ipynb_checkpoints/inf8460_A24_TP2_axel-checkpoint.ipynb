# %% [markdown]
# ##### INF8460 – Traitement automatique de la langue naturelle - Automne 2024
#
# ## TP2: Plongements de mots

# %% [markdown]
# ## Identification de l'équipe:
#
# ### Groupe de laboratoire:
#
# ### Equipe numéro :
#
# ### Membres:
#
# - membre 1 (% de contribution, nature de la contribution)
# - membre 2 (% de contribution, nature de la contribution)
# - membre 3 (% de contribution, nature de la contribution)
#
# * nature de la contribution: Décrivez brièvement ce qui a été fait par chaque membre de l’équipe. Tous les membres sont censés contribuer au développement. Bien que chaque membre puisse effectuer différentes tâches, vous devez vous efforcer d’obtenir une répartition égale du travail. Soyez précis ! N'indiquez pas seulement : travail réparti équitablement

# %% [markdown]
# ### Objectif du TP
#
# L'objectif de ce TP est d'entraîner un modèle de plongements lexicaux qui intègre des notions de synonymie et d'antonymie en utilisant des réseaux de neurones.
#
# Contrairement aux plongements vus en cours comme GloVe ou Word2Vec, qui positionnent souvent les mots à proximité équivalente de leurs synonymes et antonymes, nous chercherons à faire distinguer à nos modèles les synonymes et antonymes, en rapprochant les mots de leurs synonymes et en les éloignant de leurs antonymes.
#
# ### Jeux de données
#
# **Paires de synonymes et antonymes** (entraînement) : Les fichiers `train_synonyms.txt` et `train_antonymms.txt` contiennent les paires de synonymes et d'antonymes qui serviront à l'entraînement de nos modèles.
# - train_synonyms: ~640k paires de synonymes
# - train_antonyms: ~12k paires d'antonymes
#
# **SimLex-999** (test) : Le fichier `simlex_english.txt` contient 1000 paires de mots et leur similarité entre 0 et 10. Des antonymes auront une similarité de 0 et des mots proches auront une similarité plus élevée. Par exemples :
#
# - *nice* & *cruel* -> 0
# - *violent* & *angry* -> 5.9
# - *essential* & *necessary* -> 9.8
#
# ### Développement du TP
#
# Le TP suivra les étapes suivantes:
#
# - Partie 1 : Familiarisation avec GloVe, modèle de plongements de mots pré-entraîné
# - Partie 2 : Évaluation de GloVe sur SimLex-999
# - Partie 3 : Mise en place de la méthode d'entraînement
# - Partie 4 : Entraînement de zéro (baseline)
# - Partie 5 : Entraînement utilisant GloVe pré-entraîné et conclusion
#
# Le TP est noté sur 89 points.

# %% [markdown]
# ### Librairies autorisées
#
# + numpy
# + pandas
# + torch
# + matplotlib
#
# Si vous voulez utiliser une autre librairie, veuillez demander à votre chargé de lab.
#
# ### Imports
#
# Les imports effectués dans la cellule suivante devraient être suffisants pour faire tout ce TP.

# %%
from tqdm import tqdm
import gc

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

# %% [markdown]
# ### 1. GloVe (10 Points)

# %% [markdown]
# Dans ce TP, nous allons utiliser le modèle pré-entraîné GloVe qui crée des plongements lexicaux de mots.

# %% [markdown]
# #### 1.1 Chargement du modèle
#
# La cellule suivante permet charger le modèle GloVe pré-entraîné. Le chargement du modèle peut prendre quelques minutes.

# %%
# # Décommenter pour télécharger les GloVe embeddings à partir de https://nlp.stanford.edu/projects/glove/
# !wget http://nlp.stanford.edu/data/glove.42B.300d.zip -P /content
# !unzip /content/glove.42B.300d.zip -d /content

# %%
pretrained_model_path = 'glove.42B.300d.txt'

data_root = 'data'

train_synonyms_path = f"{data_root}/train_synonyms.txt"
train_antonyms_path = f"{data_root}/train_antonyms.txt"

eval_simlex = f'{data_root}/simlex_english.txt'

# %%
def load_word_vectors(filepath, vocab=None):
    """
    Télécharge le modèle pré-entraîné de plongements de mots en pytorch
    """
    word_to_index = {}
    embeddings = []
    index = 0

    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            split_line = line.split()
            word = split_line[0]
            if vocab is None or word in vocab:
                embedding = np.array(split_line[1:], dtype=np.float32)
                word_to_index[word] = index
                embeddings.append(embedding)
                index += 1
    
    embeddings = np.stack(embeddings)
    embeddings = torch.from_numpy(embeddings)
    return word_to_index, embeddings

# %%
word_to_index, embeddings = load_word_vectors(pretrained_model_path)

# %% [markdown]
# #### 1.2 Implémentez la fonction `cosine_similarity` avec pytorch et sans utiliser `torch.nn.CosineSimilarity` (2 points)

# %%
def cosine_similarity(a, b):
    """
    Calcule la matrice de similarité cosinus entre deux matrices

    Args :
        a   : torch.Tensor, shape=(n, d)
        b   : torch.Tensor, shape=(m, d)

    Returns:
    torch.Tensor, shape=(n, m)
    """

    num = torch.mm(a, b.t())

    a_norm = torch.linalg.norm(a, dim=1, keepdim=True)
    b_norm = torch.linalg.norm(b, dim=1, keepdim=True)

    denom = a_norm*b_norm.t()


    return num / denom


    # TODO
    # END TODO

# %%
#A = torch.Tensor([[0,1,0,5],
#                  [1,2,5,6]])
#B = torch.Tensor([[-1,0,-5,0],
#                  [9,7,2,5],
#                  [4,7,0,9]])
#cosine_similarity(A,B)
#tensor([[ 0.0000,  0.4977,  0.8440],
#        [-0.6276,  0.6150,  0.7335]])

# %% [markdown]
# #### 1.3 Complétez la fonction `n_closest_vect` qui retourne les n mots les plus proches d'un mot donné. (5 points)
#
# `n_closest_vect` prendra en entrée la matrice des plongements `embeddings`, le dictionnaire de correspondance entre les mots et les indices `word_to_index`, le plongement d'un mot `word` et le nombre `n` de mots attendus. La fonction devra retourner la liste des mots dont les plongements sont les plus proches du vecteur de référence et leur similarité cosinus.
#
# C'est-à-dire les n mots avec lesquels le mot a la plus grande similarité cosinus. Utilisez la fonction `cosine_similarity` que vous venez d'implémenter.

# %%
def n_closest_vect(embeddings, word_to_index, wordEmbedding, n=5):
    """
    Trouve les n mots les plus proches du vecteur donné et leur similarité

    Args : 
        embeddings      : torch.Tensor, shape=(vocab_size, embedding_dim)
        Matrice de plongement de tous les mots

        word_to_index   : dict
        Dictionnaire qui relie un mot à son index dans le vocabulaire

        wordEmbedding   : torch.Tensor, shape=(embedding_dim,)
        Plongement du mot dont on cherche les n mots les plus proches

        n               : int, number of closest words to return
        Nombre de mots à retourner

    Returns:
    Liste de tuple contenant les n mots les plus similaires avec leur coefficient
    de similarité
    """ 

    cosine_matrix = cosine_similarity(embeddings, wordEmbedding.unsqueeze(0))
    cosine_matrix.squeeze_()

    top_n_values = torch.topk(cosine_matrix, 5)

    top_n_words = {}

    i = 0
    word_keys = list(word_to_index.keys())
    for indice in top_n_values.indices:
      word_value = word_keys[indice]
      top_n_words[word_value] = top_n_values.values[i].item()
      i += 1
    
    return top_n_words

# %%
"""     wordEmbedding = torch.reshape(wordEmbedding, (1,-1))
    # Evaluate the matrix 
    similarityVector = cosine_similarity(wordEmbedding,embeddings) # (1,len(word_to_index))
    similarityVector = torch.reshape(similarityVector,(len(word_to_index),))
 
    idxSorted = np.argsort(similarityVector)
    
    
    # Only keep the first N
    outWords = []
    for i in range(n):
        outWords += [(list(word_to_index.keys())[idxSorted[-1-i]],
                      float(similarityVector[idxSorted[-1-i]]))]
    return outWords """
# Out:
# '     wordEmbedding = torch.reshape(wordEmbedding, (1,-1))\n    # Evaluate the matrix \n    similarityVector = cosine_similarity(wordEmbedding,embeddings) # (1,len(word_to_index))\n    similarityVector = torch.reshape(similarityVector,(len(word_to_index),))\n \n    idxSorted = np.argsort(similarityVector)\n    \n    \n    # Only keep the first N\n    outWords = []\n    for i in range(n):\n        outWords += [(list(word_to_index.keys())[idxSorted[-1-i]],\n                      float(similarityVector[idxSorted[-1-i]]))]\n    return outWords '

# %%
# Exemple

print(n_closest_vect(embeddings, word_to_index, embeddings[word_to_index['morning']]))
# Out:
# {'morning': 0.9999999403953552, 'afternoon': 0.8665473461151123, 'evening': 0.7880070805549622, 'yesterday': 0.7614548206329346, 'sunday': 0.7548925876617432}

# %% [markdown]
# Sortie attendue :
# ```
# [('morning', 1.0), ('afternoon', 0.8665473461151123), ('evening', 0.7880070209503174), ('yesterday', 0.7614548206329346), ('sunday', 0.7548925876617432)]
# ```

# %% [markdown]
# #### 1.4 Quelle est la similarité cosinus entre 'fast' et 'slow' ? Entre 'fast' et 'rapid' ? Commentez les résultats et expliquez leur origine. (3 points)

# %%
nDim = 300
fastEmbedding = torch.reshape(embeddings[word_to_index['fast']],(1,nDim))
slowEmbedding = torch.reshape(embeddings[word_to_index['slow']],(1,nDim))
rapidEmbedding = torch.reshape(embeddings[word_to_index['rapid']],(1,nDim))

fastSlowRapidSimilarity = cosine_similarity(fastEmbedding, torch.cat((slowEmbedding,rapidEmbedding),0))

print(f'{"":^10} |{"slow":^10} |{"rapid":^10}')
fastSlowStr = f'{float(fastSlowRapidSimilarity[0,0]):.5f}'
fastRapidStr = f'{float(fastSlowRapidSimilarity[0,1]):.5f}'
print(f'{"fast":^10} |{fastSlowStr:^10} |{fastRapidStr:^10}')
# Out:
#            |   slow    |  rapid
#    fast    | 0.71137   | 0.64453

# %% [markdown]
# ### 2. Évaluation (12 Points)
#
# #### Données
#
# Les cellules qui suivent permettent de télécharger les données et de se restreindre au vocabulaire qui nous sera utile, pour éviter de charger des plongements inutiles.
#
# Comme décrit dans l'introduction, nous avons 3 fichiers de données:
# - Des paires de synonymes pour l'entraînement (`train_synonyms.txt`)
# - Des paires d'antonymes pour l'entraînement (`train_antonymms.txt`)
# - Des paires de mots avec leur similarité pour l'évaluation (`simlex_english.txt`)

# %%
def load_data(filepath):
    """
    Télécharge les paires de synonymes et antonymes
    """
    data = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            pair = line.strip().split()
            assert pair[0].startswith('en_') and pair[0].startswith('en_')
            data.append((pair[0][3:], pair[1][3:]))
    return data

def data_to_tensor(data, word_to_index):
    indices = [word_to_index[word] for pair in data for word in pair if word in word_to_index]
    return torch.tensor(indices).view(-1, 2)

# %%
# Données d'entraînement
train_synonyms = load_data(train_synonyms_path)
train_antonyms = load_data(train_antonyms_path)

# Données d'évaluation
evaluation_simlex = pd.read_csv(eval_simlex, sep='\t') # pd dataframe with columns 'word 1', 'word 2', 'score'

# On se restreint au vocabulaire qu'on va utiliser pour éviter de charger des embeddings inutiles
vocab = set([word for pair in train_synonyms + train_antonyms for word in pair])
eval_vocab = set(evaluation_simlex['word 1']).union(set(evaluation_simlex['word 2']))
vocab.update(eval_vocab)

glove_word_to_index, glove_embeddings = load_word_vectors(pretrained_model_path, vocab)

# %% [markdown]
# #### 2.1 Observation du jeu de données SimLex-999. (2 points)
#
# Affichez l'histogramme de fréquence des scores de similarité dans le jeu de données SimLex-999. Utilisez `bins=40`. Votre axe des x doit représenter le score de similarité et votre axe des y doit représenter la fréquence. Comment interpréter un score de 0?

# %%
plt.figure()
evaluation_simlex.hist('score',bins = 40,density = True)
plt.title("Histogramme des scores dans Simlex-999")
plt.ylabel("taux d'apparition en %")
plt.xlabel("Score")
# Out:
# Text(0.5, 0, 'Score')

# %% [markdown]
# #### 2.2 Corrélation de Spearman
#
#
# La corrélation de Spearman est une mesure de la relation monotone entre deux variables $x$ et $y$. Elle est comprise entre -1 et 1. Plutôt que de comparer les valeurs brutes des variables, elle compare leurs rangs. Elle est calculée comme suit :
# $$\rho (x, y) = 1 - \frac{6 \sum_{i=1}^n (r_{x_i} - r_{y_i})^2}{n(n^2 - 1)}$$
# où $r_{x_i}$ est le rang de la i-ème valeur de la variable x, $r_{y_i}$ est le rang de la i-ème valeur de la variable y, $n$ est le nombre total de paires d'observations $(x, y)$.
#
# Les rangs sont attribués en ordonnant les valeurs de chaque variable du plus petit au plus grand. La plus petite valeur reçoit le rang 1, la suivante le rang 2, et ainsi de suite.
#
# ##### Expliquez pourquoi on utilise la corrélation de Spearman plutôt que la corrélation entre les valeurs des variables. (3 points)

# %% [markdown]
# #### 2.3 Implémentation de la corrélation de Spearman (2 points)
#
# Complétez la fonction suivante pour calculer la corrélation de Spearman entre deux listes de valeurs.

# %%
def spearman_rank_correlation(x, y):
    """
    Calcule la corrélation de Spearman entre deux listes de valeurs.

    Args:
        x   : list of float
        y   : list of float

    Returns:
    La corrélation de Spearman entre les deux listes (float). 
    """
    N = len(x)
    x = np.array(x)
    y = np.array(y)
    x_y = x-y
    factor = 6 / (N * ( (N ** 2) - 1))
    return 1 - factor * np.dot(x_y,x_y)

# %%
# spearman_rank_correlation([1,3,4,2],[2,1,4,3]) = 0.4

# %% [markdown]
# #### 2.4 Évaluation du modèle GloVe (2 points)
#
#
# Retrouvez les plongements du modèle GloVe de tous les mots du jeu de données SimLex-999, puis calculez la similarité cosinus entre les paires.
#
# Calculez ensuite la corrélation de Spearman entre les scores de simlex et les similarités cosinus obtenues et affichez-la.

# %%
similarityBetweenPairs = pd.DataFrame({"word 1" : list(evaluation_simlex["word 1"]),
                                       "word 2" : list(evaluation_simlex["word 2"])})

# %%
def getRank(array):
    order = array.argsort()
    return order.argsort()

# %%
# Calculate similarity between pairs
score = []
for i in range(len(similarityBetweenPairs)):
    score.append(float(cosine_similarity(
        torch.reshape(glove_embeddings[glove_word_to_index[similarityBetweenPairs['word 1'][i]]],(1,-1)),
        torch.reshape(glove_embeddings[glove_word_to_index[similarityBetweenPairs['word 2'][i]]],(1,-1))
    )))
similarityBetweenPairs['score'] = pd.Series(score)

# Evaluate the rank (1 = lowest score, N = highest score)
similarityBetweenPairs['rank'] = getRank(similarityBetweenPairs['score'])
evaluation_simlex['rank'] = getRank(evaluation_simlex['score'])

# %%
# Evaluate Spearman correlation
spearman_rank_correlation(similarityBetweenPairs['rank'],
                          evaluation_simlex['rank'])
# Out:
# 0.29230790710550225

# %% [markdown]
# Résultat attendu: 0.29

# %% [markdown]
# #### 2.5 Interprétation du résultat (3 points)
#
# Qu'est ce que ce nombre représente et que peut-on en conclure sur la qualité des plongements GloVe (2 conclusions) ?

# %% [markdown]
# ### 3. Description de la méthode contrastive (33 Points)
#
# Nous allons maintenant implémenter une méthode contrastive de plongements de mots. Elle vise à améliorer les plongements lexicaux de mots en tenant compte des synonymes et antonymes.
#
# Notre modèle se basera simplement sur une matrice de plongements de mots, qui associe à chaque mot un vecteur de plongement.
#
# L'idée est d'entraîner ce modèle à rapprocher les plongements de synonymes et d'éloigner ceux d'antonymes.
#
# La cellule suivante définit le modèle et ses attributs.

# %%
class ContrastiveWordEmbeddingModel(nn.Module):
    def __init__(self, embeddings, device='cpu', margin_plus=0.6, margin_minus=0., regularization=1e-9):
        super(ContrastiveWordEmbeddingModel, self).__init__()
        
        self.device = device

        # Hyperparamètres pour les fonctions de coût
        self.margin_plus = margin_plus
        self.margin_minus = margin_minus
        self.regularization = regularization
        
        # Initialisation des plongements de mots
        self.embeddings = nn.Embedding.from_pretrained(embeddings.detach().clone(), freeze=False).to(self.device)
        self.original_embeddings = nn.Embedding.from_pretrained(embeddings.detach().clone(), freeze=True).to(self.device)

# %% [markdown]
# #### 3.1 Création des négatifs
#
# Pendant l'entraînement, au lieu de traiter tout le jeu d'entraînement d'un coup, nous allons avoir des lots (batchs) de paires de synonymes $B_S$ et d'antonymes $B_A$.
#
# Dans un lot de synonymes, on définit le négatif d'un mot comme le mot du lot le plus proche qui n'est pas dans la même paire. Intuitivement, c'est le mot que le modèle devrait confondre le plus avec le synonyme. Similairement, dans un lot d'antonymes, on définit le négatif d'un mot comme le mot du lot le plus éloigné qui n'est pas dans la même paire.
#
# On répète ce processus pour chaque mot de chaque paire de synonymes et d'antonymes.
#
# *Attention, un mot peut apparaître plusieurs fois dans un lot avec des synonymes ou antonymes différents, et il ne peut être le négatif d'aucun de ses synonymes, ou antonymes.*
#
# ##### 3.1.1 Exemple pour illustrer l'implémentation
#
# Prenons un exemple avec un lot $B_S$ de synonymes de taille 3. On veut construire le lot de négatifs $T_S$
#
# $B_S$:
# - (arbre, plante)
# - (voiture, véhicule)
# - (arbre, buisson)
#
# On a 5 mots uniques dans le lot: arbre, plante, voiture, véhicule, buisson. Supposons que la matrice de similarité cosinus soit la suivante :
#
# |       | arbre | plante | voiture | véhicule | buisson |
# |-------|-------|--------|--------|----------|---------|
# | arbre | 1     | 0.8    | 0.1    | 0.2      | 0.9     |
# | plante| 0.8   | 1      | 0.3    | 0.4      | 0.7     |
# | voiture| 0.1  | 0.3    | 1      | 0.9      | 0.2     |
# | véhicule| 0.2 | 0.4    | 0.9    | 1        | 0.3     |
# | buisson| 0.9  | 0.7    | 0.2    | 0.3      | 1       |
#
#
# On commence par calculer les voisins de chaque mot du lot $B_S$. Le voisin d'un mot $m$ est défini comme tout mot qui apparait dans au moins une paire avec $m$ dans $B_S$. Un mot est aussi considéré comme son propre voisin.
#
# - voisins de arbre : arbre, plante, buisson
# - voisins de plante : plante, arbre
# - voisins de voiture : voiture, véhicule
# - voisins de véhicule : véhicule, voiture
# - voisins de buisson : buisson, arbre
#
# Après avoir masqué les voisins, la matrice est :
#
# |       | arbre | plante | voiture | véhicule | buisson |
# |-------|-------|--------|--------|----------|---------|
# | arbre | -inf  | -inf   | 0.1    | 0.2      | -inf    |
# | plante| -inf  | -inf   | 0.3    | 0.4      | 0.7     |
# | voiture| 0.1  | 0.3    | -inf   | -inf     | 0.2     |
# | véhicule| 0.2 | 0.4    | -inf   | -inf     | 0.3     |
# | buisson| -inf | 0.7    | 0.2    | 0.3      | -inf    |
#
# Pour calculer les négatifs, on prend le maximum de chaque ligne (donc le mot le plus similaire qui n'est pas un voisin) :
#
# Ici,
# - le négatif d'arbre est véhicule
# - le négatif de plante est buisson
# - le négatif de voiture est plante
# - le négatif de véhicule est plante
# - le négatif de buisson est plante
#
# En reprenant le batch $B_S$:
# - (arbre, plante)
# - (voiture, véhicule)
# - (arbre, buisson)
#
# $T_S$ sera composé de paires composées du négatif de chaque élément de $B_S$ :
#
# $B_S$ -> $T_S$
# - (arbre, plante) $\rightarrow$ (véhicule, buisson), car le négatif d'arbre est véhicule et le négatif de plante est buisson
# - (voiture, véhicule) $\rightarrow$ (plante, plante), car le négatif de voiture est plante et le négatif de véhicule est plante
# - (arbre, buisson) $\rightarrow$ (véhicule, plante), car le négatif d'arbre est véhicule et le négatif de buisson est plante
#
# $T_S$ sera donc :
# - (véhicule, buisson)
# - (plante, plante)
# - (véhicule, plante)

# %% [markdown]
# ##### 3.1.2 Implémentez la fonction `prepare_neighbors` qui renvoit la liste des voisins de chaque mot dans le lot. (4 points)
#
# Les voisins d'un mot $m$ sont tous les mots du lot qui apparaissent dans au moins une paire avec $m$. Utilisez les bons indices (indice dans la matrice d'embeddings et indice dans le lot). Le résultat est une liste de liste de voisins, où `neighbors[i]` est la liste des voisins du mot `i` dans le lot.

# %%
def prepare_neighbors(index_pairs, unique_idx, index_to_idx):
    """
    Prépare les voisins pour chaque mot dans les paires de mots.
    
    Args : 
        index_pairs     : torch.Tensor de seconde dimension 2
        Tensor contenant les indices des embeddings des mots dans le vocabulaire. 
        Des indices qui sont reliés ensemble par une ligne dans ce tenseur ont 
        une relation sémantique entre eux (synonymes ou antonymes).

        unique_idx      : set
        Ensemble de tous les indices qui sont mentionnés dans la liste `index_pairs`.
        
        index_to_idx    : dict
        Dictionnaire associant un indice mentionné dans `index_pairs` à son indice dans
        la liste qui sera retournée. Par exemple, si dans ce dictionnaire, la clé 4 est
        associée à la valeur 12, cela veut dire que les voisins du mot 4 dans le vocabulaire
        seront retournés à l'indice 12 dans la liste de retour.

    Returns:
    Une liste où chaque élément est une liste des indices des voisins pour chaque mot (l'indice dans la liste correspond à l'indice unique).
    """
    tempDict = {}
    # The strategy here is to first loop through all the pairs and create a dictionnary where the keys are the index
    # of the words (eventually out.keys() = unique_idx) and the values are the indexes of the words in the pair
    
    # Looping through the pairs
    for pair in index_pairs:
        """
        # Right solution to me be doesn't match the solution
        pair0,pair1 = int(pair[0]),int(pair[1])
        # checkinng if the word has already been seen
        if pair0 not in tempDict.keys():
            # if not, create an empty list with itself in it
            tempDict[pair0] = [pair0]
        # checking if the second word has already be seen next to the first word
        if pair1 not in tempDict[pair0]:
            # if not, add it to the list
            tempDict[pair0] += [pair1]

        # Do the same for the other word
        if pair1 not in tempDict.keys():
            tempDict[pair1] = [pair1]
        if pair0 not in tempDict[pair1]:
            tempDict[pair1] += [pair0]
        """
        # wrong solution to me be does match the solution
        pair0,pair1 = int(pair[0]),int(pair[1])
        # checkinng if the word has already been seen
        if pair0 not in tempDict.keys():
            # if not, create an empty list with itself in it
            tempDict[pair0] = []
        tempDict[pair0] += [pair0,pair1]

        # Do the same for the other word
        if pair1 not in tempDict.keys():
            tempDict[pair1] = []
        tempDict[pair1] += [pair1,pair0]

        
    # right now we have a dictionnary linking a word's index to all the other words' index it shared a pair with
    lenOut = max(index_to_idx.values()) + 1
    listOut = [[] for i in range(lenOut)]

    for word_idx in unique_idx:
        listOut[index_to_idx[int(word_idx)]] += [index_to_idx[el] for el in tempDict[int(word_idx)]]
    
    return listOut

# %%
# Exemple

index_pairsTEST = torch.tensor([[0, 12], [12, 31], [53, 4]])
unique_idxTEST = {0, 4, 12, 31, 53}
index_to_idxTEST = {0: 0, 4: 1, 12: 2, 31: 3, 53: 4}
print(prepare_neighbors(index_pairsTEST, unique_idxTEST, index_to_idxTEST))
# Out:
# [[0, 2], [1, 4], [2, 0, 2, 3], [3, 2], [4, 1]]

# %% [markdown]
# Réponse attendue
#
# `[[0, 2], [1, 4], [2, 0, 2, 3], [3, 2], [4, 1]]`

# %% [markdown]
# ##### 3.1.3 Implémentez la fonction `select_negatives` qui renvoit un dictionnaire qui associe à chaque élément son négatif. (4 points)
#
# Pour chaque élément du lot, on cherche le voisin le plus proche qui n'est pas le voisin de l'autre élément de la paire.
#
# Utilisez un masque pour cacher, dans la matrice de similarité, les voisins.
#
# La fonction utilise un paramètre `synonym` qui indique si on travaille sur un lot de synonymes ou d'antonymes. En cas de synonymes, on cherche le voisin le plus proche qui n'est pas un voisin de l'autre élément de la paire. En cas d'antonymes, on cherche le voisin le plus éloigné qui n'est pas un voisin de l'autre élément de la paire.

# %%
def select_negatives(indices, similarity_matrix, neighbors, synonym=True):
    """
    Sélectionne les exemples négatifs à partir de la matrice de similarité et des voisins.

    Args : 
        indices             : torch.Tensor (vocab_size)
        Indices des mots présents dans le vocabulaire
        
        similarity_matrix   : torch.Tensor (vocab_size, vocab_size)
        Matrice de similarité entre tous les mots présents dans le vocabulaire.
        
        neighbors           : list of lists
        Liste des voisins de chaque mot. Par exemple, le premier élément de la liste
        contiendra tous les voisins du mot 0 dans le vocabulaire.

        synonym             : bool, optional (default=True)
        Indique si l'on cherche des négatifs pour les synonymes (True) ou pour les antonymes (False).

    Returns:
    Dictionnaire mappant les mots avec leurs indices de négatifs {mot_index: négatif_index}.
    """
    vocabSize = len(indices)
    outDict = {}
    for row in range(vocabSize):
        similarity_matrix[row,neighbors[row]] = (-2 * synonym + 1) * np.inf # if synonym == True, mask it with -inf, else mask it with +inf
        indexSorted = np.argsort(similarity_matrix[row,:].detach().numpy())
        outDict[int(indices[row])] = int(indices[indexSorted[-1 * synonym]]) # if synonym, take the last one, else, take the first one

    return outDict

# %%
# Exemple
indices = torch.tensor([0, 1, 2, 3, 4])
neighbors = [[0, 2], [1, 4], [2, 0, 2, 3], [3, 2], [4, 1]]

similarity_matrix = torch.tensor([
    [ 1.0000, -0.4263, -0.7167, -0.9838, -0.5823],
    [-0.4263,  1.0000, -0.1600,  0.5088, -0.3708],
    [-0.7167, -0.1600,  1.0000,  0.7247,  0.5631],
    [-0.9838,  0.5088,  0.7247,  1.0000,  0.4394],
    [-0.5823, -0.3708,  0.5631,  0.4394,  1.0000]
    ])

print(select_negatives(indices, similarity_matrix, neighbors, synonym=True))
# Out:
# {0: 1, 1: 3, 2: 4, 3: 1, 4: 2}

# %% [markdown]
# Réponse attendue
#
# `{0: 1, 1: 3, 2: 4, 3: 1, 4: 2}`

# %% [markdown]
# ##### 3.1.4 Implémentez la fonction `run_negative_extraction` qui prépare les paires de synonymes et d'antonymes et appelle `prepare_neighbors` et `select_negatives`. (4 points)
#
# Préparez les indices uniques des mots du batch, calculez la similarité des mots, et appelez `prepare_neighbors` et `select_negatives`.

# %%
def run_negative_extraction(model, index_pairs, synonym=True):
    """
    Extrait les exemples négatifs pour un ensemble de paires de mots.

    Args:
        index_pairs : torch.Tensor of shape (n, 2)
                      Contient les indices des mots.

        synonym     : bool, optional (default=True)
                      Indique si l'on cherche des négatifs pour les synonymes (True) ou pour les antonymes (False).

    Returns:
    Dictionnaire mappant les indices des mots avec leurs indices de négatifs {mot_index: négatif_index}.
    """
    # create unix_id
    unix_id = torch.unique(index_pairs)

    #create index_to_idx
    index_to_idx = {}
    for i,word_idx in enumerate(unix_id):
        index_to_idx[int(word_idx)] = i


    # Get the neighbors
    neighbors = prepare_neighbors(index_pairs,unix_id,index_to_idx)


    # Calculate the similarity matrix
    wordEmbeddings = model.embeddings.weight[unix_id,:]
    similarity_matrix = cosine_similarity(wordEmbeddings,wordEmbeddings)

    return select_negatives(unix_id,similarity_matrix,neighbors)

# %% [markdown]
# #### 3.2 Fonctions de coût
#
# Pour chaque paire de synonymes $(x^l, x^r)$ *pour x left et x right* dans le lot $B_S$, nous trouvons un négatif $(t^l, t^r)$ ce qui constitue le lot $T_S$:
# - $ t^l $ est le mot dans le lot le plus proche de $ x^l $ mais qui n'est pas $ x^r $.
# - $ t^r $ est le mot dans le lot le plus proche de $ x^r $ mais qui n'est pas $ x^l $.
#
# De même, pour chaque paire d'antonymes $(x^l, x^r)$ dans le lot $B_A$, nous trouvons un négatif $(t^l, t^r)$ ce qui constitue le lot $T_A$:
# - $ t^l $ est le mot dans le lot le plus éloigné de $ x^l $ mais qui n'est pas $ x^r $.
# - $ t^r $ est le mot dans le lot le plus éloigné de $ x^r $ mais qui n'est pas $ x^l $.
#
#
# Comparer un mot à son synonyme (ou antonyme) et à son négatif permet d'entraîner le modèle sur des exemples difficiles qui forcent le modèle à apprendre des représentations plus robustes.
#
# Il y aura trois fonctions de coût :
# 1. **Attraction** : Attire les synonymes plus proches les uns des autres.
# 2. **Répulsion** : Repousse les antonymes plus loin les uns des autres.
# 3. **Régularisation** : Évite que les plongements ne s'éloignent trop de ceux du modèle pré-entraîné.
#
# Les fonctions de coût sont définies comme suit, en sommant sur `i`, les paires de synonymes et d'antonymes dans les lots $B_S$ et $B_A$ :
#
# 1. **Attraction** :
# $$ S(B_S, T_S) = \sum_{i=1}^{|B_S|} \left[ \max \left(0, \delta_{syn} + x_i^l t_i^l - x_i^l x_i^r \right) + \max \left( 0, \delta_{syn} + x_i^r t_i^r - x_i^l x_i^r \right) \right] $$
#
# 1. **Répulsion** :
# $$ A(B_A, T_A) = \sum_{i=1}^{|B_A|} \left[ \max \left(0, \delta_{ant} + x_i^l x_i^r - x_i^l t_i^l \right) + \max \left( 0, \delta_{ant} + x_i^r x_i^l - x_i^r t_i^r \right) \right] $$
#
# 1. **Régularisation** :
# $$ R(B_S, B_A) = \sum_{x_i \in V(B_S \cup B_A)} \lambda_{reg} \| \hat{x}_i - x_i \|^2 $$
#
# La fonction de coût totale est la somme de ces trois termes :
# $$ C(B_S, T_S, B_A, T_A) = S(B_S, T_S) + A(B_A, T_A) + R(B_S, B_A) $$
#
# $\delta_{syn}$, $\delta_{ant}$ et $\lambda_{reg}$ sont des hyperparamètres.

# %% [markdown]
# Avec l'exemple précédent, prenons
# > + $x_i^l$ : voiture
# > + $x_i^r$: véhicule
# > + $t_i^l$: plante
# >
# > On veut que voiture et véhicule aient un plus grand produit scalaire que voiture et plante, donc que $\delta_{syn} + x_i^l t_i^l - x_i^l x_i^r <0$, et donc que $S$ soit minimisé. De même pour la deuxième partie de l'équation, symmétrique, avec le 2nd élément du couple.

# %% [markdown]
# ##### 3.2.1 Implémentez la fonction `synonym_cost` qui calcule la fonction de coût d'attraction (sur les paires de synonymes). (5 points)
#
# $$ S(B_S, T_S) = \sum_{i=1}^{|B_S|} \left[ \max \left(0, \delta_{syn} + x_i^l t_i^l - x_i^l x_i^r \right) + \max \left( 0, \delta_{syn} + x_i^r t_i^r - x_i^l x_i^r \right) \right] $$
#
# Le membre de gauche pénalise si le mot de gauche est plus éloigné de son négatif que de son synonyme. De même, le membre de droite pénalise si le mot de gauche est plus éloigné de son négatif que de son synonyme.

# %%
def synonym_cost(model, synonym_pairs, synonym_negatives):
    """
    Calcule le coût d'attraction pour les paires de synonymes.

    synonym_pairs: liste de tuples d'indices de paires de synonymes
    synonym_negatives: dictionnaire de mots avec leurs négatifs {mot_index: négatif_index}

    Returns:
    torch.Tensor, coût total pour les paires de synonymes
    """
    delta_s = model.margin_plus
    
    xl = synonym_pairs[:,0]
    xr = synonym_pairs[:,1]
    tl = torch.empty((0,), dtype=torch.long)
    tr = torch.empty((0,), dtype=torch.long)
    
    for pair in synonym_pairs:
        left_tensor = torch.tensor(synonym_negatives[pair[0].item()])
        right_tensor = torch.tensor(synonym_negatives[pair[1].item()])
        tl = torch.cat((tl, left_tensor.unsqueeze(0)), 0)
        tr = torch.cat((tr, right_tensor.unsqueeze(0)), 0)
    
    xl_tl = torch.sum(model.embeddings(xl) * model.embeddings(tl), dim=1)
    xl_xr = torch.sum(model.embeddings(xl) * model.embeddings(xr), dim=1)
    xr_tr = torch.sum(model.embeddings(xr) * model.embeddings(tr), dim=1)
    
    matrix = torch.relu(delta_s + xl_tl - xl_xr) + torch.relu(delta_s + xr_tr - xl_xr)
    
    S = torch.sum(matrix)
   
    return S

# %% [markdown]
# ##### 3.2.2 Implémentez la fonction `antonym_cost` qui calcule la fonction de coût de répulsion (sur les paires d'antonymes). (5 points)
#
# $$ A(B_A, T_A) = \sum_{i=1}^{|B_A|} \left[ \max \left(0, \delta_{ant} + x_i^l x_i^r - x_i^l t_i^l \right) + \max \left( 0, \delta_{ant} + x_i^r x_i^l - x_i^r t_i^r \right) \right] $$
#
# Le membre de gauche pénalise si le mot de gauche est plus éloigné de son antonyme que de son négatif. De même, le membre de droite pénalise si le mot de gauche est plus éloigné de son antonyme que de son négatif.

# %%
def antonym_cost(model, antonym_pairs, antonym_negatives):
    """
    Calcule le coût de répulsion pour les paires d'antonymes.

    antonym_pairs: liste de tuples d'indices de paires d'antonymes
    antonym_negatives: dictionnaire de mots avec leurs négatifs {mot_index: négatif_index}

    Returns:
    torch.Tensor, coût total pour les paires d'antonymes
    """
    delta_a = model.margin_minus
    
    xl = antonym_pairs[:,0]
    xr = antonym_pairs[:,1]
    tl = torch.empty((0,), dtype=torch.long)
    tr = torch.empty((0,), dtype=torch.long)
    
    for pair in antonym_pairs:
        left_tensor = torch.tensor(antonym_negatives[pair[0].item()])
        right_tensor = torch.tensor(antonym_negatives[pair[1].item()])
        tl = torch.cat((tl, left_tensor.unsqueeze(0)), 0)
        tr = torch.cat((tr, right_tensor.unsqueeze(0)), 0)
    
    xl_xr = torch.sum(model.embeddings(xl) * model.embeddings(xr), dim=1)
    xl_tl = torch.sum(model.embeddings(xl) * model.embeddings(tl), dim=1)
    xr_xl = torch.sum(model.embeddings(xr) * model.embeddings(xl), dim=1)
    xr_tr = torch.sum(model.embeddings(xr) * model.embeddings(tr), dim=1)
    
    matrix = torch.relu(delta_a + xl_xr - xl_tl) + torch.relu(delta_a + xr_xl - xr_tr)
    
    A = torch.sum(matrix)
   
    return A

# %% [markdown]
# ##### 3.2.3 Implémentez la fonction `regularization_cost` qui calcule la fonction de coût de régularisation. (4 points)
#
# $$ R(B_S, B_A) = \sum_{x_i \in V(B_S \cup B_A)} \lambda_{reg} \| \hat{x}_i - x_i \|^2 $$

# %%
def regularization_cost(model, synonym_pairs, antonym_pairs):
    """
    Calcule le coût de régularisation pour les paires de synonymes et antonymes.

    synonym_pairs: liste de tuples d'indices de paires de synonymes
    antonym_pairs: liste de tuples d'indices de paires d'antonymes

    Returns:
    torch.Tensor, coût total de régularisation
    """

    indexes = torch.unique(torch.cat((synonym_pairs, antonym_pairs)))

    xhat = model.original_embeddings(indexes)
    x = model.embeddings(indexes)
    
    squared_norms = torch.norm(xhat - x, p=2, dim=1)  


    R = model.regularization * torch.sum(squared_norms)
    
    return R

# %% [markdown]
# #### 3.3 Mise en place
# ##### 3.3.1 Implémentez la fonction `forward` qui utilise les fonctions définies plus tôt pour calculer le coût total. (4 points)
#
# La fonction prend en entrée un lot de synonymes et un lot d'antonymes, c'est-à-dire des paires de synonymes et des paires d'antonymes.
#
# Vous devez trouver les négatifs de tous les mots des lots au moyen de votre fonction  run_negative_extraction puis calculer la fonction de coût totale.

# %%
def forward(model, synonym_pairs, antonym_pairs):
    """
    Fonction forward pour calculer le coût total.

    Args : 
        synonym_pairs   : 
        Liste de tuples d'indices de paires de synonymes

        antonym_pairs   : 
        Liste de tuples d'indices de paires d'antonymes

    Returns:
    Tenseur contenant le coût total (attraction, répulsion et régularisation)
    """

    synonym_negatives = run_negative_extraction(model,synonym_pairs,synonym = True)

    # We can now evaluate S
    S = synonym_cost(model,synonym_pairs,synonym_negatives)

    antonym_negatives = run_negative_extraction(model,antonym_pairs,synonym = False)

    # We can now evaluate A
    A = antonym_cost(model,antonym_pairs,antonym_negatives)

    # We evaluate the regularization cost
    R = regularization_cost(model, synonym_pairs, antonym_pairs)

    return S + A + R

# %% [markdown]
# #### 3.3.2 Évaluation (3 points)
#
# Utilisez la fonction `spearman_rank_correlation` pour compléter la fonction d'évaluation `evaluate` qui exécute le modèle sur le jeu d'évaluation et calcule la corrélation de Spearman entre les scores prédits et réels.
#
# Utilisez `torch.no_grad()` pour éviter de stocker les gradients.

# %%
def evaluate(model, eval_data, word_to_index):
    """
    Calcule les prédictions du modèle sur le jeu d'évaluation puis la corrélation de Spearman entre les scores prédits et réels.

    model: modèle de plongements de mots
    eval_data: pd.DataFrame
    word_to_index: dict

    Returns:
    float, la corrélation de Spearman entre les scores prédits par le modèle et réels.
    """

    model.eval()
    device = model.device
    word_pairs = list(zip(eval_data['word 1'], eval_data['word 2']))
    eval_indices = [(word_to_index[w1], word_to_index[w2]) for w1, w2 in word_pairs if w1 in word_to_index and w2 in word_to_index]
    
    # Estimate the score of the embeddings of the words in eval_data
    score = []
    for pairOfIndexes in eval_indices:
        score.append(float(cosine_similarity(
            torch.reshape(model.embeddings.weight[pairOfIndexes[0],:],(1,-1)),
            torch.reshape(model.embeddings.weight[pairOfIndexes[1],:],(1,-1))
        )))
    # Estimate the ranks of words in eval_data
    rank = getRank(np.array(score))
    with torch.no_grad():
        sCorrelation = spearman_rank_correlation(
            rank,
            evaluation_simlex['rank']
        )
    return sCorrelation

# %% [markdown]
# ### 4. Entraînement de zéro (16 Points)
#
# Nous allons maintenant entraîner le modèle de zéro, sans utiliser les plongements GloVe pré-entraînés. Ensuite, dans la partie 5, nous entraînerons le modèle en l'initialisant avec les plongements GloVe pré-entraînés.

# %%
# Hyperparamètres, optimiseur et DataLoader

BATCH_SIZE = 64
NUM_EPOCHS = 20
LEARNING_RATE = 5e-3

device = 'cuda' if torch.cuda.is_available() else 'cpu'

torch.cuda.empty_cache()
gc.collect()

train_syn_tensor = data_to_tensor(train_synonyms, glove_word_to_index)
train_ant_tensor = data_to_tensor(train_antonyms, glove_word_to_index)

syn_data_loader = DataLoader(train_syn_tensor, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
ant_data_loader = DataLoader(train_ant_tensor, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)

# %%
len(ant_data_loader)
# Out:
# 186

# %% [markdown]
# #### 4.1 Complétez la cellule suivante pour créer le modèle de zéro `model_zero`, à partir d'une matrice de plongements aléatoire. (1 point)

# %%
random_seed = 0
random_generator = torch.Generator(device=device).manual_seed(random_seed)

embeddings_size = glove_embeddings.size()
random_init_embeddings = torch.randn(embeddings_size, generator=random_generator, device=device)


model_zero = model_zero = ContrastiveWordEmbeddingModel(random_init_embeddings, device=device)

optimizer = optim.Adam(model_zero.parameters(), lr=LEARNING_RATE)

# %%
spearman_corr = evaluate(model_zero, evaluation_simlex, glove_word_to_index)
print(f'Before training, Spearman Correlation: {spearman_corr:.4f}')
# Out:
# Before training, Spearman Correlation: -0.0272

# %% [markdown]
# #### 4.2 Entraînez le modèle sur le jeu des paires de synonymes et d'antonymes. (6 points)
#
# N'oubliez pas que l'entraînement se fait sur les synonymes et antonymes et que l'évaluation se fait sur SimLex-999.
#
# À défaut d'avoir un jeu de validation, on observe les résultats sur le corpus de test : SimLex-999. Ceci n’est fait qu’à titre illustratif pour voir l'évolution de l'apprentissage. Il ne faut pas faire de choix pour l’entrainement à partir des résultats sur le corpus de test.
#
# *Note : Les jeux de synonymes et d'antonymes n'ont pas la même taille. Une époque (epoch) correspond à une itération sur le jeu de données le plus petit.*

# %%
from tqdm import tqdm
spearman_corr = evaluate(model_zero, evaluation_simlex, glove_word_to_index)
print(f'Before training, Spearman Correlation: {spearman_corr:.4f}')

# TODO
losses = []
spearman_corrList = []
for epoch in tqdm(range(NUM_EPOCHS), desc="epoch"):
    model_zero.train()
    temp_losses = 0
    for syn, ant in tqdm(zip(syn_data_loader, ant_data_loader), desc="dataloaders"):
        #print(syn)
        
        
        loss = forward(model_zero, syn, ant)
        
        optimizer.zero_grad()
        
        
        loss.backward()
        temp_losses += loss
        
        optimizer.step()

    
    losses.append((temp_losses/(len(syn_data_loader)+len(ant_data_loader))).item())
    spearman_corr = evaluate(model_zero, evaluation_simlex, glove_word_to_index)
    spearman_corrList += [evaluate(model_zero,evaluation_simlex,glove_word_to_index)]

    
spearman_corr = evaluate(model_zero, evaluation_simlex, glove_word_to_index)
print(f'After training, Spearman Correlation: {spearman_corrList[-1]:.4f}')
print(f'After training, Spearman Correlation: {spearman_corr:.4f}')
# END TODO
# Out:
# Before training, Spearman Correlation: -0.0272
# epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.52it/s]
# dataloaders: 2it [00:00,  5.01it/s]
# dataloaders: 3it [00:00,  5.11it/s]
# dataloaders: 4it [00:00,  5.07it/s]
# dataloaders: 5it [00:01,  4.98it/s]
# dataloaders: 6it [00:01,  4.99it/s]
# dataloaders: 7it [00:01,  4.97it/s]
# dataloaders: 8it [00:01,  5.02it/s]
# dataloaders: 9it [00:01,  5.04it/s]
# dataloaders: 10it [00:01,  5.12it/s]
# dataloaders: 11it [00:02,  5.21it/s]
# dataloaders: 12it [00:02,  5.18it/s]
# dataloaders: 13it [00:02,  5.17it/s]
# dataloaders: 14it [00:02,  5.23it/s]
# dataloaders: 15it [00:02,  5.25it/s]
# dataloaders: 16it [00:03,  5.17it/s]
# dataloaders: 17it [00:03,  5.05it/s]
# dataloaders: 18it [00:03,  4.97it/s]
# dataloaders: 19it [00:03,  5.00it/s]
# dataloaders: 20it [00:03,  5.15it/s]
# dataloaders: 21it [00:04,  5.29it/s]
# dataloaders: 22it [00:04,  5.37it/s]
# dataloaders: 23it [00:04,  5.45it/s]
# dataloaders: 24it [00:04,  5.47it/s]
# dataloaders: 25it [00:04,  5.48it/s]
# dataloaders: 26it [00:05,  5.50it/s]
# dataloaders: 27it [00:05,  5.50it/s]
# dataloaders: 28it [00:05,  5.51it/s]
# dataloaders: 29it [00:05,  5.43it/s]
# dataloaders: 30it [00:05,  5.49it/s]
# dataloaders: 31it [00:05,  5.53it/s]
# dataloaders: 32it [00:06,  5.56it/s]
# dataloaders: 33it [00:06,  5.58it/s]
# dataloaders: 34it [00:06,  5.59it/s]
# dataloaders: 35it [00:06,  5.50it/s]
# dataloaders: 36it [00:06,  5.53it/s]
# dataloaders: 37it [00:06,  5.56it/s]
# dataloaders: 38it [00:07,  5.52it/s]
# dataloaders: 39it [00:07,  5.56it/s]
# dataloaders: 40it [00:07,  5.48it/s]
# dataloaders: 41it [00:07,  5.43it/s]
# dataloaders: 42it [00:07,  5.44it/s]
# dataloaders: 43it [00:08,  5.46it/s]
# dataloaders: 44it [00:08,  5.48it/s]
# dataloaders: 45it [00:08,  5.51it/s]
# dataloaders: 46it [00:08,  5.52it/s]
# dataloaders: 47it [00:08,  5.52it/s]
# dataloaders: 48it [00:08,  5.55it/s]
# dataloaders: 49it [00:09,  5.56it/s]
# dataloaders: 50it [00:09,  5.56it/s]
# dataloaders: 51it [00:09,  5.57it/s]
# dataloaders: 52it [00:09,  5.54it/s]
# dataloaders: 53it [00:09,  5.55it/s]
# dataloaders: 54it [00:10,  5.45it/s]
# dataloaders: 55it [00:10,  5.44it/s]
# dataloaders: 56it [00:10,  5.45it/s]
# dataloaders: 57it [00:10,  5.48it/s]
# dataloaders: 58it [00:10,  5.49it/s]
# dataloaders: 59it [00:10,  5.50it/s]
# dataloaders: 60it [00:11,  5.53it/s]
# dataloaders: 61it [00:11,  5.55it/s]
# dataloaders: 62it [00:11,  5.57it/s]
# dataloaders: 63it [00:11,  5.50it/s]
# dataloaders: 64it [00:11,  5.18it/s]
# dataloaders: 65it [00:12,  5.16it/s]
# dataloaders: 66it [00:12,  5.06it/s]
# dataloaders: 67it [00:12,  5.03it/s]
# dataloaders: 68it [00:12,  5.05it/s]
# dataloaders: 69it [00:12,  5.14it/s]
# dataloaders: 70it [00:13,  5.11it/s]
# dataloaders: 71it [00:13,  5.07it/s]
# dataloaders: 72it [00:13,  4.95it/s]
# dataloaders: 73it [00:13,  4.98it/s]
# dataloaders: 74it [00:13,  4.90it/s]
# dataloaders: 75it [00:14,  4.90it/s]
# dataloaders: 76it [00:14,  4.91it/s]
# dataloaders: 77it [00:14,  4.81it/s]
# dataloaders: 78it [00:14,  4.81it/s]
# dataloaders: 79it [00:14,  4.86it/s]
# dataloaders: 80it [00:15,  4.88it/s]
# dataloaders: 81it [00:15,  4.90it/s]
# dataloaders: 82it [00:15,  4.94it/s]
# dataloaders: 83it [00:15,  4.94it/s]
# dataloaders: 84it [00:15,  4.90it/s]
# dataloaders: 85it [00:16,  4.96it/s]
# dataloaders: 86it [00:16,  4.98it/s]
# dataloaders: 87it [00:16,  5.03it/s]
# dataloaders: 88it [00:16,  4.90it/s]
# dataloaders: 89it [00:17,  4.81it/s]
# dataloaders: 90it [00:17,  4.80it/s]
# dataloaders: 91it [00:17,  4.81it/s]
# dataloaders: 92it [00:17,  4.71it/s]
# dataloaders: 93it [00:17,  4.64it/s]
# dataloaders: 94it [00:18,  4.48it/s]
# dataloaders: 95it [00:18,  4.54it/s]
# dataloaders: 96it [00:18,  4.61it/s]
# dataloaders: 97it [00:18,  4.66it/s]
# dataloaders: 98it [00:19,  4.41it/s]
# dataloaders: 99it [00:19,  4.51it/s]
# dataloaders: 100it [00:19,  4.54it/s]
# dataloaders: 101it [00:19,  4.58it/s]
# dataloaders: 102it [00:19,  4.60it/s]
# dataloaders: 103it [00:20,  4.55it/s]
# dataloaders: 104it [00:20,  4.69it/s]
# dataloaders: 105it [00:20,  4.79it/s]
# dataloaders: 106it [00:20,  4.90it/s]
# dataloaders: 107it [00:20,  5.09it/s]
# dataloaders: 108it [00:21,  5.21it/s]
# dataloaders: 109it [00:21,  5.15it/s]
# dataloaders: 110it [00:21,  5.10it/s]
# dataloaders: 111it [00:21,  5.17it/s]
# dataloaders: 112it [00:21,  5.12it/s]
# dataloaders: 113it [00:22,  5.14it/s]
# dataloaders: 114it [00:22,  5.15it/s]
# dataloaders: 115it [00:22,  5.06it/s]
# dataloaders: 116it [00:22,  5.07it/s]
# dataloaders: 117it [00:22,  5.09it/s]
# dataloaders: 118it [00:23,  5.07it/s]
# dataloaders: 119it [00:23,  5.00it/s]
# dataloaders: 120it [00:23,  4.93it/s]
# dataloaders: 121it [00:23,  4.85it/s]
# dataloaders: 122it [00:23,  4.74it/s]
# dataloaders: 123it [00:24,  4.84it/s]
# dataloaders: 124it [00:24,  4.83it/s]
# dataloaders: 125it [00:24,  4.87it/s]
# dataloaders: 126it [00:24,  4.90it/s]
# dataloaders: 127it [00:24,  4.88it/s]
# dataloaders: 128it [00:25,  4.86it/s]
# dataloaders: 129it [00:25,  4.94it/s]
# dataloaders: 130it [00:25,  4.97it/s]
# dataloaders: 131it [00:25,  4.99it/s]
# dataloaders: 132it [00:25,  4.95it/s]
# dataloaders: 133it [00:26,  4.98it/s]
# dataloaders: 134it [00:26,  4.98it/s]
# dataloaders: 135it [00:26,  4.90it/s]
# dataloaders: 136it [00:26,  4.85it/s]
# dataloaders: 137it [00:26,  4.88it/s]
# dataloaders: 138it [00:27,  4.03it/s]
# dataloaders: 139it [00:27,  4.24it/s]
# dataloaders: 140it [00:27,  4.38it/s]
# dataloaders: 141it [00:27,  4.52it/s]
# dataloaders: 142it [00:28,  4.54it/s]
# dataloaders: 143it [00:28,  4.53it/s]
# dataloaders: 144it [00:28,  4.70it/s]
# dataloaders: 145it [00:28,  4.79it/s]
# dataloaders: 146it [00:28,  4.84it/s]
# dataloaders: 147it [00:29,  3.96it/s]
# dataloaders: 148it [00:29,  4.23it/s]
# dataloaders: 149it [00:29,  4.50it/s]
# dataloaders: 150it [00:29,  4.67it/s]
# dataloaders: 151it [00:30,  4.74it/s]
# dataloaders: 152it [00:30,  4.91it/s]
# dataloaders: 153it [00:30,  4.84it/s]
# dataloaders: 154it [00:30,  4.94it/s]
# dataloaders: 155it [00:30,  5.05it/s]
# dataloaders: 156it [00:31,  5.05it/s]
# dataloaders: 157it [00:31,  5.20it/s]
# dataloaders: 158it [00:31,  5.16it/s]
# dataloaders: 159it [00:31,  5.22it/s]
# dataloaders: 160it [00:31,  5.30it/s]
# dataloaders: 161it [00:31,  5.34it/s]
# dataloaders: 162it [00:32,  5.41it/s]
# dataloaders: 163it [00:32,  5.45it/s]
# dataloaders: 164it [00:32,  5.37it/s]
# dataloaders: 165it [00:32,  5.35it/s]
# dataloaders: 166it [00:32,  5.36it/s]
# dataloaders: 167it [00:33,  5.12it/s]
# dataloaders: 168it [00:33,  5.17it/s]
# dataloaders: 169it [00:33,  5.19it/s]
# dataloaders: 170it [00:33,  5.18it/s]
# dataloaders: 171it [00:33,  5.22it/s]
# dataloaders: 172it [00:34,  5.13it/s]
# dataloaders: 173it [00:34,  5.13it/s]
# dataloaders: 174it [00:34,  4.88it/s]
# dataloaders: 175it [00:34,  4.79it/s]
# dataloaders: 176it [00:34,  4.73it/s]
# dataloaders: 177it [00:35,  4.82it/s]
# dataloaders: 178it [00:35,  4.84it/s]
# dataloaders: 179it [00:35,  4.89it/s]
# dataloaders: 180it [00:35,  4.93it/s]
# dataloaders: 181it [00:35,  4.91it/s]
# dataloaders: 182it [00:36,  4.88it/s]
# dataloaders: 183it [00:36,  4.93it/s]
# dataloaders: 184it [00:36,  5.02it/s]
# dataloaders: 185it [00:36,  5.04it/s]
# dataloaders: 186it [00:36,  5.04it/s]
# epoch:   5%|▌         | 1/20 [00:37<11:46, 37.20s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.61it/s]
# dataloaders: 2it [00:00,  4.89it/s]
# dataloaders: 3it [00:00,  5.03it/s]
# dataloaders: 4it [00:00,  5.09it/s]
# dataloaders: 5it [00:00,  5.06it/s]
# dataloaders: 6it [00:01,  5.04it/s]
# dataloaders: 7it [00:01,  5.00it/s]
# dataloaders: 8it [00:01,  4.88it/s]
# dataloaders: 9it [00:01,  4.82it/s]
# dataloaders: 10it [00:02,  4.78it/s]
# dataloaders: 11it [00:02,  4.82it/s]
# dataloaders: 12it [00:02,  4.90it/s]
# dataloaders: 13it [00:02,  4.99it/s]
# dataloaders: 14it [00:02,  5.05it/s]
# dataloaders: 15it [00:03,  5.11it/s]
# dataloaders: 16it [00:03,  5.10it/s]
# dataloaders: 17it [00:03,  5.09it/s]
# dataloaders: 18it [00:03,  5.15it/s]
# dataloaders: 19it [00:03,  5.10it/s]
# dataloaders: 20it [00:03,  5.10it/s]
# dataloaders: 21it [00:04,  5.00it/s]
# dataloaders: 22it [00:04,  4.92it/s]
# dataloaders: 23it [00:04,  4.79it/s]
# dataloaders: 24it [00:04,  4.90it/s]
# dataloaders: 25it [00:05,  4.96it/s]
# dataloaders: 26it [00:05,  4.96it/s]
# dataloaders: 27it [00:05,  4.97it/s]
# dataloaders: 28it [00:05,  5.03it/s]
# dataloaders: 29it [00:05,  5.07it/s]
# dataloaders: 30it [00:06,  5.02it/s]
# dataloaders: 31it [00:06,  4.95it/s]
# dataloaders: 32it [00:06,  5.02it/s]
# dataloaders: 33it [00:06,  5.05it/s]
# dataloaders: 34it [00:06,  5.01it/s]
# dataloaders: 35it [00:07,  4.79it/s]
# dataloaders: 36it [00:07,  4.85it/s]
# dataloaders: 37it [00:07,  4.92it/s]
# dataloaders: 38it [00:07,  4.94it/s]
# dataloaders: 39it [00:07,  4.90it/s]
# dataloaders: 40it [00:08,  4.90it/s]
# dataloaders: 41it [00:08,  5.01it/s]
# dataloaders: 42it [00:08,  5.08it/s]
# dataloaders: 43it [00:08,  5.09it/s]
# dataloaders: 44it [00:08,  5.10it/s]
# dataloaders: 45it [00:09,  5.16it/s]
# dataloaders: 46it [00:09,  5.16it/s]
# dataloaders: 47it [00:09,  5.20it/s]
# dataloaders: 48it [00:09,  5.22it/s]
# dataloaders: 49it [00:09,  5.22it/s]
# dataloaders: 50it [00:09,  5.26it/s]
# dataloaders: 51it [00:10,  5.19it/s]
# dataloaders: 52it [00:10,  5.13it/s]
# dataloaders: 53it [00:10,  5.13it/s]
# dataloaders: 54it [00:10,  5.18it/s]
# dataloaders: 55it [00:10,  5.14it/s]
# dataloaders: 56it [00:11,  5.06it/s]
# dataloaders: 57it [00:11,  5.19it/s]
# dataloaders: 58it [00:11,  5.17it/s]
# dataloaders: 59it [00:11,  5.20it/s]
# dataloaders: 60it [00:11,  5.24it/s]
# dataloaders: 61it [00:12,  5.26it/s]
# dataloaders: 62it [00:12,  5.27it/s]
# dataloaders: 63it [00:12,  5.22it/s]
# dataloaders: 64it [00:12,  5.25it/s]
# dataloaders: 65it [00:12,  5.23it/s]
# dataloaders: 66it [00:13,  5.26it/s]
# dataloaders: 67it [00:13,  5.20it/s]
# dataloaders: 68it [00:13,  5.07it/s]
# dataloaders: 69it [00:13,  5.09it/s]
# dataloaders: 70it [00:13,  5.13it/s]
# dataloaders: 71it [00:14,  5.18it/s]
# dataloaders: 72it [00:14,  5.16it/s]
# dataloaders: 73it [00:14,  5.24it/s]
# dataloaders: 74it [00:14,  5.26it/s]
# dataloaders: 75it [00:14,  5.14it/s]
# dataloaders: 76it [00:15,  5.11it/s]
# dataloaders: 77it [00:15,  5.20it/s]
# dataloaders: 78it [00:15,  5.32it/s]
# dataloaders: 79it [00:15,  5.35it/s]
# dataloaders: 80it [00:15,  5.37it/s]
# dataloaders: 81it [00:15,  5.35it/s]
# dataloaders: 82it [00:16,  5.42it/s]
# dataloaders: 83it [00:16,  5.43it/s]
# dataloaders: 84it [00:16,  5.45it/s]
# dataloaders: 85it [00:16,  5.49it/s]
# dataloaders: 86it [00:16,  5.51it/s]
# dataloaders: 87it [00:17,  5.52it/s]
# dataloaders: 88it [00:17,  5.45it/s]
# dataloaders: 89it [00:17,  5.31it/s]
# dataloaders: 90it [00:17,  5.15it/s]
# dataloaders: 91it [00:17,  5.11it/s]
# dataloaders: 92it [00:18,  5.07it/s]
# dataloaders: 93it [00:18,  5.06it/s]
# dataloaders: 94it [00:18,  5.12it/s]
# dataloaders: 95it [00:18,  5.16it/s]
# dataloaders: 96it [00:18,  5.21it/s]
# dataloaders: 97it [00:18,  5.19it/s]
# dataloaders: 98it [00:19,  5.18it/s]
# dataloaders: 99it [00:19,  5.16it/s]
# dataloaders: 100it [00:19,  5.17it/s]
# dataloaders: 101it [00:19,  4.24it/s]
# dataloaders: 102it [00:20,  4.51it/s]
# dataloaders: 103it [00:20,  4.64it/s]
# dataloaders: 104it [00:20,  4.78it/s]
# dataloaders: 105it [00:20,  4.93it/s]
# dataloaders: 106it [00:20,  5.00it/s]
# dataloaders: 107it [00:21,  5.06it/s]
# dataloaders: 108it [00:21,  5.10it/s]
# dataloaders: 109it [00:21,  5.15it/s]
# dataloaders: 110it [00:21,  5.10it/s]
# dataloaders: 111it [00:21,  5.04it/s]
# dataloaders: 112it [00:22,  5.08it/s]
# dataloaders: 113it [00:22,  5.17it/s]
# dataloaders: 114it [00:22,  5.12it/s]
# dataloaders: 115it [00:22,  5.23it/s]
# dataloaders: 116it [00:22,  5.32it/s]
# dataloaders: 117it [00:22,  5.22it/s]
# dataloaders: 118it [00:23,  5.11it/s]
# dataloaders: 119it [00:23,  5.15it/s]
# dataloaders: 120it [00:23,  4.97it/s]
# dataloaders: 121it [00:23,  5.04it/s]
# dataloaders: 122it [00:23,  5.03it/s]
# dataloaders: 123it [00:24,  4.91it/s]
# dataloaders: 124it [00:24,  4.96it/s]
# dataloaders: 125it [00:24,  4.97it/s]
# dataloaders: 126it [00:24,  4.63it/s]
# dataloaders: 127it [00:25,  3.68it/s]
# dataloaders: 128it [00:25,  3.84it/s]
# dataloaders: 129it [00:25,  4.09it/s]
# dataloaders: 130it [00:25,  4.18it/s]
# dataloaders: 131it [00:26,  4.34it/s]
# dataloaders: 132it [00:26,  4.34it/s]
# dataloaders: 133it [00:26,  4.46it/s]
# dataloaders: 134it [00:26,  4.56it/s]
# dataloaders: 135it [00:26,  4.61it/s]
# dataloaders: 136it [00:27,  4.73it/s]
# dataloaders: 137it [00:27,  4.82it/s]
# dataloaders: 138it [00:27,  4.78it/s]
# dataloaders: 139it [00:27,  4.70it/s]
# dataloaders: 140it [00:28,  4.79it/s]
# dataloaders: 141it [00:28,  4.80it/s]
# dataloaders: 142it [00:28,  4.81it/s]
# dataloaders: 143it [00:28,  4.75it/s]
# dataloaders: 144it [00:28,  4.73it/s]
# dataloaders: 145it [00:29,  4.70it/s]
# dataloaders: 146it [00:29,  4.65it/s]
# dataloaders: 147it [00:29,  4.75it/s]
# dataloaders: 148it [00:29,  4.74it/s]
# dataloaders: 149it [00:29,  4.70it/s]
# dataloaders: 150it [00:30,  4.62it/s]
# dataloaders: 151it [00:30,  4.63it/s]
# dataloaders: 152it [00:30,  4.56it/s]
# dataloaders: 153it [00:30,  4.49it/s]
# dataloaders: 154it [00:31,  4.45it/s]
# dataloaders: 155it [00:31,  4.56it/s]
# dataloaders: 156it [00:31,  4.65it/s]
# dataloaders: 157it [00:31,  4.70it/s]
# dataloaders: 158it [00:31,  4.74it/s]
# dataloaders: 159it [00:32,  4.84it/s]
# dataloaders: 160it [00:32,  4.94it/s]
# dataloaders: 161it [00:32,  5.00it/s]
# dataloaders: 162it [00:32,  5.08it/s]
# dataloaders: 163it [00:32,  5.07it/s]
# dataloaders: 164it [00:33,  5.07it/s]
# dataloaders: 165it [00:33,  5.03it/s]
# dataloaders: 166it [00:33,  5.03it/s]
# dataloaders: 167it [00:33,  5.02it/s]
# dataloaders: 168it [00:33,  4.77it/s]
# dataloaders: 169it [00:34,  4.62it/s]
# dataloaders: 170it [00:34,  4.71it/s]
# dataloaders: 171it [00:34,  4.81it/s]
# dataloaders: 172it [00:34,  4.83it/s]
# dataloaders: 173it [00:34,  4.84it/s]
# dataloaders: 174it [00:35,  4.83it/s]
# dataloaders: 175it [00:35,  4.89it/s]
# dataloaders: 176it [00:35,  4.90it/s]
# dataloaders: 177it [00:35,  4.95it/s]
# dataloaders: 178it [00:35,  4.95it/s]
# dataloaders: 179it [00:36,  4.89it/s]
# dataloaders: 180it [00:36,  4.85it/s]
# dataloaders: 181it [00:36,  4.87it/s]
# dataloaders: 182it [00:36,  4.86it/s]
# dataloaders: 183it [00:36,  4.90it/s]
# dataloaders: 184it [00:37,  4.90it/s]
# dataloaders: 185it [00:37,  4.93it/s]
# dataloaders: 186it [00:37,  4.95it/s]
# epoch:  10%|█         | 2/20 [01:15<11:16, 37.56s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.44it/s]
# dataloaders: 2it [00:00,  4.74it/s]
# dataloaders: 3it [00:00,  4.80it/s]
# dataloaders: 4it [00:00,  4.83it/s]
# dataloaders: 5it [00:01,  4.86it/s]
# dataloaders: 6it [00:01,  4.85it/s]
# dataloaders: 7it [00:01,  4.80it/s]
# dataloaders: 8it [00:01,  4.88it/s]
# dataloaders: 9it [00:01,  4.92it/s]
# dataloaders: 10it [00:02,  4.99it/s]
# dataloaders: 11it [00:02,  5.05it/s]
# dataloaders: 12it [00:02,  5.00it/s]
# dataloaders: 13it [00:02,  4.97it/s]
# dataloaders: 14it [00:02,  4.83it/s]
# dataloaders: 15it [00:03,  4.87it/s]
# dataloaders: 16it [00:03,  4.88it/s]
# dataloaders: 17it [00:03,  4.93it/s]
# dataloaders: 18it [00:03,  4.95it/s]
# dataloaders: 19it [00:03,  5.03it/s]
# dataloaders: 20it [00:04,  5.04it/s]
# dataloaders: 21it [00:04,  5.04it/s]
# dataloaders: 22it [00:04,  5.07it/s]
# dataloaders: 23it [00:04,  5.09it/s]
# dataloaders: 24it [00:04,  5.13it/s]
# dataloaders: 25it [00:05,  5.10it/s]
# dataloaders: 26it [00:05,  5.07it/s]
# dataloaders: 27it [00:05,  5.02it/s]
# dataloaders: 28it [00:05,  5.00it/s]
# dataloaders: 29it [00:05,  4.97it/s]
# dataloaders: 30it [00:06,  4.50it/s]
# dataloaders: 31it [00:06,  4.53it/s]
# dataloaders: 32it [00:06,  4.26it/s]
# dataloaders: 33it [00:06,  4.38it/s]
# dataloaders: 34it [00:07,  4.43it/s]
# dataloaders: 35it [00:07,  4.37it/s]
# dataloaders: 36it [00:07,  3.44it/s]
# dataloaders: 37it [00:07,  3.70it/s]
# dataloaders: 38it [00:08,  3.86it/s]
# dataloaders: 39it [00:08,  4.06it/s]
# dataloaders: 40it [00:08,  4.25it/s]
# dataloaders: 41it [00:08,  4.41it/s]
# dataloaders: 42it [00:09,  4.48it/s]
# dataloaders: 43it [00:09,  4.49it/s]
# dataloaders: 44it [00:09,  4.54it/s]
# dataloaders: 45it [00:09,  4.29it/s]
# dataloaders: 46it [00:09,  4.31it/s]
# dataloaders: 47it [00:10,  4.43it/s]
# dataloaders: 48it [00:10,  4.46it/s]
# dataloaders: 49it [00:10,  4.60it/s]
# dataloaders: 50it [00:10,  4.69it/s]
# dataloaders: 51it [00:10,  4.72it/s]
# dataloaders: 52it [00:11,  4.79it/s]
# dataloaders: 53it [00:11,  4.82it/s]
# dataloaders: 54it [00:11,  4.84it/s]
# dataloaders: 55it [00:11,  4.85it/s]
# dataloaders: 56it [00:12,  4.69it/s]
# dataloaders: 57it [00:12,  4.62it/s]
# dataloaders: 58it [00:12,  4.69it/s]
# dataloaders: 59it [00:12,  4.68it/s]
# dataloaders: 60it [00:12,  4.85it/s]
# dataloaders: 61it [00:13,  4.92it/s]
# dataloaders: 62it [00:13,  4.90it/s]
# dataloaders: 63it [00:13,  4.90it/s]
# dataloaders: 64it [00:13,  4.85it/s]
# dataloaders: 65it [00:13,  4.80it/s]
# dataloaders: 66it [00:14,  4.84it/s]
# dataloaders: 67it [00:14,  4.76it/s]
# dataloaders: 68it [00:14,  4.83it/s]
# dataloaders: 69it [00:14,  4.89it/s]
# dataloaders: 70it [00:14,  4.91it/s]
# dataloaders: 71it [00:15,  4.91it/s]
# dataloaders: 72it [00:15,  4.95it/s]
# dataloaders: 73it [00:15,  4.88it/s]
# dataloaders: 74it [00:15,  4.88it/s]
# dataloaders: 75it [00:15,  4.93it/s]
# dataloaders: 76it [00:16,  4.86it/s]
# dataloaders: 77it [00:16,  4.96it/s]
# dataloaders: 78it [00:16,  5.06it/s]
# dataloaders: 79it [00:16,  5.19it/s]
# dataloaders: 80it [00:16,  5.19it/s]
# dataloaders: 81it [00:17,  5.27it/s]
# dataloaders: 82it [00:17,  5.33it/s]
# dataloaders: 83it [00:17,  5.32it/s]
# dataloaders: 84it [00:17,  5.25it/s]
# dataloaders: 85it [00:17,  5.15it/s]
# dataloaders: 86it [00:18,  5.06it/s]
# dataloaders: 87it [00:18,  5.12it/s]
# dataloaders: 88it [00:18,  5.21it/s]
# dataloaders: 89it [00:18,  5.29it/s]
# dataloaders: 90it [00:18,  5.31it/s]
# dataloaders: 91it [00:18,  5.37it/s]
# dataloaders: 92it [00:19,  5.30it/s]
# dataloaders: 93it [00:19,  4.98it/s]
# dataloaders: 94it [00:19,  4.96it/s]
# dataloaders: 95it [00:19,  4.90it/s]
# dataloaders: 96it [00:20,  4.92it/s]
# dataloaders: 97it [00:20,  4.91it/s]
# dataloaders: 98it [00:20,  4.89it/s]
# dataloaders: 99it [00:20,  4.81it/s]
# dataloaders: 100it [00:20,  4.86it/s]
# dataloaders: 101it [00:21,  4.82it/s]
# dataloaders: 102it [00:21,  4.71it/s]
# dataloaders: 103it [00:21,  4.79it/s]
# dataloaders: 104it [00:21,  4.62it/s]
# dataloaders: 105it [00:21,  4.63it/s]
# dataloaders: 106it [00:22,  4.61it/s]
# dataloaders: 107it [00:22,  4.66it/s]
# dataloaders: 108it [00:22,  4.67it/s]
# dataloaders: 109it [00:22,  4.63it/s]
# dataloaders: 110it [00:23,  4.50it/s]
# dataloaders: 111it [00:23,  4.41it/s]
# dataloaders: 112it [00:23,  4.46it/s]
# dataloaders: 113it [00:23,  4.49it/s]
# dataloaders: 114it [00:23,  4.55it/s]
# dataloaders: 115it [00:24,  4.65it/s]
# dataloaders: 116it [00:24,  4.72it/s]
# dataloaders: 117it [00:24,  4.68it/s]
# dataloaders: 118it [00:24,  4.63it/s]
# dataloaders: 119it [00:24,  4.69it/s]
# dataloaders: 120it [00:25,  4.71it/s]
# dataloaders: 121it [00:25,  4.71it/s]
# dataloaders: 122it [00:25,  4.80it/s]
# dataloaders: 123it [00:25,  4.87it/s]
# dataloaders: 124it [00:25,  4.94it/s]
# dataloaders: 125it [00:26,  4.78it/s]
# dataloaders: 126it [00:26,  4.82it/s]
# dataloaders: 127it [00:26,  4.87it/s]
# dataloaders: 128it [00:26,  4.86it/s]
# dataloaders: 129it [00:27,  4.77it/s]
# dataloaders: 130it [00:27,  4.76it/s]
# dataloaders: 131it [00:27,  4.70it/s]
# dataloaders: 132it [00:27,  4.81it/s]
# dataloaders: 133it [00:27,  4.37it/s]
# dataloaders: 134it [00:28,  4.42it/s]
# dataloaders: 135it [00:28,  4.51it/s]
# dataloaders: 136it [00:28,  4.57it/s]
# dataloaders: 137it [00:28,  4.66it/s]
# dataloaders: 138it [00:29,  4.71it/s]
# dataloaders: 139it [00:29,  4.79it/s]
# dataloaders: 140it [00:29,  4.75it/s]
# dataloaders: 141it [00:29,  4.78it/s]
# dataloaders: 142it [00:29,  4.85it/s]
# dataloaders: 143it [00:30,  4.85it/s]
# dataloaders: 144it [00:30,  4.82it/s]
# dataloaders: 145it [00:30,  4.84it/s]
# dataloaders: 146it [00:30,  4.85it/s]
# dataloaders: 147it [00:30,  4.33it/s]
# dataloaders: 148it [00:31,  4.41it/s]
# dataloaders: 149it [00:31,  4.41it/s]
# dataloaders: 150it [00:31,  4.55it/s]
# dataloaders: 151it [00:31,  4.65it/s]
# dataloaders: 152it [00:32,  4.68it/s]
# dataloaders: 153it [00:32,  4.78it/s]
# dataloaders: 154it [00:32,  4.81it/s]
# dataloaders: 155it [00:32,  4.85it/s]
# dataloaders: 156it [00:32,  4.78it/s]
# dataloaders: 157it [00:33,  4.80it/s]
# dataloaders: 158it [00:33,  4.90it/s]
# dataloaders: 159it [00:33,  4.93it/s]
# dataloaders: 160it [00:33,  4.97it/s]
# dataloaders: 161it [00:33,  4.99it/s]
# dataloaders: 162it [00:34,  5.00it/s]
# dataloaders: 163it [00:34,  4.93it/s]
# dataloaders: 164it [00:34,  4.93it/s]
# dataloaders: 165it [00:34,  4.67it/s]
# dataloaders: 166it [00:34,  4.72it/s]
# dataloaders: 167it [00:35,  4.69it/s]
# dataloaders: 168it [00:35,  4.63it/s]
# dataloaders: 169it [00:35,  4.60it/s]
# dataloaders: 170it [00:35,  4.66it/s]
# dataloaders: 171it [00:35,  4.78it/s]
# dataloaders: 172it [00:36,  4.83it/s]
# dataloaders: 173it [00:36,  4.85it/s]
# dataloaders: 174it [00:36,  4.91it/s]
# dataloaders: 175it [00:36,  4.96it/s]
# dataloaders: 176it [00:36,  4.79it/s]
# dataloaders: 177it [00:37,  4.82it/s]
# dataloaders: 178it [00:37,  4.83it/s]
# dataloaders: 179it [00:37,  4.90it/s]
# dataloaders: 180it [00:37,  4.77it/s]
# dataloaders: 181it [00:38,  4.65it/s]
# dataloaders: 182it [00:38,  4.65it/s]
# dataloaders: 183it [00:38,  4.63it/s]
# dataloaders: 184it [00:38,  4.65it/s]
# dataloaders: 185it [00:38,  4.60it/s]
# dataloaders: 186it [00:39,  4.76it/s]
# epoch:  15%|█▌        | 3/20 [01:54<10:52, 38.40s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  3.62it/s]
# dataloaders: 2it [00:00,  4.33it/s]
# dataloaders: 3it [00:00,  4.55it/s]
# dataloaders: 4it [00:00,  4.48it/s]
# dataloaders: 5it [00:01,  4.36it/s]
# dataloaders: 6it [00:01,  4.43it/s]
# dataloaders: 7it [00:01,  4.12it/s]
# dataloaders: 8it [00:01,  4.25it/s]
# dataloaders: 9it [00:02,  4.28it/s]
# dataloaders: 10it [00:02,  4.30it/s]
# dataloaders: 11it [00:02,  4.43it/s]
# dataloaders: 12it [00:02,  4.59it/s]
# dataloaders: 13it [00:02,  4.59it/s]
# dataloaders: 14it [00:03,  4.68it/s]
# dataloaders: 15it [00:03,  4.70it/s]
# dataloaders: 16it [00:03,  4.72it/s]
# dataloaders: 17it [00:03,  4.76it/s]
# dataloaders: 18it [00:03,  4.79it/s]
# dataloaders: 19it [00:04,  4.75it/s]
# dataloaders: 20it [00:04,  4.75it/s]
# dataloaders: 21it [00:04,  4.78it/s]
# dataloaders: 22it [00:04,  4.79it/s]
# dataloaders: 23it [00:05,  4.84it/s]
# dataloaders: 24it [00:05,  4.92it/s]
# dataloaders: 25it [00:05,  3.75it/s]
# dataloaders: 26it [00:05,  4.02it/s]
# dataloaders: 27it [00:06,  4.21it/s]
# dataloaders: 28it [00:06,  3.96it/s]
# dataloaders: 29it [00:06,  4.10it/s]
# dataloaders: 30it [00:06,  4.33it/s]
# dataloaders: 31it [00:06,  4.49it/s]
# dataloaders: 32it [00:07,  4.62it/s]
# dataloaders: 33it [00:07,  4.70it/s]
# dataloaders: 34it [00:07,  4.74it/s]
# dataloaders: 35it [00:07,  4.67it/s]
# dataloaders: 36it [00:08,  4.64it/s]
# dataloaders: 37it [00:08,  4.64it/s]
# dataloaders: 38it [00:08,  4.52it/s]
# dataloaders: 39it [00:08,  4.57it/s]
# dataloaders: 40it [00:08,  4.62it/s]
# dataloaders: 41it [00:09,  4.33it/s]
# dataloaders: 42it [00:09,  4.44it/s]
# dataloaders: 43it [00:09,  4.61it/s]
# dataloaders: 44it [00:09,  4.74it/s]
# dataloaders: 45it [00:09,  4.79it/s]
# dataloaders: 46it [00:10,  4.86it/s]
# dataloaders: 47it [00:10,  4.90it/s]
# dataloaders: 48it [00:10,  4.50it/s]
# dataloaders: 49it [00:10,  4.51it/s]
# dataloaders: 50it [00:11,  4.51it/s]
# dataloaders: 51it [00:11,  4.56it/s]
# dataloaders: 52it [00:11,  4.57it/s]
# dataloaders: 53it [00:11,  4.64it/s]
# dataloaders: 54it [00:11,  4.78it/s]
# dataloaders: 55it [00:12,  4.83it/s]
# dataloaders: 56it [00:12,  4.71it/s]
# dataloaders: 57it [00:12,  4.13it/s]
# dataloaders: 58it [00:12,  4.40it/s]
# dataloaders: 59it [00:13,  4.62it/s]
# dataloaders: 60it [00:13,  4.56it/s]
# dataloaders: 61it [00:13,  4.64it/s]
# dataloaders: 62it [00:13,  4.77it/s]
# dataloaders: 63it [00:13,  4.90it/s]
# dataloaders: 64it [00:14,  4.99it/s]
# dataloaders: 65it [00:14,  4.93it/s]
# dataloaders: 66it [00:14,  4.88it/s]
# dataloaders: 67it [00:14,  4.84it/s]
# dataloaders: 68it [00:14,  4.92it/s]
# dataloaders: 69it [00:15,  4.91it/s]
# dataloaders: 70it [00:15,  4.86it/s]
# dataloaders: 71it [00:15,  4.84it/s]
# dataloaders: 72it [00:15,  4.79it/s]
# dataloaders: 73it [00:15,  4.72it/s]
# dataloaders: 74it [00:16,  4.74it/s]
# dataloaders: 75it [00:16,  4.78it/s]
# dataloaders: 76it [00:16,  4.76it/s]
# dataloaders: 77it [00:16,  4.89it/s]
# dataloaders: 78it [00:16,  4.87it/s]
# dataloaders: 79it [00:17,  4.93it/s]
# dataloaders: 80it [00:17,  4.94it/s]
# dataloaders: 81it [00:17,  4.88it/s]
# dataloaders: 82it [00:17,  4.93it/s]
# dataloaders: 83it [00:17,  4.97it/s]
# dataloaders: 84it [00:18,  5.05it/s]
# dataloaders: 85it [00:18,  5.12it/s]
# dataloaders: 86it [00:18,  5.12it/s]
# dataloaders: 87it [00:18,  5.09it/s]
# dataloaders: 88it [00:18,  5.13it/s]
# dataloaders: 89it [00:19,  5.11it/s]
# dataloaders: 90it [00:19,  5.16it/s]
# dataloaders: 91it [00:19,  5.25it/s]
# dataloaders: 92it [00:19,  5.31it/s]
# dataloaders: 93it [00:19,  5.31it/s]
# dataloaders: 94it [00:20,  5.25it/s]
# dataloaders: 95it [00:20,  5.27it/s]
# dataloaders: 96it [00:20,  5.10it/s]
# dataloaders: 97it [00:20,  5.07it/s]
# dataloaders: 98it [00:20,  5.11it/s]
# dataloaders: 99it [00:21,  5.11it/s]
# dataloaders: 100it [00:21,  4.18it/s]
# dataloaders: 101it [00:21,  4.50it/s]
# dataloaders: 102it [00:21,  4.68it/s]
# dataloaders: 103it [00:21,  4.76it/s]
# dataloaders: 104it [00:22,  4.95it/s]
# dataloaders: 105it [00:22,  4.95it/s]
# dataloaders: 106it [00:22,  5.06it/s]
# dataloaders: 107it [00:22,  5.04it/s]
# dataloaders: 108it [00:22,  5.11it/s]
# dataloaders: 109it [00:23,  5.17it/s]
# dataloaders: 110it [00:23,  5.20it/s]
# dataloaders: 111it [00:23,  5.24it/s]
# dataloaders: 112it [00:23,  5.24it/s]
# dataloaders: 113it [00:23,  5.31it/s]
# dataloaders: 114it [00:24,  5.31it/s]
# dataloaders: 115it [00:24,  5.35it/s]
# dataloaders: 116it [00:24,  5.38it/s]
# dataloaders: 117it [00:24,  5.36it/s]
# dataloaders: 118it [00:24,  5.34it/s]
# dataloaders: 119it [00:24,  5.28it/s]
# dataloaders: 120it [00:25,  5.27it/s]
# dataloaders: 121it [00:25,  5.17it/s]
# dataloaders: 122it [00:25,  5.22it/s]
# dataloaders: 123it [00:25,  5.29it/s]
# dataloaders: 124it [00:25,  5.34it/s]
# dataloaders: 125it [00:26,  5.22it/s]
# dataloaders: 126it [00:26,  5.29it/s]
# dataloaders: 127it [00:26,  5.29it/s]
# dataloaders: 128it [00:26,  5.32it/s]
# dataloaders: 129it [00:26,  5.29it/s]
# dataloaders: 130it [00:27,  5.26it/s]
# dataloaders: 131it [00:27,  5.13it/s]
# dataloaders: 132it [00:27,  5.12it/s]
# dataloaders: 133it [00:27,  5.14it/s]
# dataloaders: 134it [00:27,  5.07it/s]
# dataloaders: 135it [00:28,  5.00it/s]
# dataloaders: 136it [00:28,  4.79it/s]
# dataloaders: 137it [00:28,  4.76it/s]
# dataloaders: 138it [00:28,  4.79it/s]
# dataloaders: 139it [00:28,  4.82it/s]
# dataloaders: 140it [00:29,  4.63it/s]
# dataloaders: 141it [00:29,  4.77it/s]
# dataloaders: 142it [00:29,  4.96it/s]
# dataloaders: 143it [00:29,  5.05it/s]
# dataloaders: 144it [00:29,  5.16it/s]
# dataloaders: 145it [00:30,  4.93it/s]
# dataloaders: 146it [00:30,  4.87it/s]
# dataloaders: 147it [00:30,  4.84it/s]
# dataloaders: 148it [00:30,  4.69it/s]
# dataloaders: 149it [00:31,  4.65it/s]
# dataloaders: 150it [00:31,  4.68it/s]
# dataloaders: 151it [00:31,  4.57it/s]
# dataloaders: 152it [00:31,  4.46it/s]
# dataloaders: 153it [00:31,  4.48it/s]
# dataloaders: 154it [00:32,  4.57it/s]
# dataloaders: 155it [00:32,  4.71it/s]
# dataloaders: 156it [00:32,  4.59it/s]
# dataloaders: 157it [00:32,  4.53it/s]
# dataloaders: 158it [00:33,  4.53it/s]
# dataloaders: 159it [00:33,  4.65it/s]
# dataloaders: 160it [00:33,  4.34it/s]
# dataloaders: 161it [00:33,  4.26it/s]
# dataloaders: 162it [00:33,  4.33it/s]
# dataloaders: 163it [00:34,  4.26it/s]
# dataloaders: 164it [00:34,  4.35it/s]
# dataloaders: 165it [00:34,  4.44it/s]
# dataloaders: 166it [00:34,  4.55it/s]
# dataloaders: 167it [00:35,  4.63it/s]
# dataloaders: 168it [00:35,  4.72it/s]
# dataloaders: 169it [00:35,  4.81it/s]
# dataloaders: 170it [00:35,  4.62it/s]
# dataloaders: 171it [00:35,  4.47it/s]
# dataloaders: 172it [00:36,  4.64it/s]
# dataloaders: 173it [00:36,  4.76it/s]
# dataloaders: 174it [00:36,  4.65it/s]
# dataloaders: 175it [00:36,  4.70it/s]
# dataloaders: 176it [00:36,  4.55it/s]
# dataloaders: 177it [00:37,  4.64it/s]
# dataloaders: 178it [00:37,  4.66it/s]
# dataloaders: 179it [00:37,  4.35it/s]
# dataloaders: 180it [00:37,  4.58it/s]
# dataloaders: 181it [00:38,  3.55it/s]
# dataloaders: 182it [00:38,  3.73it/s]
# dataloaders: 183it [00:38,  3.97it/s]
# dataloaders: 184it [00:38,  4.23it/s]
# dataloaders: 185it [00:39,  3.82it/s]
# dataloaders: 186it [00:39,  4.71it/s]
# epoch:  20%|██        | 4/20 [02:34<10:22, 38.91s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.84it/s]
# dataloaders: 2it [00:00,  5.16it/s]
# dataloaders: 3it [00:00,  5.26it/s]
# dataloaders: 4it [00:00,  5.21it/s]
# dataloaders: 5it [00:00,  5.26it/s]
# dataloaders: 6it [00:01,  5.35it/s]
# dataloaders: 7it [00:01,  5.40it/s]
# dataloaders: 8it [00:01,  5.42it/s]
# dataloaders: 9it [00:01,  5.43it/s]
# dataloaders: 10it [00:01,  5.43it/s]
# dataloaders: 11it [00:02,  5.35it/s]
# dataloaders: 12it [00:02,  5.35it/s]
# dataloaders: 13it [00:02,  5.36it/s]
# dataloaders: 14it [00:02,  5.39it/s]
# dataloaders: 15it [00:02,  5.39it/s]
# dataloaders: 16it [00:03,  5.31it/s]
# dataloaders: 17it [00:03,  5.19it/s]
# dataloaders: 18it [00:03,  5.25it/s]
# dataloaders: 19it [00:03,  5.31it/s]
# dataloaders: 20it [00:03,  5.34it/s]
# dataloaders: 21it [00:03,  5.31it/s]
# dataloaders: 22it [00:04,  5.30it/s]
# dataloaders: 23it [00:04,  5.13it/s]
# dataloaders: 24it [00:04,  5.07it/s]
# dataloaders: 25it [00:04,  5.00it/s]
# dataloaders: 26it [00:04,  5.12it/s]
# dataloaders: 27it [00:05,  5.16it/s]
# dataloaders: 28it [00:05,  5.14it/s]
# dataloaders: 29it [00:05,  5.19it/s]
# dataloaders: 30it [00:05,  5.28it/s]
# dataloaders: 31it [00:05,  5.05it/s]
# dataloaders: 32it [00:06,  5.11it/s]
# dataloaders: 33it [00:06,  5.06it/s]
# dataloaders: 34it [00:06,  4.99it/s]
# dataloaders: 35it [00:06,  4.85it/s]
# dataloaders: 36it [00:06,  4.81it/s]
# dataloaders: 37it [00:07,  4.55it/s]
# dataloaders: 38it [00:07,  4.49it/s]
# dataloaders: 39it [00:07,  4.40it/s]
# dataloaders: 40it [00:07,  4.40it/s]
# dataloaders: 41it [00:08,  4.54it/s]
# dataloaders: 42it [00:08,  4.68it/s]
# dataloaders: 43it [00:08,  4.73it/s]
# dataloaders: 44it [00:08,  4.82it/s]
# dataloaders: 45it [00:08,  4.77it/s]
# dataloaders: 46it [00:09,  4.71it/s]
# dataloaders: 47it [00:09,  4.72it/s]
# dataloaders: 48it [00:09,  4.67it/s]
# dataloaders: 49it [00:09,  4.59it/s]
# dataloaders: 50it [00:10,  4.48it/s]
# dataloaders: 51it [00:10,  4.41it/s]
# dataloaders: 52it [00:10,  4.15it/s]
# dataloaders: 53it [00:10,  4.43it/s]
# dataloaders: 54it [00:10,  4.67it/s]
# dataloaders: 55it [00:11,  4.89it/s]
# dataloaders: 56it [00:11,  4.62it/s]
# dataloaders: 57it [00:11,  4.75it/s]
# dataloaders: 58it [00:11,  4.86it/s]
# dataloaders: 59it [00:11,  4.73it/s]
# dataloaders: 60it [00:12,  4.70it/s]
# dataloaders: 61it [00:12,  4.70it/s]
# dataloaders: 62it [00:12,  4.72it/s]
# dataloaders: 63it [00:12,  4.67it/s]
# dataloaders: 64it [00:13,  4.70it/s]
# dataloaders: 65it [00:13,  4.65it/s]
# dataloaders: 66it [00:13,  4.69it/s]
# dataloaders: 67it [00:13,  4.76it/s]
# dataloaders: 68it [00:13,  4.30it/s]
# dataloaders: 69it [00:14,  4.29it/s]
# dataloaders: 70it [00:14,  4.22it/s]
# dataloaders: 71it [00:14,  4.27it/s]
# dataloaders: 72it [00:14,  4.24it/s]
# dataloaders: 73it [00:15,  3.84it/s]
# dataloaders: 74it [00:15,  3.76it/s]
# dataloaders: 75it [00:15,  3.49it/s]
# dataloaders: 76it [00:16,  3.81it/s]
# dataloaders: 77it [00:16,  4.15it/s]
# dataloaders: 78it [00:16,  4.29it/s]
# dataloaders: 79it [00:16,  4.35it/s]
# dataloaders: 80it [00:16,  4.40it/s]
# dataloaders: 81it [00:17,  4.41it/s]
# dataloaders: 82it [00:17,  4.45it/s]
# dataloaders: 83it [00:17,  4.53it/s]
# dataloaders: 84it [00:17,  4.60it/s]
# dataloaders: 85it [00:17,  4.64it/s]
# dataloaders: 86it [00:18,  4.80it/s]
# dataloaders: 87it [00:18,  4.33it/s]
# dataloaders: 88it [00:18,  3.97it/s]
# dataloaders: 89it [00:19,  3.76it/s]
# dataloaders: 90it [00:19,  3.83it/s]
# dataloaders: 91it [00:19,  4.11it/s]
# dataloaders: 92it [00:19,  4.15it/s]
# dataloaders: 93it [00:19,  4.35it/s]
# dataloaders: 94it [00:20,  4.39it/s]
# dataloaders: 95it [00:20,  4.52it/s]
# dataloaders: 96it [00:20,  4.72it/s]
# dataloaders: 97it [00:20,  4.81it/s]
# dataloaders: 98it [00:20,  4.96it/s]
# dataloaders: 99it [00:21,  4.91it/s]
# dataloaders: 100it [00:21,  4.98it/s]
# dataloaders: 101it [00:21,  5.09it/s]
# dataloaders: 102it [00:21,  5.03it/s]
# dataloaders: 103it [00:21,  5.08it/s]
# dataloaders: 104it [00:22,  4.97it/s]
# dataloaders: 105it [00:22,  4.88it/s]
# dataloaders: 106it [00:22,  4.81it/s]
# dataloaders: 107it [00:22,  4.64it/s]
# dataloaders: 108it [00:22,  4.67it/s]
# dataloaders: 109it [00:23,  4.75it/s]
# dataloaders: 110it [00:23,  4.84it/s]
# dataloaders: 111it [00:23,  4.80it/s]
# dataloaders: 112it [00:23,  4.89it/s]
# dataloaders: 113it [00:24,  4.69it/s]
# dataloaders: 114it [00:24,  4.58it/s]
# dataloaders: 115it [00:24,  4.65it/s]
# dataloaders: 116it [00:24,  4.82it/s]
# dataloaders: 117it [00:24,  4.85it/s]
# dataloaders: 118it [00:25,  4.93it/s]
# dataloaders: 119it [00:25,  4.86it/s]
# dataloaders: 120it [00:25,  4.95it/s]
# dataloaders: 121it [00:25,  5.01it/s]
# dataloaders: 122it [00:25,  4.89it/s]
# dataloaders: 123it [00:26,  5.07it/s]
# dataloaders: 124it [00:26,  5.18it/s]
# dataloaders: 125it [00:26,  5.31it/s]
# dataloaders: 126it [00:26,  5.40it/s]
# dataloaders: 127it [00:26,  5.43it/s]
# dataloaders: 128it [00:26,  5.34it/s]
# dataloaders: 129it [00:27,  5.20it/s]
# dataloaders: 130it [00:27,  5.12it/s]
# dataloaders: 131it [00:27,  4.93it/s]
# dataloaders: 132it [00:27,  4.72it/s]
# dataloaders: 133it [00:28,  4.11it/s]
# dataloaders: 134it [00:28,  4.24it/s]
# dataloaders: 135it [00:28,  4.28it/s]
# dataloaders: 136it [00:28,  4.27it/s]
# dataloaders: 137it [00:29,  4.16it/s]
# dataloaders: 138it [00:29,  4.28it/s]
# dataloaders: 139it [00:29,  4.53it/s]
# dataloaders: 140it [00:29,  4.70it/s]
# dataloaders: 141it [00:29,  4.83it/s]
# dataloaders: 142it [00:30,  4.95it/s]
# dataloaders: 143it [00:30,  4.94it/s]
# dataloaders: 144it [00:30,  4.90it/s]
# dataloaders: 145it [00:30,  4.94it/s]
# dataloaders: 146it [00:30,  5.03it/s]
# dataloaders: 147it [00:31,  5.00it/s]
# dataloaders: 148it [00:31,  5.00it/s]
# dataloaders: 149it [00:31,  5.11it/s]
# dataloaders: 150it [00:31,  5.20it/s]
# dataloaders: 151it [00:31,  5.14it/s]
# dataloaders: 152it [00:32,  5.05it/s]
# dataloaders: 153it [00:32,  5.03it/s]
# dataloaders: 154it [00:32,  4.90it/s]
# dataloaders: 155it [00:32,  4.94it/s]
# dataloaders: 156it [00:32,  4.99it/s]
# dataloaders: 157it [00:33,  5.09it/s]
# dataloaders: 158it [00:33,  5.18it/s]
# dataloaders: 159it [00:33,  5.12it/s]
# dataloaders: 160it [00:33,  5.14it/s]
# dataloaders: 161it [00:33,  5.05it/s]
# dataloaders: 162it [00:34,  4.96it/s]
# dataloaders: 163it [00:34,  4.81it/s]
# dataloaders: 164it [00:34,  4.94it/s]
# dataloaders: 165it [00:34,  5.04it/s]
# dataloaders: 166it [00:34,  5.10it/s]
# dataloaders: 167it [00:35,  5.17it/s]
# dataloaders: 168it [00:35,  5.19it/s]
# dataloaders: 169it [00:35,  5.27it/s]
# dataloaders: 170it [00:35,  5.19it/s]
# dataloaders: 171it [00:35,  5.17it/s]
# dataloaders: 172it [00:35,  5.07it/s]
# dataloaders: 173it [00:36,  5.05it/s]
# dataloaders: 174it [00:36,  5.13it/s]
# dataloaders: 175it [00:36,  5.14it/s]
# dataloaders: 176it [00:36,  5.17it/s]
# dataloaders: 177it [00:36,  5.29it/s]
# dataloaders: 178it [00:37,  5.15it/s]
# dataloaders: 179it [00:37,  5.08it/s]
# dataloaders: 180it [00:37,  5.09it/s]
# dataloaders: 181it [00:37,  5.17it/s]
# dataloaders: 182it [00:37,  5.25it/s]
# dataloaders: 183it [00:38,  5.37it/s]
# dataloaders: 184it [00:38,  5.39it/s]
# dataloaders: 185it [00:38,  5.26it/s]
# dataloaders: 186it [00:38,  4.81it/s]
# epoch:  25%|██▌       | 5/20 [03:13<09:43, 38.93s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.03it/s]
# dataloaders: 2it [00:00,  4.16it/s]
# dataloaders: 3it [00:00,  4.44it/s]
# dataloaders: 4it [00:00,  4.55it/s]
# dataloaders: 5it [00:01,  4.69it/s]
# dataloaders: 6it [00:01,  4.72it/s]
# dataloaders: 7it [00:01,  4.77it/s]
# dataloaders: 8it [00:01,  4.79it/s]
# dataloaders: 9it [00:01,  4.79it/s]
# dataloaders: 10it [00:02,  4.68it/s]
# dataloaders: 11it [00:02,  4.69it/s]
# dataloaders: 12it [00:02,  4.78it/s]
# dataloaders: 13it [00:02,  4.77it/s]
# dataloaders: 14it [00:02,  4.83it/s]
# dataloaders: 15it [00:03,  4.92it/s]
# dataloaders: 16it [00:03,  5.00it/s]
# dataloaders: 17it [00:03,  5.12it/s]
# dataloaders: 18it [00:03,  5.28it/s]
# dataloaders: 19it [00:03,  5.41it/s]
# dataloaders: 20it [00:04,  5.52it/s]
# dataloaders: 21it [00:04,  5.56it/s]
# dataloaders: 22it [00:04,  5.61it/s]
# dataloaders: 23it [00:04,  5.61it/s]
# dataloaders: 24it [00:04,  5.59it/s]
# dataloaders: 25it [00:04,  5.46it/s]
# dataloaders: 26it [00:05,  5.51it/s]
# dataloaders: 27it [00:05,  5.42it/s]
# dataloaders: 28it [00:05,  5.40it/s]
# dataloaders: 29it [00:05,  5.38it/s]
# dataloaders: 30it [00:05,  5.28it/s]
# dataloaders: 31it [00:06,  5.22it/s]
# dataloaders: 32it [00:06,  5.15it/s]
# dataloaders: 33it [00:06,  5.17it/s]
# dataloaders: 34it [00:06,  5.17it/s]
# dataloaders: 35it [00:06,  5.16it/s]
# dataloaders: 36it [00:07,  5.28it/s]
# dataloaders: 37it [00:07,  5.16it/s]
# dataloaders: 38it [00:07,  5.13it/s]
# dataloaders: 39it [00:07,  5.14it/s]
# dataloaders: 40it [00:07,  5.11it/s]
# dataloaders: 41it [00:08,  5.12it/s]
# dataloaders: 42it [00:08,  5.17it/s]
# dataloaders: 43it [00:08,  5.17it/s]
# dataloaders: 44it [00:08,  5.05it/s]
# dataloaders: 45it [00:08,  5.12it/s]
# dataloaders: 46it [00:09,  5.04it/s]
# dataloaders: 47it [00:09,  4.98it/s]
# dataloaders: 48it [00:09,  4.79it/s]
# dataloaders: 49it [00:09,  4.90it/s]
# dataloaders: 50it [00:09,  5.02it/s]
# dataloaders: 51it [00:10,  4.99it/s]
# dataloaders: 52it [00:10,  4.97it/s]
# dataloaders: 53it [00:10,  4.98it/s]
# dataloaders: 54it [00:10,  5.00it/s]
# dataloaders: 55it [00:10,  5.06it/s]
# dataloaders: 56it [00:11,  5.14it/s]
# dataloaders: 57it [00:11,  5.19it/s]
# dataloaders: 58it [00:11,  5.02it/s]
# dataloaders: 59it [00:11,  5.08it/s]
# dataloaders: 60it [00:11,  5.13it/s]
# dataloaders: 61it [00:12,  5.14it/s]
# dataloaders: 62it [00:12,  5.18it/s]
# dataloaders: 63it [00:12,  5.15it/s]
# dataloaders: 64it [00:12,  5.24it/s]
# dataloaders: 65it [00:12,  5.29it/s]
# dataloaders: 66it [00:12,  5.29it/s]
# dataloaders: 67it [00:13,  5.34it/s]
# dataloaders: 68it [00:13,  5.29it/s]
# dataloaders: 69it [00:13,  5.21it/s]
# dataloaders: 70it [00:13,  5.24it/s]
# dataloaders: 71it [00:13,  5.30it/s]
# dataloaders: 72it [00:14,  5.30it/s]
# dataloaders: 73it [00:14,  5.33it/s]
# dataloaders: 74it [00:14,  5.31it/s]
# dataloaders: 75it [00:14,  5.27it/s]
# dataloaders: 76it [00:14,  5.28it/s]
# dataloaders: 77it [00:15,  5.31it/s]
# dataloaders: 78it [00:15,  5.35it/s]
# dataloaders: 79it [00:15,  5.39it/s]
# dataloaders: 80it [00:15,  5.27it/s]
# dataloaders: 81it [00:15,  5.13it/s]
# dataloaders: 82it [00:16,  5.14it/s]
# dataloaders: 83it [00:16,  5.12it/s]
# dataloaders: 84it [00:16,  5.03it/s]
# dataloaders: 85it [00:16,  5.01it/s]
# dataloaders: 86it [00:16,  5.02it/s]
# dataloaders: 87it [00:17,  5.05it/s]
# dataloaders: 88it [00:17,  4.90it/s]
# dataloaders: 89it [00:17,  4.89it/s]
# dataloaders: 90it [00:17,  4.81it/s]
# dataloaders: 91it [00:17,  4.62it/s]
# dataloaders: 92it [00:18,  4.48it/s]
# dataloaders: 93it [00:18,  4.48it/s]
# dataloaders: 94it [00:18,  4.32it/s]
# dataloaders: 95it [00:18,  4.32it/s]
# dataloaders: 96it [00:19,  4.16it/s]
# dataloaders: 97it [00:19,  4.26it/s]
# dataloaders: 98it [00:19,  4.37it/s]
# dataloaders: 99it [00:19,  4.41it/s]
# dataloaders: 100it [00:20,  3.95it/s]
# dataloaders: 101it [00:20,  4.15it/s]
# dataloaders: 102it [00:20,  4.40it/s]
# dataloaders: 103it [00:20,  4.65it/s]
# dataloaders: 104it [00:20,  4.65it/s]
# dataloaders: 105it [00:21,  4.79it/s]
# dataloaders: 106it [00:21,  4.90it/s]
# dataloaders: 107it [00:21,  5.00it/s]
# dataloaders: 108it [00:21,  5.05it/s]
# dataloaders: 109it [00:21,  5.17it/s]
# dataloaders: 110it [00:22,  5.23it/s]
# dataloaders: 111it [00:22,  5.26it/s]
# dataloaders: 112it [00:22,  5.31it/s]
# dataloaders: 113it [00:22,  5.28it/s]
# dataloaders: 114it [00:22,  5.25it/s]
# dataloaders: 115it [00:22,  5.27it/s]
# dataloaders: 116it [00:23,  5.23it/s]
# dataloaders: 117it [00:23,  5.16it/s]
# dataloaders: 118it [00:23,  5.21it/s]
# dataloaders: 119it [00:23,  5.08it/s]
# dataloaders: 120it [00:23,  4.93it/s]
# dataloaders: 121it [00:24,  5.10it/s]
# dataloaders: 122it [00:24,  5.07it/s]
# dataloaders: 123it [00:24,  5.14it/s]
# dataloaders: 124it [00:24,  5.13it/s]
# dataloaders: 125it [00:24,  5.07it/s]
# dataloaders: 126it [00:25,  5.06it/s]
# dataloaders: 127it [00:25,  4.95it/s]
# dataloaders: 128it [00:25,  5.00it/s]
# dataloaders: 129it [00:25,  5.12it/s]
# dataloaders: 130it [00:25,  4.97it/s]
# dataloaders: 131it [00:26,  4.94it/s]
# dataloaders: 132it [00:26,  5.07it/s]
# dataloaders: 133it [00:26,  5.12it/s]
# dataloaders: 134it [00:26,  5.21it/s]
# dataloaders: 135it [00:26,  5.27it/s]
# dataloaders: 136it [00:27,  5.36it/s]
# dataloaders: 137it [00:27,  5.29it/s]
# dataloaders: 138it [00:27,  5.18it/s]
# dataloaders: 139it [00:27,  5.15it/s]
# dataloaders: 140it [00:27,  5.23it/s]
# dataloaders: 141it [00:28,  5.18it/s]
# dataloaders: 142it [00:28,  5.23it/s]
# dataloaders: 143it [00:28,  5.30it/s]
# dataloaders: 144it [00:28,  5.39it/s]
# dataloaders: 145it [00:28,  5.36it/s]
# dataloaders: 146it [00:28,  5.28it/s]
# dataloaders: 147it [00:29,  5.31it/s]
# dataloaders: 148it [00:29,  5.27it/s]
# dataloaders: 149it [00:29,  5.20it/s]
# dataloaders: 150it [00:29,  5.21it/s]
# dataloaders: 151it [00:29,  4.88it/s]
# dataloaders: 152it [00:30,  4.87it/s]
# dataloaders: 153it [00:30,  4.85it/s]
# dataloaders: 154it [00:30,  4.94it/s]
# dataloaders: 155it [00:30,  5.02it/s]
# dataloaders: 156it [00:30,  5.01it/s]
# dataloaders: 157it [00:31,  5.01it/s]
# dataloaders: 158it [00:31,  4.91it/s]
# dataloaders: 159it [00:31,  4.79it/s]
# dataloaders: 160it [00:31,  4.88it/s]
# dataloaders: 161it [00:32,  4.98it/s]
# dataloaders: 162it [00:32,  4.68it/s]
# dataloaders: 163it [00:32,  4.65it/s]
# dataloaders: 164it [00:32,  4.69it/s]
# dataloaders: 165it [00:32,  4.74it/s]
# dataloaders: 166it [00:33,  4.80it/s]
# dataloaders: 167it [00:33,  4.86it/s]
# dataloaders: 168it [00:33,  4.87it/s]
# dataloaders: 169it [00:33,  4.88it/s]
# dataloaders: 170it [00:33,  4.80it/s]
# dataloaders: 171it [00:34,  4.46it/s]
# dataloaders: 172it [00:34,  4.40it/s]
# dataloaders: 173it [00:34,  4.39it/s]
# dataloaders: 174it [00:34,  4.43it/s]
# dataloaders: 175it [00:35,  4.57it/s]
# dataloaders: 176it [00:35,  3.96it/s]
# dataloaders: 177it [00:35,  4.25it/s]
# dataloaders: 178it [00:35,  4.40it/s]
# dataloaders: 179it [00:35,  4.57it/s]
# dataloaders: 180it [00:36,  4.55it/s]
# dataloaders: 181it [00:36,  4.65it/s]
# dataloaders: 182it [00:36,  4.73it/s]
# dataloaders: 183it [00:36,  4.63it/s]
# dataloaders: 184it [00:37,  4.82it/s]
# dataloaders: 185it [00:37,  4.80it/s]
# dataloaders: 186it [00:37,  4.97it/s]
# epoch:  30%|███       | 6/20 [03:50<08:59, 38.51s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.58it/s]
# dataloaders: 2it [00:00,  5.09it/s]
# dataloaders: 3it [00:00,  4.87it/s]
# dataloaders: 4it [00:00,  5.02it/s]
# dataloaders: 5it [00:00,  5.10it/s]
# dataloaders: 6it [00:01,  5.14it/s]
# dataloaders: 7it [00:01,  5.04it/s]
# dataloaders: 8it [00:01,  5.07it/s]
# dataloaders: 9it [00:01,  5.03it/s]
# dataloaders: 10it [00:02,  4.84it/s]
# dataloaders: 11it [00:02,  4.77it/s]
# dataloaders: 12it [00:02,  4.90it/s]
# dataloaders: 13it [00:02,  4.86it/s]
# dataloaders: 14it [00:02,  4.90it/s]
# dataloaders: 15it [00:03,  4.90it/s]
# dataloaders: 16it [00:03,  4.91it/s]
# dataloaders: 17it [00:03,  4.87it/s]
# dataloaders: 18it [00:03,  4.89it/s]
# dataloaders: 19it [00:03,  4.82it/s]
# dataloaders: 20it [00:04,  4.97it/s]
# dataloaders: 21it [00:04,  5.09it/s]
# dataloaders: 22it [00:04,  5.12it/s]
# dataloaders: 23it [00:04,  5.13it/s]
# dataloaders: 24it [00:04,  5.01it/s]
# dataloaders: 25it [00:05,  5.09it/s]
# dataloaders: 26it [00:05,  5.15it/s]
# dataloaders: 27it [00:05,  5.20it/s]
# dataloaders: 28it [00:05,  5.15it/s]
# dataloaders: 29it [00:05,  5.11it/s]
# dataloaders: 30it [00:05,  5.20it/s]
# dataloaders: 31it [00:06,  5.27it/s]
# dataloaders: 32it [00:06,  5.31it/s]
# dataloaders: 33it [00:06,  5.30it/s]
# dataloaders: 34it [00:06,  5.28it/s]
# dataloaders: 35it [00:06,  5.31it/s]
# dataloaders: 36it [00:07,  5.23it/s]
# dataloaders: 37it [00:07,  5.15it/s]
# dataloaders: 38it [00:07,  5.19it/s]
# dataloaders: 39it [00:07,  5.24it/s]
# dataloaders: 40it [00:07,  4.96it/s]
# dataloaders: 41it [00:08,  5.08it/s]
# dataloaders: 42it [00:08,  5.06it/s]
# dataloaders: 43it [00:08,  5.13it/s]
# dataloaders: 44it [00:08,  5.25it/s]
# dataloaders: 45it [00:08,  5.19it/s]
# dataloaders: 46it [00:09,  5.15it/s]
# dataloaders: 47it [00:09,  5.12it/s]
# dataloaders: 48it [00:09,  5.22it/s]
# dataloaders: 49it [00:09,  5.13it/s]
# dataloaders: 50it [00:09,  5.14it/s]
# dataloaders: 51it [00:10,  5.05it/s]
# dataloaders: 52it [00:10,  4.74it/s]
# dataloaders: 53it [00:10,  4.76it/s]
# dataloaders: 54it [00:10,  4.59it/s]
# dataloaders: 55it [00:10,  4.48it/s]
# dataloaders: 56it [00:11,  4.61it/s]
# dataloaders: 57it [00:11,  4.62it/s]
# dataloaders: 58it [00:11,  4.80it/s]
# dataloaders: 59it [00:11,  4.85it/s]
# dataloaders: 60it [00:11,  4.77it/s]
# dataloaders: 61it [00:12,  4.52it/s]
# dataloaders: 62it [00:12,  4.54it/s]
# dataloaders: 63it [00:12,  4.50it/s]
# dataloaders: 64it [00:13,  3.85it/s]
# dataloaders: 65it [00:13,  4.11it/s]
# dataloaders: 66it [00:13,  4.19it/s]
# dataloaders: 67it [00:13,  4.40it/s]
# dataloaders: 68it [00:13,  4.51it/s]
# dataloaders: 69it [00:14,  4.59it/s]
# dataloaders: 70it [00:14,  4.73it/s]
# dataloaders: 71it [00:14,  4.77it/s]
# dataloaders: 72it [00:14,  4.78it/s]
# dataloaders: 73it [00:14,  4.74it/s]
# dataloaders: 74it [00:15,  4.92it/s]
# dataloaders: 75it [00:15,  5.02it/s]
# dataloaders: 76it [00:15,  5.16it/s]
# dataloaders: 77it [00:15,  5.21it/s]
# dataloaders: 78it [00:15,  5.18it/s]
# dataloaders: 79it [00:16,  5.13it/s]
# dataloaders: 80it [00:16,  5.09it/s]
# dataloaders: 81it [00:16,  5.07it/s]
# dataloaders: 82it [00:16,  5.12it/s]
# dataloaders: 83it [00:16,  5.12it/s]
# dataloaders: 84it [00:17,  5.15it/s]
# dataloaders: 85it [00:17,  5.04it/s]
# dataloaders: 86it [00:17,  5.10it/s]
# dataloaders: 87it [00:17,  5.22it/s]
# dataloaders: 88it [00:17,  5.23it/s]
# dataloaders: 89it [00:18,  5.16it/s]
# dataloaders: 90it [00:18,  5.12it/s]
# dataloaders: 91it [00:18,  5.09it/s]
# dataloaders: 92it [00:18,  5.10it/s]
# dataloaders: 93it [00:18,  5.07it/s]
# dataloaders: 94it [00:18,  5.12it/s]
# dataloaders: 95it [00:19,  4.97it/s]
# dataloaders: 96it [00:19,  5.06it/s]
# dataloaders: 97it [00:19,  5.16it/s]
# dataloaders: 98it [00:19,  5.25it/s]
# dataloaders: 99it [00:19,  5.25it/s]
# dataloaders: 100it [00:20,  5.27it/s]
# dataloaders: 101it [00:20,  5.32it/s]
# dataloaders: 102it [00:20,  5.17it/s]
# dataloaders: 103it [00:20,  5.16it/s]
# dataloaders: 104it [00:20,  5.15it/s]
# dataloaders: 105it [00:21,  5.21it/s]
# dataloaders: 106it [00:21,  5.23it/s]
# dataloaders: 107it [00:21,  5.20it/s]
# dataloaders: 108it [00:21,  5.28it/s]
# dataloaders: 109it [00:21,  5.37it/s]
# dataloaders: 110it [00:22,  5.46it/s]
# dataloaders: 111it [00:22,  5.46it/s]
# dataloaders: 112it [00:22,  5.48it/s]
# dataloaders: 113it [00:22,  5.52it/s]
# dataloaders: 114it [00:22,  5.55it/s]
# dataloaders: 115it [00:22,  5.57it/s]
# dataloaders: 116it [00:23,  5.55it/s]
# dataloaders: 117it [00:23,  5.56it/s]
# dataloaders: 118it [00:23,  5.48it/s]
# dataloaders: 119it [00:23,  5.35it/s]
# dataloaders: 120it [00:23,  5.16it/s]
# dataloaders: 121it [00:24,  5.12it/s]
# dataloaders: 122it [00:24,  5.10it/s]
# dataloaders: 123it [00:24,  5.10it/s]
# dataloaders: 124it [00:24,  5.09it/s]
# dataloaders: 125it [00:24,  5.12it/s]
# dataloaders: 126it [00:25,  5.09it/s]
# dataloaders: 127it [00:25,  5.14it/s]
# dataloaders: 128it [00:25,  4.93it/s]
# dataloaders: 129it [00:25,  4.93it/s]
# dataloaders: 130it [00:25,  4.90it/s]
# dataloaders: 131it [00:26,  4.39it/s]
# dataloaders: 132it [00:26,  4.37it/s]
# dataloaders: 133it [00:26,  4.34it/s]
# dataloaders: 134it [00:26,  4.40it/s]
# dataloaders: 135it [00:27,  4.55it/s]
# dataloaders: 136it [00:27,  4.58it/s]
# dataloaders: 137it [00:27,  4.61it/s]
# dataloaders: 138it [00:27,  4.64it/s]
# dataloaders: 139it [00:27,  4.74it/s]
# dataloaders: 140it [00:28,  4.86it/s]
# dataloaders: 141it [00:28,  4.90it/s]
# dataloaders: 142it [00:28,  4.92it/s]
# dataloaders: 143it [00:28,  4.91it/s]
# dataloaders: 144it [00:28,  4.91it/s]
# dataloaders: 145it [00:29,  4.74it/s]
# dataloaders: 146it [00:29,  4.72it/s]
# dataloaders: 147it [00:29,  4.76it/s]
# dataloaders: 148it [00:29,  4.95it/s]
# dataloaders: 149it [00:29,  5.10it/s]
# dataloaders: 150it [00:30,  5.17it/s]
# ...
# dataloaders: 141it [00:28,  5.20it/s]
# dataloaders: 142it [00:28,  5.14it/s]
# dataloaders: 143it [00:28,  5.01it/s]
# dataloaders: 144it [00:29,  4.85it/s]
# dataloaders: 145it [00:29,  4.92it/s]
# dataloaders: 146it [00:29,  4.92it/s]
# dataloaders: 147it [00:29,  5.05it/s]
# dataloaders: 148it [00:29,  5.09it/s]
# dataloaders: 149it [00:30,  5.15it/s]
# dataloaders: 150it [00:30,  5.21it/s]
# dataloaders: 151it [00:30,  5.10it/s]
# dataloaders: 152it [00:30,  5.02it/s]
# dataloaders: 153it [00:30,  4.97it/s]
# dataloaders: 154it [00:31,  4.98it/s]
# dataloaders: 155it [00:31,  4.82it/s]
# dataloaders: 156it [00:31,  4.84it/s]
# dataloaders: 157it [00:31,  4.88it/s]
# dataloaders: 158it [00:31,  4.90it/s]
# dataloaders: 159it [00:32,  4.91it/s]
# dataloaders: 160it [00:32,  4.89it/s]
# dataloaders: 161it [00:32,  4.89it/s]
# dataloaders: 162it [00:32,  4.81it/s]
# dataloaders: 163it [00:32,  4.81it/s]
# dataloaders: 164it [00:33,  4.82it/s]
# dataloaders: 165it [00:33,  4.79it/s]
# dataloaders: 166it [00:33,  4.75it/s]
# dataloaders: 167it [00:33,  4.87it/s]
# dataloaders: 168it [00:33,  4.99it/s]
# dataloaders: 169it [00:34,  5.07it/s]
# dataloaders: 170it [00:34,  5.12it/s]
# dataloaders: 171it [00:34,  5.19it/s]
# dataloaders: 172it [00:34,  5.21it/s]
# dataloaders: 173it [00:34,  5.18it/s]
# dataloaders: 174it [00:35,  5.15it/s]
# dataloaders: 175it [00:35,  5.16it/s]
# dataloaders: 176it [00:35,  5.12it/s]
# dataloaders: 177it [00:35,  5.09it/s]
# dataloaders: 178it [00:35,  5.04it/s]
# dataloaders: 179it [00:36,  5.09it/s]
# dataloaders: 180it [00:36,  5.13it/s]
# dataloaders: 181it [00:36,  5.16it/s]
# dataloaders: 182it [00:36,  5.16it/s]
# dataloaders: 183it [00:36,  5.17it/s]
# dataloaders: 184it [00:37,  5.20it/s]
# dataloaders: 185it [00:37,  5.20it/s]
# dataloaders: 186it [00:37,  4.96it/s]
# epoch:  90%|█████████ | 18/20 [11:20<01:15, 37.82s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.61it/s]
# dataloaders: 2it [00:00,  4.76it/s]
# dataloaders: 3it [00:00,  4.99it/s]
# dataloaders: 4it [00:00,  5.10it/s]
# dataloaders: 5it [00:00,  5.18it/s]
# dataloaders: 6it [00:01,  5.21it/s]
# dataloaders: 7it [00:01,  5.20it/s]
# dataloaders: 8it [00:01,  5.09it/s]
# dataloaders: 9it [00:01,  5.14it/s]
# dataloaders: 10it [00:01,  5.14it/s]
# dataloaders: 11it [00:02,  5.17it/s]
# dataloaders: 12it [00:02,  5.10it/s]
# dataloaders: 13it [00:02,  5.14it/s]
# dataloaders: 14it [00:02,  5.07it/s]
# dataloaders: 15it [00:02,  5.00it/s]
# dataloaders: 16it [00:03,  4.89it/s]
# dataloaders: 17it [00:03,  4.95it/s]
# dataloaders: 18it [00:03,  5.00it/s]
# dataloaders: 19it [00:03,  5.09it/s]
# dataloaders: 20it [00:03,  5.15it/s]
# dataloaders: 21it [00:04,  5.14it/s]
# dataloaders: 22it [00:04,  5.15it/s]
# dataloaders: 23it [00:04,  5.18it/s]
# dataloaders: 24it [00:04,  5.19it/s]
# dataloaders: 25it [00:04,  5.12it/s]
# dataloaders: 26it [00:05,  5.16it/s]
# dataloaders: 27it [00:05,  5.17it/s]
# dataloaders: 28it [00:05,  5.16it/s]
# dataloaders: 29it [00:05,  5.21it/s]
# dataloaders: 30it [00:05,  5.24it/s]
# dataloaders: 31it [00:06,  5.24it/s]
# dataloaders: 32it [00:06,  5.18it/s]
# dataloaders: 33it [00:06,  5.17it/s]
# dataloaders: 34it [00:06,  5.20it/s]
# dataloaders: 35it [00:06,  5.22it/s]
# dataloaders: 36it [00:07,  5.01it/s]
# dataloaders: 37it [00:07,  5.03it/s]
# dataloaders: 38it [00:07,  5.08it/s]
# dataloaders: 39it [00:07,  5.11it/s]
# dataloaders: 40it [00:07,  5.16it/s]
# dataloaders: 41it [00:08,  4.99it/s]
# dataloaders: 42it [00:08,  4.92it/s]
# dataloaders: 43it [00:08,  5.01it/s]
# dataloaders: 44it [00:08,  5.06it/s]
# dataloaders: 45it [00:08,  4.99it/s]
# dataloaders: 46it [00:09,  4.95it/s]
# dataloaders: 47it [00:09,  4.93it/s]
# dataloaders: 48it [00:09,  4.91it/s]
# dataloaders: 49it [00:09,  4.75it/s]
# dataloaders: 50it [00:09,  4.70it/s]
# dataloaders: 51it [00:10,  4.74it/s]
# dataloaders: 52it [00:10,  4.77it/s]
# dataloaders: 53it [00:10,  4.78it/s]
# dataloaders: 54it [00:10,  4.82it/s]
# dataloaders: 55it [00:10,  4.82it/s]
# dataloaders: 56it [00:11,  4.79it/s]
# dataloaders: 57it [00:11,  4.78it/s]
# dataloaders: 58it [00:11,  4.70it/s]
# dataloaders: 59it [00:11,  4.56it/s]
# dataloaders: 60it [00:12,  4.68it/s]
# dataloaders: 61it [00:12,  4.83it/s]
# dataloaders: 62it [00:12,  4.92it/s]
# dataloaders: 63it [00:12,  4.86it/s]
# dataloaders: 64it [00:12,  4.95it/s]
# dataloaders: 65it [00:12,  5.05it/s]
# dataloaders: 66it [00:13,  5.02it/s]
# dataloaders: 67it [00:13,  5.04it/s]
# dataloaders: 68it [00:13,  5.11it/s]
# dataloaders: 69it [00:13,  5.10it/s]
# dataloaders: 70it [00:13,  5.11it/s]
# dataloaders: 71it [00:14,  5.17it/s]
# dataloaders: 72it [00:14,  5.08it/s]
# dataloaders: 73it [00:14,  5.02it/s]
# dataloaders: 74it [00:14,  5.11it/s]
# dataloaders: 75it [00:15,  4.45it/s]
# dataloaders: 76it [00:15,  4.59it/s]
# dataloaders: 77it [00:15,  4.74it/s]
# dataloaders: 78it [00:15,  4.87it/s]
# dataloaders: 79it [00:15,  4.98it/s]
# dataloaders: 80it [00:16,  5.01it/s]
# dataloaders: 81it [00:16,  5.05it/s]
# dataloaders: 82it [00:16,  5.05it/s]
# dataloaders: 83it [00:16,  5.10it/s]
# dataloaders: 84it [00:16,  5.09it/s]
# dataloaders: 85it [00:16,  5.12it/s]
# dataloaders: 86it [00:17,  5.15it/s]
# dataloaders: 87it [00:17,  5.17it/s]
# dataloaders: 88it [00:17,  5.17it/s]
# dataloaders: 89it [00:17,  5.13it/s]
# dataloaders: 90it [00:18,  4.77it/s]
# dataloaders: 91it [00:18,  4.73it/s]
# dataloaders: 92it [00:18,  4.70it/s]
# dataloaders: 93it [00:18,  4.55it/s]
# dataloaders: 94it [00:18,  4.74it/s]
# dataloaders: 95it [00:19,  4.89it/s]
# dataloaders: 96it [00:19,  4.99it/s]
# dataloaders: 97it [00:19,  5.04it/s]
# dataloaders: 98it [00:19,  5.09it/s]
# dataloaders: 99it [00:19,  5.00it/s]
# dataloaders: 100it [00:20,  4.82it/s]
# dataloaders: 101it [00:20,  4.63it/s]
# dataloaders: 102it [00:20,  4.48it/s]
# dataloaders: 103it [00:20,  4.48it/s]
# dataloaders: 104it [00:20,  4.59it/s]
# dataloaders: 105it [00:21,  4.69it/s]
# dataloaders: 106it [00:21,  4.76it/s]
# dataloaders: 107it [00:21,  4.80it/s]
# dataloaders: 108it [00:21,  4.93it/s]
# dataloaders: 109it [00:21,  4.88it/s]
# dataloaders: 110it [00:22,  4.81it/s]
# dataloaders: 111it [00:22,  4.89it/s]
# dataloaders: 112it [00:22,  4.79it/s]
# dataloaders: 113it [00:22,  4.73it/s]
# dataloaders: 114it [00:23,  4.70it/s]
# dataloaders: 115it [00:23,  4.67it/s]
# dataloaders: 116it [00:23,  4.65it/s]
# dataloaders: 117it [00:23,  4.63it/s]
# dataloaders: 118it [00:23,  4.63it/s]
# dataloaders: 119it [00:24,  4.51it/s]
# dataloaders: 120it [00:24,  4.54it/s]
# dataloaders: 121it [00:24,  3.79it/s]
# dataloaders: 122it [00:24,  3.95it/s]
# dataloaders: 123it [00:25,  4.01it/s]
# dataloaders: 124it [00:25,  4.14it/s]
# dataloaders: 125it [00:25,  4.37it/s]
# dataloaders: 126it [00:25,  4.50it/s]
# dataloaders: 127it [00:26,  4.48it/s]
# dataloaders: 128it [00:26,  4.53it/s]
# dataloaders: 129it [00:26,  4.49it/s]
# dataloaders: 130it [00:26,  4.60it/s]
# dataloaders: 131it [00:26,  4.59it/s]
# dataloaders: 132it [00:27,  4.55it/s]
# dataloaders: 133it [00:27,  4.45it/s]
# dataloaders: 134it [00:27,  4.60it/s]
# dataloaders: 135it [00:27,  4.62it/s]
# dataloaders: 136it [00:28,  4.66it/s]
# dataloaders: 137it [00:28,  4.80it/s]
# dataloaders: 138it [00:28,  4.82it/s]
# dataloaders: 139it [00:28,  4.78it/s]
# dataloaders: 140it [00:28,  4.84it/s]
# dataloaders: 141it [00:29,  4.72it/s]
# dataloaders: 142it [00:29,  4.63it/s]
# dataloaders: 143it [00:29,  4.50it/s]
# dataloaders: 144it [00:29,  4.48it/s]
# dataloaders: 145it [00:29,  4.52it/s]
# dataloaders: 146it [00:30,  4.70it/s]
# dataloaders: 147it [00:30,  4.69it/s]
# dataloaders: 148it [00:30,  4.70it/s]
# dataloaders: 149it [00:30,  4.76it/s]
# dataloaders: 150it [00:30,  4.67it/s]
# dataloaders: 151it [00:31,  4.78it/s]
# dataloaders: 152it [00:31,  4.57it/s]
# dataloaders: 153it [00:31,  4.32it/s]
# dataloaders: 154it [00:31,  4.29it/s]
# dataloaders: 155it [00:32,  4.54it/s]
# dataloaders: 156it [00:32,  4.55it/s]
# dataloaders: 157it [00:32,  4.62it/s]
# dataloaders: 158it [00:32,  4.70it/s]
# dataloaders: 159it [00:32,  4.84it/s]
# dataloaders: 160it [00:33,  4.92it/s]
# dataloaders: 161it [00:33,  4.95it/s]
# dataloaders: 162it [00:33,  5.04it/s]
# dataloaders: 163it [00:33,  5.09it/s]
# dataloaders: 164it [00:33,  5.08it/s]
# dataloaders: 165it [00:34,  5.07it/s]
# dataloaders: 166it [00:34,  5.05it/s]
# dataloaders: 167it [00:34,  4.96it/s]
# dataloaders: 168it [00:34,  5.03it/s]
# dataloaders: 169it [00:34,  5.08it/s]
# dataloaders: 170it [00:35,  5.10it/s]
# dataloaders: 171it [00:35,  5.14it/s]
# dataloaders: 172it [00:35,  5.14it/s]
# dataloaders: 173it [00:35,  5.16it/s]
# dataloaders: 174it [00:35,  4.99it/s]
# dataloaders: 175it [00:36,  5.04it/s]
# dataloaders: 176it [00:36,  5.05it/s]
# dataloaders: 177it [00:36,  5.09it/s]
# dataloaders: 178it [00:36,  5.13it/s]
# dataloaders: 179it [00:36,  5.16it/s]
# dataloaders: 180it [00:37,  5.15it/s]
# dataloaders: 181it [00:37,  5.03it/s]
# dataloaders: 182it [00:37,  4.44it/s]
# dataloaders: 183it [00:37,  4.66it/s]
# dataloaders: 184it [00:37,  4.78it/s]
# dataloaders: 185it [00:38,  4.78it/s]
# dataloaders: 186it [00:38,  4.85it/s]
# epoch:  95%|█████████▌| 19/20 [11:58<00:38, 38.05s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.55it/s]
# dataloaders: 2it [00:00,  4.89it/s]
# dataloaders: 3it [00:00,  5.04it/s]
# dataloaders: 4it [00:00,  5.11it/s]
# dataloaders: 5it [00:01,  4.97it/s]
# dataloaders: 6it [00:01,  5.04it/s]
# dataloaders: 7it [00:01,  5.03it/s]
# dataloaders: 8it [00:01,  4.99it/s]
# dataloaders: 9it [00:01,  4.92it/s]
# dataloaders: 10it [00:02,  4.95it/s]
# dataloaders: 11it [00:02,  4.75it/s]
# dataloaders: 12it [00:02,  4.78it/s]
# dataloaders: 13it [00:02,  4.80it/s]
# dataloaders: 14it [00:02,  4.85it/s]
# dataloaders: 15it [00:03,  4.78it/s]
# dataloaders: 16it [00:03,  4.81it/s]
# dataloaders: 17it [00:03,  4.75it/s]
# dataloaders: 18it [00:03,  4.77it/s]
# dataloaders: 19it [00:03,  4.69it/s]
# dataloaders: 20it [00:04,  4.63it/s]
# dataloaders: 21it [00:04,  4.58it/s]
# dataloaders: 22it [00:04,  4.57it/s]
# dataloaders: 23it [00:04,  4.69it/s]
# dataloaders: 24it [00:05,  4.67it/s]
# dataloaders: 25it [00:05,  4.72it/s]
# dataloaders: 26it [00:05,  4.77it/s]
# dataloaders: 27it [00:05,  4.90it/s]
# dataloaders: 28it [00:05,  4.84it/s]
# dataloaders: 29it [00:06,  4.87it/s]
# dataloaders: 30it [00:06,  4.97it/s]
# dataloaders: 31it [00:06,  5.06it/s]
# dataloaders: 32it [00:06,  4.95it/s]
# dataloaders: 33it [00:06,  4.92it/s]
# dataloaders: 34it [00:07,  4.99it/s]
# dataloaders: 35it [00:07,  5.06it/s]
# dataloaders: 36it [00:07,  5.10it/s]
# dataloaders: 37it [00:07,  5.15it/s]
# dataloaders: 38it [00:07,  5.10it/s]
# dataloaders: 39it [00:07,  5.15it/s]
# dataloaders: 40it [00:08,  5.13it/s]
# dataloaders: 41it [00:08,  5.07it/s]
# dataloaders: 42it [00:08,  5.12it/s]
# dataloaders: 43it [00:08,  5.08it/s]
# dataloaders: 44it [00:08,  5.06it/s]
# dataloaders: 45it [00:09,  4.96it/s]
# dataloaders: 46it [00:09,  4.97it/s]
# dataloaders: 47it [00:09,  5.03it/s]
# dataloaders: 48it [00:09,  5.04it/s]
# dataloaders: 49it [00:09,  5.11it/s]
# dataloaders: 50it [00:10,  5.14it/s]
# dataloaders: 51it [00:10,  5.16it/s]
# dataloaders: 52it [00:10,  5.17it/s]
# dataloaders: 53it [00:10,  5.03it/s]
# dataloaders: 54it [00:10,  4.79it/s]
# dataloaders: 55it [00:11,  4.82it/s]
# dataloaders: 56it [00:11,  4.89it/s]
# dataloaders: 57it [00:11,  4.95it/s]
# dataloaders: 58it [00:11,  4.86it/s]
# dataloaders: 59it [00:12,  4.85it/s]
# dataloaders: 60it [00:12,  4.67it/s]
# dataloaders: 61it [00:12,  4.48it/s]
# dataloaders: 62it [00:12,  4.55it/s]
# dataloaders: 63it [00:12,  4.58it/s]
# dataloaders: 64it [00:13,  4.70it/s]
# dataloaders: 65it [00:13,  4.66it/s]
# dataloaders: 66it [00:13,  4.70it/s]
# dataloaders: 67it [00:13,  4.76it/s]
# dataloaders: 68it [00:13,  4.74it/s]
# dataloaders: 69it [00:14,  4.63it/s]
# dataloaders: 70it [00:14,  4.73it/s]
# dataloaders: 71it [00:14,  4.70it/s]
# dataloaders: 72it [00:14,  4.75it/s]
# dataloaders: 73it [00:14,  4.85it/s]
# dataloaders: 74it [00:15,  4.95it/s]
# dataloaders: 75it [00:15,  5.02it/s]
# dataloaders: 76it [00:15,  4.89it/s]
# dataloaders: 77it [00:15,  4.82it/s]
# dataloaders: 78it [00:16,  4.88it/s]
# dataloaders: 79it [00:16,  4.82it/s]
# dataloaders: 80it [00:16,  4.49it/s]
# dataloaders: 81it [00:16,  4.41it/s]
# dataloaders: 82it [00:16,  4.53it/s]
# dataloaders: 83it [00:17,  4.68it/s]
# dataloaders: 84it [00:17,  4.82it/s]
# dataloaders: 85it [00:17,  4.75it/s]
# dataloaders: 86it [00:17,  4.70it/s]
# dataloaders: 87it [00:17,  4.63it/s]
# dataloaders: 88it [00:18,  4.57it/s]
# dataloaders: 89it [00:18,  4.49it/s]
# dataloaders: 90it [00:18,  4.39it/s]
# dataloaders: 91it [00:18,  4.30it/s]
# dataloaders: 92it [00:19,  4.29it/s]
# dataloaders: 93it [00:19,  4.34it/s]
# dataloaders: 94it [00:19,  4.34it/s]
# dataloaders: 95it [00:19,  4.23it/s]
# dataloaders: 96it [00:20,  4.32it/s]
# dataloaders: 97it [00:20,  4.47it/s]
# dataloaders: 98it [00:20,  4.60it/s]
# dataloaders: 99it [00:20,  4.61it/s]
# dataloaders: 100it [00:20,  4.56it/s]
# dataloaders: 101it [00:21,  4.54it/s]
# dataloaders: 102it [00:21,  4.45it/s]
# dataloaders: 103it [00:21,  4.39it/s]
# dataloaders: 104it [00:21,  4.45it/s]
# dataloaders: 105it [00:22,  4.54it/s]
# dataloaders: 106it [00:22,  4.56it/s]
# dataloaders: 107it [00:22,  4.69it/s]
# dataloaders: 108it [00:22,  4.82it/s]
# dataloaders: 109it [00:22,  4.79it/s]
# dataloaders: 110it [00:23,  4.92it/s]
# dataloaders: 111it [00:23,  4.99it/s]
# dataloaders: 112it [00:23,  5.03it/s]
# dataloaders: 113it [00:23,  5.07it/s]
# dataloaders: 114it [00:23,  5.12it/s]
# dataloaders: 115it [00:24,  5.07it/s]
# dataloaders: 116it [00:24,  4.97it/s]
# dataloaders: 117it [00:24,  4.97it/s]
# dataloaders: 118it [00:24,  4.73it/s]
# dataloaders: 119it [00:24,  4.85it/s]
# dataloaders: 120it [00:25,  4.95it/s]
# dataloaders: 121it [00:25,  4.98it/s]
# dataloaders: 122it [00:25,  5.07it/s]
# dataloaders: 123it [00:25,  5.11it/s]
# dataloaders: 124it [00:25,  5.13it/s]
# dataloaders: 125it [00:26,  5.13it/s]
# dataloaders: 126it [00:26,  5.12it/s]
# dataloaders: 127it [00:26,  5.15it/s]
# dataloaders: 128it [00:26,  5.16it/s]
# dataloaders: 129it [00:26,  5.04it/s]
# dataloaders: 130it [00:27,  5.07it/s]
# dataloaders: 131it [00:27,  5.13it/s]
# dataloaders: 132it [00:27,  5.14it/s]
# dataloaders: 133it [00:27,  5.16it/s]
# dataloaders: 134it [00:27,  5.05it/s]
# dataloaders: 135it [00:28,  4.97it/s]
# dataloaders: 136it [00:28,  5.03it/s]
# dataloaders: 137it [00:28,  5.08it/s]
# dataloaders: 138it [00:28,  5.10it/s]
# dataloaders: 139it [00:28,  4.91it/s]
# dataloaders: 140it [00:29,  4.95it/s]
# dataloaders: 141it [00:29,  5.02it/s]
# dataloaders: 142it [00:29,  5.03it/s]
# dataloaders: 143it [00:29,  5.09it/s]
# dataloaders: 144it [00:29,  5.11it/s]
# dataloaders: 145it [00:29,  5.06it/s]
# dataloaders: 146it [00:30,  4.98it/s]
# dataloaders: 147it [00:30,  4.81it/s]
# dataloaders: 148it [00:30,  4.82it/s]
# dataloaders: 149it [00:30,  4.89it/s]
# dataloaders: 150it [00:31,  4.98it/s]
# dataloaders: 151it [00:31,  4.98it/s]
# dataloaders: 152it [00:31,  4.90it/s]
# dataloaders: 153it [00:31,  4.96it/s]
# dataloaders: 154it [00:31,  5.02it/s]
# dataloaders: 155it [00:32,  5.05it/s]
# dataloaders: 156it [00:32,  5.07it/s]
# dataloaders: 157it [00:32,  5.04it/s]
# dataloaders: 158it [00:32,  5.08it/s]
# dataloaders: 159it [00:32,  5.04it/s]
# dataloaders: 160it [00:32,  5.10it/s]
# dataloaders: 161it [00:33,  5.12it/s]
# dataloaders: 162it [00:33,  5.13it/s]
# dataloaders: 163it [00:33,  5.05it/s]
# dataloaders: 164it [00:33,  5.08it/s]
# dataloaders: 165it [00:33,  5.11it/s]
# dataloaders: 166it [00:34,  4.99it/s]
# dataloaders: 167it [00:34,  4.86it/s]
# dataloaders: 168it [00:34,  4.81it/s]
# dataloaders: 169it [00:34,  4.80it/s]
# dataloaders: 170it [00:35,  4.67it/s]
# dataloaders: 171it [00:35,  4.70it/s]
# dataloaders: 172it [00:35,  4.73it/s]
# dataloaders: 173it [00:35,  4.64it/s]
# dataloaders: 174it [00:35,  4.66it/s]
# dataloaders: 175it [00:36,  4.71it/s]
# dataloaders: 176it [00:36,  4.71it/s]
# dataloaders: 177it [00:36,  4.70it/s]
# dataloaders: 178it [00:36,  4.64it/s]
# dataloaders: 179it [00:36,  4.63it/s]
# dataloaders: 180it [00:37,  4.70it/s]
# dataloaders: 181it [00:37,  4.82it/s]
# dataloaders: 182it [00:37,  4.94it/s]
# dataloaders: 183it [00:37,  4.98it/s]
# dataloaders: 184it [00:37,  4.96it/s]
# dataloaders: 185it [00:38,  5.02it/s]
# dataloaders: 186it [00:38,  4.85it/s]
# epoch: 100%|██████████| 20/20 [12:37<00:00, 37.86s/it]
# After training, Spearman Correlation: 0.1206
# After training, Spearman Correlation: 0.1206

# %% [markdown]
# #### 4.3 Courbes d'entraînement du modèle de zéro (4 points)
#
# Affichez la perte moyenne sur le jeu d'entraînement et la corrélation de Spearman sur le jeu de validation à chaque époque.

# %%
# Create some mock data
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.plot(losses, color=color)
ax1.set_xlabel("Iteration")
ax1.set_ylabel("Loss over iteration", color = color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second Axes that shares the same x-axis

color = 'tab:blue'
ax2.plot(spearman_corrList, color=color)
ax2.set_ylabel("Spearman Correlation over iteration",color = color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
ant_test = torch.tensor([[ 4480,  7146],
        [15031, 20597],
        [ 1750, 25259],
        [ 3020, 20812],
        [  181,  8790],
        [ 1382,  6069],
        [ 2303,  7229],
        [ 1155,  2079],
        [13254,  3149],
        [13234, 16294],
        [  407,  2079],
        [ 4867,  3892],
        [12221,  1997],
        [ 8797,  1690],
        [ 2225, 11508],
        [  760, 16371],
        [14123, 31742],
        [  925,  6753],
        [20576, 25039],
        [10716, 28439],
        [10783, 29953],
        [ 4025, 13192],
        [ 3473,  4619],
        [13848, 23341],
        [17960, 13289],
        [ 4698,  9053],
        [ 1556, 12193],
        [ 1825,  2175],
        [ 5969, 13584],
        [32890,  6928],
        [ 4048,  5254],
        [ 4317,  7296],
        [ 7656,  9228],
        [16199, 19650],
        [  648, 23013],
        [ 4351,  5690],
        [ 2011,   724],
        [ 7128, 23704],
        [  741, 16465],
        [ 9134, 15458],
        [ 4496,  2761],
        [  113,  1411],
        [18804, 24280],
        [14343,  3972],
        [10673,  2175],
        [22933, 27044],
        [ 5197, 15052],
        [ 2173, 10611],
        [15077, 32875],
        [13537, 26564],
        [19186, 12046],
        [ 9703, 11146],
        [ 5108,  3511],
        [ 7206,  2478],
        [26787, 23375],
        [ 3014,  4912],
        [ 9589,  4451],
        [ 1934,  2951],
        [ 2398, 10044],
        [ 2778, 13957],
        [ 6803,  7540],
        [ 7350,  1493],
        [12337,  2383],
        [22749,  6414]])


ant_neg = run_negative_extraction(model_zero, ant_test, synonym=False)
tl = torch.empty((0,))
tr = torch.empty((0,))
for pair in ant_test:
    left_tensor = torch.tensor(ant_neg[pair[0].item()])
    tl = torch.cat((tl, left_tensor.unsqueeze(0)), 0)
    
tl
# Out:
# tensor([22749.,  3473.,  5108., 16294., 13957., 29953.,  7350.,  3892.,  2175.,
#         13537., 13234.,  8790., 17960.,  8790.,  5254.,  5197.,  8790., 10783.,
#          7656., 32875.,  6753.,  5690., 23013., 13254., 12221.,  2079., 26787.,
#          1934., 20597., 28439.,  4351., 29953., 15458.,  5690., 12221.,  4048.,
#          6069.,  3972.,  7656.,  2079.,  5969., 10611., 13584.,  9589.,  3020.,
#         13537., 22749., 27044., 15458.,  3020., 23704., 13584.,  1750., 20812.,
#           741.,  4351., 14343.,  5690., 17960.,  4867.,  9053.,  2303.,  9228.,
#          5197.])

# %% [markdown]
# #### 4.4 Évaluation du modèle de zéro et comparaison avec GloVe (5 points)
#
# Comparez le modèle de zéro après l'entraînement à GloVe (résultat de la partie 2.4) en termes de corrélation de Spearman sur le jeu de validation. Quelle méthode est la plus performante ? Pourquoi ?

# %% [markdown]
# ### 5. Intérêt de GloVe (18 Points)
#
# Dans la section précédente, nous avons entraîné un modèle de zéro.
#
# Nous allons maintenant évaluer si initialiser le modèle avec les plongements de GloVe permet d'améliorer les performances.

# %% [markdown]
# #### 5.1 Initialisation avec GloVe (6 points)
#
# Entraînez le modèle `model_fine_tuned`, mais cette fois en ititialisant directement avec les plongements du modèle pré-entraîné GloVe.
#
# On utilisera Adam comme optimiseur.

# %%
# TODO
model_fine_tuned = ContrastiveWordEmbeddingModel(glove_embeddings,device=device)
optimizer = optim.Adam(model_fine_tuned.parameters(), lr=LEARNING_RATE)

# %%
spearman_corr = evaluate(model_fine_tuned, evaluation_simlex, glove_word_to_index)
print(f'Before training, Spearman Correlation: {spearman_corr:.4f}')

# TODO
losses = []
spearman_corrList = []
for epoch in tqdm(range(NUM_EPOCHS), desc="epoch"):
    model_fine_tuned.train()
    temp_losses = 0
    for syn, ant in tqdm(zip(syn_data_loader, ant_data_loader), desc="dataloaders"):
        #print(syn)
        
        
        loss = forward(model_fine_tuned, syn, ant)
        
        optimizer.zero_grad()
        
        
        loss.backward()
        temp_losses += loss
        
        optimizer.step()

    
    losses.append((temp_losses/(len(syn_data_loader)+len(ant_data_loader))).item())
    spearman_corr = evaluate(model_fine_tuned, evaluation_simlex, glove_word_to_index)
    spearman_corrList += [evaluate(model_fine_tuned,evaluation_simlex,glove_word_to_index)]


spearman_corr = evaluate(model_fine_tuned, evaluation_simlex, glove_word_to_index)
print(f'After training, Spearman Correlation: {spearman_corrList[-1]:.4f}')
print(f'After training, Spearman Correlation: {spearman_corr:.4f}')
# END TODO
# Out:
# Before training, Spearman Correlation: 0.2923
# epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.23it/s]
# dataloaders: 2it [00:00,  4.91it/s]
# dataloaders: 3it [00:00,  5.18it/s]
# dataloaders: 4it [00:00,  5.35it/s]
# dataloaders: 5it [00:00,  5.31it/s]
# dataloaders: 6it [00:01,  5.30it/s]
# dataloaders: 7it [00:01,  5.30it/s]
# dataloaders: 8it [00:01,  5.40it/s]
# dataloaders: 9it [00:01,  5.39it/s]
# dataloaders: 10it [00:01,  5.40it/s]
# dataloaders: 11it [00:02,  5.47it/s]
# dataloaders: 12it [00:02,  5.51it/s]
# dataloaders: 13it [00:02,  5.54it/s]
# dataloaders: 14it [00:02,  5.55it/s]
# dataloaders: 15it [00:02,  5.57it/s]
# dataloaders: 16it [00:02,  5.57it/s]
# dataloaders: 17it [00:03,  5.57it/s]
# dataloaders: 18it [00:03,  5.55it/s]
# dataloaders: 19it [00:03,  5.51it/s]
# dataloaders: 20it [00:03,  5.49it/s]
# dataloaders: 21it [00:03,  5.54it/s]
# dataloaders: 22it [00:04,  5.57it/s]
# dataloaders: 23it [00:04,  5.58it/s]
# dataloaders: 24it [00:04,  5.45it/s]
# dataloaders: 25it [00:04,  5.41it/s]
# dataloaders: 26it [00:04,  5.45it/s]
# dataloaders: 27it [00:04,  5.45it/s]
# dataloaders: 28it [00:05,  5.45it/s]
# dataloaders: 29it [00:05,  5.46it/s]
# dataloaders: 30it [00:05,  5.48it/s]
# dataloaders: 31it [00:05,  5.45it/s]
# dataloaders: 32it [00:05,  5.28it/s]
# dataloaders: 33it [00:06,  5.23it/s]
# dataloaders: 34it [00:06,  5.33it/s]
# dataloaders: 35it [00:06,  5.42it/s]
# dataloaders: 36it [00:06,  5.48it/s]
# dataloaders: 37it [00:06,  5.35it/s]
# dataloaders: 38it [00:07,  5.43it/s]
# dataloaders: 39it [00:07,  5.44it/s]
# dataloaders: 40it [00:07,  5.47it/s]
# dataloaders: 41it [00:07,  5.50it/s]
# dataloaders: 42it [00:07,  5.52it/s]
# dataloaders: 43it [00:07,  5.46it/s]
# dataloaders: 44it [00:08,  5.50it/s]
# dataloaders: 45it [00:08,  5.52it/s]
# dataloaders: 46it [00:08,  4.83it/s]
# dataloaders: 47it [00:08,  4.88it/s]
# dataloaders: 48it [00:08,  5.07it/s]
# dataloaders: 49it [00:09,  5.16it/s]
# dataloaders: 50it [00:09,  5.27it/s]
# dataloaders: 51it [00:09,  5.37it/s]
# dataloaders: 52it [00:09,  5.37it/s]
# dataloaders: 53it [00:09,  5.32it/s]
# dataloaders: 54it [00:10,  5.39it/s]
# dataloaders: 55it [00:10,  5.42it/s]
# dataloaders: 56it [00:10,  5.46it/s]
# dataloaders: 57it [00:10,  5.47it/s]
# dataloaders: 58it [00:10,  5.29it/s]
# dataloaders: 59it [00:11,  4.90it/s]
# dataloaders: 60it [00:11,  4.85it/s]
# dataloaders: 61it [00:11,  4.94it/s]
# dataloaders: 62it [00:11,  4.97it/s]
# dataloaders: 63it [00:11,  4.82it/s]
# dataloaders: 64it [00:12,  4.83it/s]
# dataloaders: 65it [00:12,  4.86it/s]
# dataloaders: 66it [00:12,  4.63it/s]
# dataloaders: 67it [00:12,  4.75it/s]
# dataloaders: 68it [00:12,  4.82it/s]
# dataloaders: 69it [00:13,  4.69it/s]
# dataloaders: 70it [00:13,  4.76it/s]
# dataloaders: 71it [00:13,  4.84it/s]
# dataloaders: 72it [00:13,  4.95it/s]
# dataloaders: 73it [00:13,  4.99it/s]
# dataloaders: 74it [00:14,  4.99it/s]
# dataloaders: 75it [00:14,  4.70it/s]
# dataloaders: 76it [00:14,  4.64it/s]
# dataloaders: 77it [00:14,  4.76it/s]
# dataloaders: 78it [00:14,  4.85it/s]
# dataloaders: 79it [00:15,  4.87it/s]
# dataloaders: 80it [00:15,  4.91it/s]
# dataloaders: 81it [00:15,  5.04it/s]
# dataloaders: 82it [00:15,  5.18it/s]
# dataloaders: 83it [00:15,  5.09it/s]
# dataloaders: 84it [00:16,  5.05it/s]
# dataloaders: 85it [00:16,  4.87it/s]
# dataloaders: 86it [00:16,  4.68it/s]
# dataloaders: 87it [00:16,  4.47it/s]
# dataloaders: 88it [00:17,  4.41it/s]
# dataloaders: 89it [00:17,  4.43it/s]
# dataloaders: 90it [00:17,  4.45it/s]
# dataloaders: 91it [00:17,  4.67it/s]
# dataloaders: 92it [00:17,  4.84it/s]
# dataloaders: 93it [00:18,  4.93it/s]
# dataloaders: 94it [00:18,  4.97it/s]
# dataloaders: 95it [00:18,  4.99it/s]
# dataloaders: 96it [00:18,  4.97it/s]
# dataloaders: 97it [00:18,  4.97it/s]
# dataloaders: 98it [00:19,  5.01it/s]
# dataloaders: 99it [00:19,  5.01it/s]
# dataloaders: 100it [00:19,  5.04it/s]
# dataloaders: 101it [00:19,  5.07it/s]
# dataloaders: 102it [00:19,  5.12it/s]
# dataloaders: 103it [00:20,  5.09it/s]
# dataloaders: 104it [00:20,  5.19it/s]
# dataloaders: 105it [00:20,  5.18it/s]
# dataloaders: 106it [00:20,  5.14it/s]
# dataloaders: 107it [00:20,  4.94it/s]
# dataloaders: 108it [00:21,  5.13it/s]
# dataloaders: 109it [00:21,  5.22it/s]
# dataloaders: 110it [00:21,  5.22it/s]
# dataloaders: 111it [00:21,  5.25it/s]
# dataloaders: 112it [00:21,  5.27it/s]
# dataloaders: 113it [00:21,  5.30it/s]
# dataloaders: 114it [00:22,  5.22it/s]
# dataloaders: 115it [00:22,  5.19it/s]
# dataloaders: 116it [00:22,  5.21it/s]
# dataloaders: 117it [00:22,  5.24it/s]
# dataloaders: 118it [00:22,  5.21it/s]
# dataloaders: 119it [00:23,  5.21it/s]
# dataloaders: 120it [00:23,  5.36it/s]
# dataloaders: 121it [00:23,  5.46it/s]
# dataloaders: 122it [00:23,  5.38it/s]
# dataloaders: 123it [00:23,  5.38it/s]
# dataloaders: 124it [00:24,  5.37it/s]
# dataloaders: 125it [00:24,  5.32it/s]
# dataloaders: 126it [00:24,  5.40it/s]
# dataloaders: 127it [00:24,  5.46it/s]
# dataloaders: 128it [00:24,  5.49it/s]
# dataloaders: 129it [00:24,  5.44it/s]
# dataloaders: 130it [00:25,  5.39it/s]
# dataloaders: 131it [00:25,  5.39it/s]
# dataloaders: 132it [00:25,  5.46it/s]
# dataloaders: 133it [00:25,  5.43it/s]
# dataloaders: 134it [00:25,  5.18it/s]
# dataloaders: 135it [00:26,  5.16it/s]
# dataloaders: 136it [00:26,  5.10it/s]
# dataloaders: 137it [00:26,  4.75it/s]
# dataloaders: 138it [00:26,  4.81it/s]
# dataloaders: 139it [00:26,  4.92it/s]
# dataloaders: 140it [00:27,  4.96it/s]
# dataloaders: 141it [00:27,  4.47it/s]
# dataloaders: 142it [00:27,  4.65it/s]
# dataloaders: 143it [00:27,  4.76it/s]
# dataloaders: 144it [00:28,  4.84it/s]
# dataloaders: 145it [00:28,  4.78it/s]
# dataloaders: 146it [00:28,  4.91it/s]
# dataloaders: 147it [00:28,  4.92it/s]
# dataloaders: 148it [00:28,  4.99it/s]
# dataloaders: 149it [00:29,  5.09it/s]
# dataloaders: 150it [00:29,  5.17it/s]
# dataloaders: 151it [00:29,  5.20it/s]
# dataloaders: 152it [00:29,  5.25it/s]
# dataloaders: 153it [00:29,  5.31it/s]
# dataloaders: 154it [00:29,  5.32it/s]
# dataloaders: 155it [00:30,  5.21it/s]
# dataloaders: 156it [00:30,  5.17it/s]
# dataloaders: 157it [00:30,  5.14it/s]
# dataloaders: 158it [00:30,  4.86it/s]
# dataloaders: 159it [00:30,  4.88it/s]
# dataloaders: 160it [00:31,  4.86it/s]
# dataloaders: 161it [00:31,  4.85it/s]
# dataloaders: 162it [00:31,  4.63it/s]
# dataloaders: 163it [00:31,  4.49it/s]
# dataloaders: 164it [00:32,  4.44it/s]
# dataloaders: 165it [00:32,  4.39it/s]
# dataloaders: 166it [00:32,  4.40it/s]
# dataloaders: 167it [00:32,  4.58it/s]
# dataloaders: 168it [00:32,  4.75it/s]
# dataloaders: 169it [00:33,  4.87it/s]
# dataloaders: 170it [00:33,  4.93it/s]
# dataloaders: 171it [00:33,  4.99it/s]
# dataloaders: 172it [00:33,  5.01it/s]
# dataloaders: 173it [00:33,  5.03it/s]
# dataloaders: 174it [00:34,  5.18it/s]
# dataloaders: 175it [00:34,  5.25it/s]
# dataloaders: 176it [00:34,  5.33it/s]
# dataloaders: 177it [00:34,  5.42it/s]
# dataloaders: 178it [00:34,  5.44it/s]
# dataloaders: 179it [00:35,  5.31it/s]
# dataloaders: 180it [00:35,  5.25it/s]
# dataloaders: 181it [00:35,  5.26it/s]
# dataloaders: 182it [00:35,  5.37it/s]
# dataloaders: 183it [00:35,  5.45it/s]
# dataloaders: 184it [00:35,  5.49it/s]
# dataloaders: 185it [00:36,  5.32it/s]
# dataloaders: 186it [00:36,  5.12it/s]
# epoch:   5%|▌         | 1/20 [00:36<11:35, 36.58s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.63it/s]
# dataloaders: 2it [00:00,  5.13it/s]
# dataloaders: 3it [00:00,  5.38it/s]
# dataloaders: 4it [00:00,  5.44it/s]
# dataloaders: 5it [00:00,  5.42it/s]
# dataloaders: 6it [00:01,  5.46it/s]
# dataloaders: 7it [00:01,  5.33it/s]
# dataloaders: 8it [00:01,  5.27it/s]
# dataloaders: 9it [00:01,  5.29it/s]
# dataloaders: 10it [00:01,  5.34it/s]
# dataloaders: 11it [00:02,  5.40it/s]
# dataloaders: 12it [00:02,  5.38it/s]
# dataloaders: 13it [00:02,  5.46it/s]
# dataloaders: 14it [00:02,  5.52it/s]
# dataloaders: 15it [00:02,  5.57it/s]
# dataloaders: 16it [00:02,  5.40it/s]
# dataloaders: 17it [00:03,  5.40it/s]
# dataloaders: 18it [00:03,  5.43it/s]
# dataloaders: 19it [00:03,  5.13it/s]
# dataloaders: 20it [00:03,  4.96it/s]
# dataloaders: 21it [00:03,  5.00it/s]
# dataloaders: 22it [00:04,  4.91it/s]
# dataloaders: 23it [00:04,  4.84it/s]
# dataloaders: 24it [00:04,  4.97it/s]
# dataloaders: 25it [00:04,  5.10it/s]
# dataloaders: 26it [00:04,  5.05it/s]
# dataloaders: 27it [00:05,  5.06it/s]
# dataloaders: 28it [00:05,  5.11it/s]
# dataloaders: 29it [00:05,  5.14it/s]
# dataloaders: 30it [00:05,  5.12it/s]
# dataloaders: 31it [00:05,  5.20it/s]
# dataloaders: 32it [00:06,  5.05it/s]
# dataloaders: 33it [00:06,  4.97it/s]
# dataloaders: 34it [00:06,  4.88it/s]
# dataloaders: 35it [00:06,  4.68it/s]
# dataloaders: 36it [00:07,  4.73it/s]
# dataloaders: 37it [00:07,  4.78it/s]
# dataloaders: 38it [00:07,  4.58it/s]
# dataloaders: 39it [00:07,  4.64it/s]
# dataloaders: 40it [00:07,  4.79it/s]
# dataloaders: 41it [00:08,  4.80it/s]
# dataloaders: 42it [00:08,  4.87it/s]
# dataloaders: 43it [00:08,  4.96it/s]
# dataloaders: 44it [00:08,  4.99it/s]
# dataloaders: 45it [00:08,  5.07it/s]
# dataloaders: 46it [00:09,  5.12it/s]
# dataloaders: 47it [00:09,  5.18it/s]
# dataloaders: 48it [00:09,  5.13it/s]
# dataloaders: 49it [00:09,  5.06it/s]
# dataloaders: 50it [00:09,  4.99it/s]
# dataloaders: 51it [00:10,  5.06it/s]
# dataloaders: 52it [00:10,  5.04it/s]
# dataloaders: 53it [00:10,  5.02it/s]
# dataloaders: 54it [00:10,  4.99it/s]
# dataloaders: 55it [00:10,  5.06it/s]
# dataloaders: 56it [00:11,  5.10it/s]
# dataloaders: 57it [00:11,  5.21it/s]
# dataloaders: 58it [00:11,  5.33it/s]
# dataloaders: 59it [00:11,  5.45it/s]
# dataloaders: 60it [00:11,  5.56it/s]
# dataloaders: 61it [00:11,  5.55it/s]
# dataloaders: 62it [00:12,  5.60it/s]
# dataloaders: 63it [00:12,  5.66it/s]
# dataloaders: 64it [00:12,  5.62it/s]
# dataloaders: 65it [00:12,  5.66it/s]
# dataloaders: 66it [00:12,  5.49it/s]
# dataloaders: 67it [00:12,  5.42it/s]
# dataloaders: 68it [00:13,  5.30it/s]
# dataloaders: 69it [00:13,  5.25it/s]
# dataloaders: 70it [00:13,  5.20it/s]
# dataloaders: 71it [00:13,  5.20it/s]
# dataloaders: 72it [00:13,  5.13it/s]
# dataloaders: 73it [00:14,  4.93it/s]
# dataloaders: 74it [00:14,  4.97it/s]
# dataloaders: 75it [00:14,  4.96it/s]
# dataloaders: 76it [00:14,  4.99it/s]
# dataloaders: 77it [00:14,  5.05it/s]
# dataloaders: 78it [00:15,  5.21it/s]
# dataloaders: 79it [00:15,  5.04it/s]
# dataloaders: 80it [00:15,  5.13it/s]
# dataloaders: 81it [00:15,  5.23it/s]
# dataloaders: 82it [00:15,  5.21it/s]
# dataloaders: 83it [00:16,  5.17it/s]
# dataloaders: 84it [00:16,  5.34it/s]
# dataloaders: 85it [00:16,  5.28it/s]
# dataloaders: 86it [00:16,  5.33it/s]
# dataloaders: 87it [00:16,  5.20it/s]
# dataloaders: 88it [00:17,  5.07it/s]
# dataloaders: 89it [00:17,  5.05it/s]
# dataloaders: 90it [00:17,  5.04it/s]
# dataloaders: 91it [00:17,  5.14it/s]
# dataloaders: 92it [00:17,  5.23it/s]
# dataloaders: 93it [00:18,  5.28it/s]
# dataloaders: 94it [00:18,  5.34it/s]
# dataloaders: 95it [00:18,  5.38it/s]
# dataloaders: 96it [00:18,  5.14it/s]
# dataloaders: 97it [00:18,  5.11it/s]
# dataloaders: 98it [00:19,  5.23it/s]
# dataloaders: 99it [00:19,  5.35it/s]
# dataloaders: 100it [00:19,  5.37it/s]
# dataloaders: 101it [00:19,  5.36it/s]
# dataloaders: 102it [00:19,  5.41it/s]
# dataloaders: 103it [00:19,  5.41it/s]
# dataloaders: 104it [00:20,  5.40it/s]
# dataloaders: 105it [00:20,  5.35it/s]
# dataloaders: 106it [00:20,  5.39it/s]
# dataloaders: 107it [00:20,  5.35it/s]
# dataloaders: 108it [00:20,  5.16it/s]
# dataloaders: 109it [00:21,  5.09it/s]
# dataloaders: 110it [00:21,  5.14it/s]
# dataloaders: 111it [00:21,  5.25it/s]
# dataloaders: 112it [00:21,  5.31it/s]
# dataloaders: 113it [00:21,  5.31it/s]
# dataloaders: 114it [00:22,  5.38it/s]
# dataloaders: 115it [00:22,  5.45it/s]
# dataloaders: 116it [00:22,  5.53it/s]
# dataloaders: 117it [00:22,  5.47it/s]
# dataloaders: 118it [00:22,  5.21it/s]
# dataloaders: 119it [00:22,  5.08it/s]
# dataloaders: 120it [00:23,  5.04it/s]
# dataloaders: 121it [00:23,  5.09it/s]
# dataloaders: 122it [00:23,  5.13it/s]
# dataloaders: 123it [00:23,  5.22it/s]
# dataloaders: 124it [00:23,  5.21it/s]
# dataloaders: 125it [00:24,  5.17it/s]
# dataloaders: 126it [00:24,  5.12it/s]
# dataloaders: 127it [00:24,  5.16it/s]
# dataloaders: 128it [00:24,  5.08it/s]
# dataloaders: 129it [00:24,  5.09it/s]
# dataloaders: 130it [00:25,  4.91it/s]
# dataloaders: 131it [00:25,  5.02it/s]
# dataloaders: 132it [00:25,  4.89it/s]
# dataloaders: 133it [00:25,  4.77it/s]
# dataloaders: 134it [00:25,  4.85it/s]
# dataloaders: 135it [00:26,  4.87it/s]
# dataloaders: 136it [00:26,  4.71it/s]
# dataloaders: 137it [00:26,  4.65it/s]
# dataloaders: 138it [00:26,  4.66it/s]
# dataloaders: 139it [00:27,  4.78it/s]
# dataloaders: 140it [00:27,  4.96it/s]
# dataloaders: 141it [00:27,  5.12it/s]
# dataloaders: 142it [00:27,  4.50it/s]
# dataloaders: 143it [00:27,  4.49it/s]
# dataloaders: 144it [00:28,  4.37it/s]
# dataloaders: 145it [00:28,  4.64it/s]
# dataloaders: 146it [00:28,  4.89it/s]
# dataloaders: 147it [00:28,  5.02it/s]
# dataloaders: 148it [00:28,  5.16it/s]
# dataloaders: 149it [00:29,  5.29it/s]
# dataloaders: 150it [00:29,  5.37it/s]
# dataloaders: 151it [00:29,  5.45it/s]
# dataloaders: 152it [00:29,  5.40it/s]
# dataloaders: 153it [00:29,  5.47it/s]
# dataloaders: 154it [00:29,  5.43it/s]
# dataloaders: 155it [00:30,  5.38it/s]
# dataloaders: 156it [00:30,  5.34it/s]
# dataloaders: 157it [00:30,  5.33it/s]
# dataloaders: 158it [00:30,  5.19it/s]
# dataloaders: 159it [00:30,  5.24it/s]
# dataloaders: 160it [00:31,  5.19it/s]
# dataloaders: 161it [00:31,  5.13it/s]
# dataloaders: 162it [00:31,  4.95it/s]
# dataloaders: 163it [00:31,  5.03it/s]
# dataloaders: 164it [00:31,  5.02it/s]
# dataloaders: 165it [00:32,  5.11it/s]
# dataloaders: 166it [00:32,  5.01it/s]
# dataloaders: 167it [00:32,  4.98it/s]
# dataloaders: 168it [00:32,  5.11it/s]
# dataloaders: 169it [00:32,  5.21it/s]
# dataloaders: 170it [00:33,  5.21it/s]
# dataloaders: 171it [00:33,  5.22it/s]
# dataloaders: 172it [00:33,  5.21it/s]
# dataloaders: 173it [00:33,  5.26it/s]
# dataloaders: 174it [00:33,  5.32it/s]
# dataloaders: 175it [00:34,  5.30it/s]
# dataloaders: 176it [00:34,  5.08it/s]
# dataloaders: 177it [00:34,  4.69it/s]
# dataloaders: 178it [00:34,  4.70it/s]
# dataloaders: 179it [00:34,  4.70it/s]
# dataloaders: 180it [00:35,  4.38it/s]
# dataloaders: 181it [00:35,  3.93it/s]
# dataloaders: 182it [00:35,  4.02it/s]
# dataloaders: 183it [00:35,  4.32it/s]
# dataloaders: 184it [00:36,  4.52it/s]
# dataloaders: 185it [00:36,  4.36it/s]
# dataloaders: 186it [00:36,  5.08it/s]
# epoch:  10%|█         | 2/20 [01:13<11:01, 36.75s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  3.85it/s]
# dataloaders: 2it [00:00,  4.38it/s]
# dataloaders: 3it [00:00,  4.56it/s]
# dataloaders: 4it [00:00,  4.46it/s]
# dataloaders: 5it [00:01,  4.44it/s]
# dataloaders: 6it [00:01,  4.53it/s]
# dataloaders: 7it [00:01,  4.71it/s]
# dataloaders: 8it [00:01,  4.56it/s]
# dataloaders: 9it [00:02,  4.52it/s]
# dataloaders: 10it [00:02,  4.38it/s]
# dataloaders: 11it [00:02,  4.39it/s]
# dataloaders: 12it [00:02,  4.45it/s]
# dataloaders: 13it [00:02,  4.58it/s]
# dataloaders: 14it [00:03,  4.57it/s]
# dataloaders: 15it [00:03,  4.41it/s]
# dataloaders: 16it [00:03,  4.50it/s]
# dataloaders: 17it [00:03,  4.59it/s]
# dataloaders: 18it [00:03,  4.62it/s]
# dataloaders: 19it [00:04,  4.68it/s]
# dataloaders: 20it [00:04,  4.12it/s]
# dataloaders: 21it [00:04,  4.21it/s]
# dataloaders: 22it [00:04,  4.33it/s]
# dataloaders: 23it [00:05,  4.45it/s]
# dataloaders: 24it [00:05,  4.60it/s]
# dataloaders: 25it [00:05,  4.82it/s]
# dataloaders: 26it [00:05,  4.83it/s]
# dataloaders: 27it [00:05,  4.85it/s]
# dataloaders: 28it [00:06,  4.97it/s]
# dataloaders: 29it [00:06,  4.99it/s]
# dataloaders: 30it [00:06,  4.86it/s]
# dataloaders: 31it [00:06,  4.86it/s]
# dataloaders: 32it [00:06,  4.90it/s]
# dataloaders: 33it [00:07,  5.05it/s]
# dataloaders: 34it [00:07,  5.10it/s]
# dataloaders: 35it [00:07,  5.19it/s]
# dataloaders: 36it [00:07,  5.11it/s]
# dataloaders: 37it [00:07,  5.20it/s]
# dataloaders: 38it [00:08,  5.21it/s]
# dataloaders: 39it [00:08,  5.20it/s]
# dataloaders: 40it [00:08,  5.01it/s]
# dataloaders: 41it [00:08,  4.93it/s]
# dataloaders: 42it [00:08,  4.97it/s]
# dataloaders: 43it [00:09,  4.85it/s]
# dataloaders: 44it [00:09,  4.80it/s]
# dataloaders: 45it [00:09,  4.77it/s]
# dataloaders: 46it [00:09,  4.92it/s]
# dataloaders: 47it [00:09,  4.75it/s]
# dataloaders: 48it [00:10,  4.83it/s]
# dataloaders: 49it [00:10,  5.07it/s]
# dataloaders: 50it [00:10,  5.16it/s]
# dataloaders: 51it [00:10,  5.22it/s]
# dataloaders: 52it [00:10,  5.19it/s]
# dataloaders: 53it [00:11,  5.07it/s]
# dataloaders: 54it [00:11,  5.13it/s]
# dataloaders: 55it [00:11,  5.11it/s]
# dataloaders: 56it [00:11,  5.02it/s]
# dataloaders: 57it [00:11,  5.10it/s]
# dataloaders: 58it [00:12,  5.05it/s]
# dataloaders: 59it [00:12,  4.97it/s]
# dataloaders: 60it [00:12,  5.07it/s]
# dataloaders: 61it [00:12,  5.17it/s]
# dataloaders: 62it [00:12,  5.21it/s]
# dataloaders: 63it [00:13,  5.17it/s]
# dataloaders: 64it [00:13,  5.00it/s]
# dataloaders: 65it [00:13,  4.74it/s]
# dataloaders: 66it [00:13,  4.61it/s]
# dataloaders: 67it [00:13,  4.80it/s]
# dataloaders: 68it [00:14,  5.01it/s]
# dataloaders: 69it [00:14,  5.20it/s]
# dataloaders: 70it [00:14,  5.25it/s]
# dataloaders: 71it [00:14,  5.20it/s]
# dataloaders: 72it [00:14,  5.09it/s]
# dataloaders: 73it [00:15,  5.16it/s]
# dataloaders: 74it [00:15,  5.28it/s]
# dataloaders: 75it [00:15,  5.28it/s]
# dataloaders: 76it [00:15,  5.28it/s]
# dataloaders: 77it [00:15,  5.35it/s]
# dataloaders: 78it [00:15,  5.45it/s]
# dataloaders: 79it [00:16,  5.32it/s]
# dataloaders: 80it [00:16,  5.25it/s]
# dataloaders: 81it [00:16,  5.24it/s]
# dataloaders: 82it [00:16,  5.32it/s]
# dataloaders: 83it [00:16,  5.27it/s]
# dataloaders: 84it [00:17,  5.36it/s]
# dataloaders: 85it [00:17,  5.33it/s]
# dataloaders: 86it [00:17,  4.98it/s]
# dataloaders: 87it [00:17,  4.71it/s]
# dataloaders: 88it [00:18,  4.39it/s]
# dataloaders: 89it [00:18,  4.51it/s]
# dataloaders: 90it [00:18,  4.62it/s]
# dataloaders: 91it [00:18,  4.71it/s]
# dataloaders: 92it [00:18,  4.68it/s]
# dataloaders: 93it [00:19,  4.56it/s]
# dataloaders: 94it [00:19,  4.40it/s]
# dataloaders: 95it [00:19,  4.53it/s]
# dataloaders: 96it [00:19,  4.51it/s]
# dataloaders: 97it [00:19,  4.71it/s]
# dataloaders: 98it [00:20,  4.75it/s]
# dataloaders: 99it [00:20,  4.80it/s]
# dataloaders: 100it [00:20,  4.85it/s]
# dataloaders: 101it [00:20,  4.88it/s]
# dataloaders: 102it [00:21,  4.91it/s]
# dataloaders: 103it [00:21,  5.06it/s]
# dataloaders: 104it [00:21,  5.12it/s]
# dataloaders: 105it [00:21,  5.25it/s]
# dataloaders: 106it [00:21,  5.20it/s]
# dataloaders: 107it [00:21,  5.24it/s]
# dataloaders: 108it [00:22,  5.29it/s]
# dataloaders: 109it [00:22,  5.26it/s]
# dataloaders: 110it [00:22,  5.14it/s]
# dataloaders: 111it [00:22,  5.10it/s]
# dataloaders: 112it [00:22,  5.07it/s]
# dataloaders: 113it [00:23,  4.99it/s]
# dataloaders: 114it [00:23,  5.02it/s]
# dataloaders: 115it [00:23,  5.15it/s]
# dataloaders: 116it [00:23,  5.18it/s]
# dataloaders: 117it [00:23,  5.20it/s]
# dataloaders: 118it [00:24,  5.23it/s]
# dataloaders: 119it [00:24,  5.27it/s]
# dataloaders: 120it [00:24,  5.35it/s]
# dataloaders: 121it [00:24,  5.23it/s]
# dataloaders: 122it [00:24,  5.19it/s]
# dataloaders: 123it [00:25,  5.10it/s]
# dataloaders: 124it [00:25,  4.94it/s]
# dataloaders: 125it [00:25,  4.96it/s]
# dataloaders: 126it [00:25,  4.98it/s]
# dataloaders: 127it [00:25,  5.02it/s]
# dataloaders: 128it [00:26,  5.00it/s]
# dataloaders: 129it [00:26,  5.05it/s]
# dataloaders: 130it [00:26,  4.98it/s]
# dataloaders: 131it [00:26,  4.72it/s]
# dataloaders: 132it [00:26,  4.71it/s]
# dataloaders: 133it [00:27,  4.73it/s]
# dataloaders: 134it [00:27,  4.78it/s]
# dataloaders: 135it [00:27,  4.91it/s]
# dataloaders: 136it [00:27,  5.01it/s]
# dataloaders: 137it [00:27,  5.12it/s]
# dataloaders: 138it [00:28,  5.20it/s]
# dataloaders: 139it [00:28,  5.31it/s]
# dataloaders: 140it [00:28,  5.40it/s]
# dataloaders: 141it [00:28,  5.38it/s]
# dataloaders: 142it [00:28,  5.46it/s]
# dataloaders: 143it [00:28,  5.50it/s]
# dataloaders: 144it [00:29,  5.52it/s]
# dataloaders: 145it [00:29,  5.41it/s]
# dataloaders: 146it [00:29,  5.42it/s]
# dataloaders: 147it [00:29,  5.52it/s]
# dataloaders: 148it [00:29,  5.51it/s]
# dataloaders: 149it [00:30,  5.49it/s]
# dataloaders: 150it [00:30,  5.28it/s]
# dataloaders: 151it [00:30,  5.03it/s]
# dataloaders: 152it [00:30,  5.14it/s]
# dataloaders: 153it [00:30,  5.26it/s]
# dataloaders: 154it [00:31,  5.22it/s]
# dataloaders: 155it [00:31,  5.16it/s]
# dataloaders: 156it [00:31,  5.24it/s]
# dataloaders: 157it [00:31,  5.13it/s]
# dataloaders: 158it [00:31,  5.04it/s]
# dataloaders: 159it [00:32,  4.83it/s]
# dataloaders: 160it [00:32,  5.04it/s]
# dataloaders: 161it [00:32,  5.22it/s]
# dataloaders: 162it [00:32,  5.38it/s]
# dataloaders: 163it [00:32,  5.50it/s]
# dataloaders: 164it [00:32,  5.56it/s]
# dataloaders: 165it [00:33,  5.62it/s]
# dataloaders: 166it [00:33,  5.64it/s]
# dataloaders: 167it [00:33,  5.66it/s]
# dataloaders: 168it [00:33,  5.60it/s]
# dataloaders: 169it [00:33,  5.44it/s]
# dataloaders: 170it [00:34,  5.47it/s]
# dataloaders: 171it [00:34,  5.46it/s]
# dataloaders: 172it [00:34,  5.43it/s]
# dataloaders: 173it [00:34,  5.39it/s]
# dataloaders: 174it [00:34,  5.34it/s]
# dataloaders: 175it [00:34,  5.22it/s]
# dataloaders: 176it [00:35,  5.21it/s]
# dataloaders: 177it [00:35,  5.10it/s]
# dataloaders: 178it [00:35,  4.95it/s]
# dataloaders: 179it [00:35,  5.03it/s]
# dataloaders: 180it [00:35,  5.03it/s]
# dataloaders: 181it [00:36,  4.87it/s]
# dataloaders: 182it [00:36,  4.87it/s]
# dataloaders: 183it [00:36,  4.80it/s]
# dataloaders: 184it [00:36,  4.80it/s]
# dataloaders: 185it [00:37,  4.80it/s]
# dataloaders: 186it [00:37,  4.99it/s]
# epoch:  15%|█▌        | 3/20 [01:51<10:31, 37.13s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.61it/s]
# dataloaders: 2it [00:00,  4.99it/s]
# dataloaders: 3it [00:00,  5.15it/s]
# dataloaders: 4it [00:00,  5.21it/s]
# dataloaders: 5it [00:00,  5.06it/s]
# dataloaders: 6it [00:01,  4.99it/s]
# dataloaders: 7it [00:01,  4.97it/s]
# dataloaders: 8it [00:01,  5.00it/s]
# dataloaders: 9it [00:01,  5.10it/s]
# dataloaders: 10it [00:01,  5.20it/s]
# dataloaders: 11it [00:02,  5.14it/s]
# dataloaders: 12it [00:02,  5.10it/s]
# dataloaders: 13it [00:02,  4.99it/s]
# dataloaders: 14it [00:02,  4.97it/s]
# dataloaders: 15it [00:02,  4.95it/s]
# dataloaders: 16it [00:03,  5.07it/s]
# dataloaders: 17it [00:03,  5.22it/s]
# dataloaders: 18it [00:03,  5.29it/s]
# dataloaders: 19it [00:03,  5.42it/s]
# dataloaders: 20it [00:03,  5.40it/s]
# dataloaders: 21it [00:04,  5.22it/s]
# dataloaders: 22it [00:04,  5.08it/s]
# dataloaders: 23it [00:04,  5.18it/s]
# dataloaders: 24it [00:04,  5.24it/s]
# dataloaders: 25it [00:04,  5.16it/s]
# dataloaders: 26it [00:05,  4.83it/s]
# dataloaders: 27it [00:05,  4.62it/s]
# dataloaders: 28it [00:05,  4.47it/s]
# dataloaders: 29it [00:05,  4.51it/s]
# dataloaders: 30it [00:06,  4.51it/s]
# dataloaders: 31it [00:06,  4.68it/s]
# dataloaders: 32it [00:06,  4.67it/s]
# dataloaders: 33it [00:06,  4.67it/s]
# dataloaders: 34it [00:06,  4.68it/s]
# dataloaders: 35it [00:07,  4.72it/s]
# dataloaders: 36it [00:07,  4.72it/s]
# dataloaders: 37it [00:07,  4.50it/s]
# dataloaders: 38it [00:07,  4.57it/s]
# dataloaders: 39it [00:07,  4.63it/s]
# dataloaders: 40it [00:08,  4.69it/s]
# dataloaders: 41it [00:08,  4.71it/s]
# dataloaders: 42it [00:08,  4.73it/s]
# dataloaders: 43it [00:08,  4.69it/s]
# dataloaders: 44it [00:08,  4.87it/s]
# dataloaders: 45it [00:09,  4.91it/s]
# dataloaders: 46it [00:09,  5.00it/s]
# dataloaders: 47it [00:09,  4.98it/s]
# dataloaders: 48it [00:09,  5.00it/s]
# dataloaders: 49it [00:09,  5.11it/s]
# dataloaders: 50it [00:10,  5.03it/s]
# dataloaders: 51it [00:10,  5.12it/s]
# dataloaders: 52it [00:10,  5.22it/s]
# dataloaders: 53it [00:10,  5.23it/s]
# dataloaders: 54it [00:10,  5.09it/s]
# dataloaders: 55it [00:11,  5.00it/s]
# dataloaders: 56it [00:11,  4.97it/s]
# dataloaders: 57it [00:11,  4.98it/s]
# dataloaders: 58it [00:11,  4.87it/s]
# dataloaders: 59it [00:11,  4.72it/s]
# dataloaders: 60it [00:12,  4.66it/s]
# dataloaders: 61it [00:12,  4.65it/s]
# dataloaders: 62it [00:12,  4.72it/s]
# dataloaders: 63it [00:12,  4.82it/s]
# dataloaders: 64it [00:13,  4.91it/s]
# dataloaders: 65it [00:13,  4.98it/s]
# dataloaders: 66it [00:13,  5.04it/s]
# dataloaders: 67it [00:13,  5.07it/s]
# dataloaders: 68it [00:13,  5.07it/s]
# dataloaders: 69it [00:14,  5.08it/s]
# dataloaders: 70it [00:14,  4.96it/s]
# dataloaders: 71it [00:14,  4.99it/s]
# dataloaders: 72it [00:14,  4.98it/s]
# dataloaders: 73it [00:14,  4.73it/s]
# dataloaders: 74it [00:15,  4.67it/s]
# dataloaders: 75it [00:15,  4.59it/s]
# dataloaders: 76it [00:15,  4.69it/s]
# dataloaders: 77it [00:15,  4.78it/s]
# dataloaders: 78it [00:15,  4.91it/s]
# dataloaders: 79it [00:16,  4.95it/s]
# dataloaders: 80it [00:16,  4.98it/s]
# dataloaders: 81it [00:16,  5.08it/s]
# dataloaders: 82it [00:16,  5.15it/s]
# dataloaders: 83it [00:16,  4.91it/s]
# dataloaders: 84it [00:17,  4.77it/s]
# dataloaders: 85it [00:17,  4.66it/s]
# dataloaders: 86it [00:17,  4.67it/s]
# dataloaders: 87it [00:17,  4.57it/s]
# dataloaders: 88it [00:18,  4.43it/s]
# dataloaders: 89it [00:18,  4.28it/s]
# dataloaders: 90it [00:18,  4.33it/s]
# dataloaders: 91it [00:18,  3.78it/s]
# dataloaders: 92it [00:19,  4.03it/s]
# dataloaders: 93it [00:19,  4.34it/s]
# dataloaders: 94it [00:19,  4.48it/s]
# dataloaders: 95it [00:19,  4.59it/s]
# dataloaders: 96it [00:19,  4.70it/s]
# dataloaders: 97it [00:20,  4.83it/s]
# dataloaders: 98it [00:20,  4.91it/s]
# dataloaders: 99it [00:20,  4.98it/s]
# dataloaders: 100it [00:20,  5.11it/s]
# dataloaders: 101it [00:20,  5.12it/s]
# dataloaders: 102it [00:21,  5.09it/s]
# dataloaders: 103it [00:21,  4.93it/s]
# dataloaders: 104it [00:21,  4.89it/s]
# dataloaders: 105it [00:21,  4.90it/s]
# dataloaders: 106it [00:21,  4.92it/s]
# dataloaders: 107it [00:22,  5.01it/s]
# dataloaders: 108it [00:22,  5.04it/s]
# dataloaders: 109it [00:22,  5.04it/s]
# dataloaders: 110it [00:22,  4.97it/s]
# dataloaders: 111it [00:22,  5.04it/s]
# dataloaders: 112it [00:23,  5.18it/s]
# dataloaders: 113it [00:23,  5.28it/s]
# dataloaders: 114it [00:23,  5.30it/s]
# dataloaders: 115it [00:23,  5.29it/s]
# dataloaders: 116it [00:23,  5.16it/s]
# dataloaders: 117it [00:23,  5.20it/s]
# dataloaders: 118it [00:24,  5.17it/s]
# dataloaders: 119it [00:24,  5.05it/s]
# dataloaders: 120it [00:24,  5.00it/s]
# dataloaders: 121it [00:24,  4.96it/s]
# dataloaders: 122it [00:24,  4.99it/s]
# dataloaders: 123it [00:25,  5.03it/s]
# dataloaders: 124it [00:25,  4.97it/s]
# dataloaders: 125it [00:25,  4.84it/s]
# dataloaders: 126it [00:25,  4.84it/s]
# dataloaders: 127it [00:26,  4.91it/s]
# dataloaders: 128it [00:26,  5.02it/s]
# dataloaders: 129it [00:26,  5.11it/s]
# dataloaders: 130it [00:26,  5.21it/s]
# dataloaders: 131it [00:26,  5.33it/s]
# dataloaders: 132it [00:26,  5.39it/s]
# dataloaders: 133it [00:27,  5.43it/s]
# dataloaders: 134it [00:27,  5.33it/s]
# dataloaders: 135it [00:27,  5.39it/s]
# dataloaders: 136it [00:27,  5.24it/s]
# dataloaders: 137it [00:27,  5.10it/s]
# dataloaders: 138it [00:28,  4.99it/s]
# dataloaders: 139it [00:28,  4.90it/s]
# dataloaders: 140it [00:28,  4.89it/s]
# dataloaders: 141it [00:28,  4.80it/s]
# dataloaders: 142it [00:28,  4.88it/s]
# dataloaders: 143it [00:29,  5.03it/s]
# dataloaders: 144it [00:29,  4.35it/s]
# dataloaders: 145it [00:29,  4.54it/s]
# dataloaders: 146it [00:29,  4.75it/s]
# dataloaders: 147it [00:29,  4.93it/s]
# dataloaders: 148it [00:30,  4.89it/s]
# dataloaders: 149it [00:30,  4.80it/s]
# dataloaders: 150it [00:30,  4.79it/s]
# dataloaders: 151it [00:30,  4.75it/s]
# dataloaders: 152it [00:31,  4.80it/s]
# dataloaders: 153it [00:31,  4.82it/s]
# dataloaders: 154it [00:31,  4.87it/s]
# dataloaders: 155it [00:31,  5.04it/s]
# dataloaders: 156it [00:31,  5.13it/s]
# dataloaders: 157it [00:31,  5.30it/s]
# dataloaders: 158it [00:32,  5.40it/s]
# dataloaders: 159it [00:32,  5.30it/s]
# dataloaders: 160it [00:32,  5.35it/s]
# dataloaders: 161it [00:32,  5.32it/s]
# dataloaders: 162it [00:32,  5.36it/s]
# dataloaders: 163it [00:33,  5.36it/s]
# dataloaders: 164it [00:33,  5.34it/s]
# dataloaders: 165it [00:33,  5.42it/s]
# dataloaders: 166it [00:33,  5.47it/s]
# dataloaders: 167it [00:33,  5.48it/s]
# dataloaders: 168it [00:34,  5.56it/s]
# dataloaders: 169it [00:34,  5.45it/s]
# dataloaders: 170it [00:34,  5.44it/s]
# dataloaders: 171it [00:34,  5.46it/s]
# dataloaders: 172it [00:34,  5.47it/s]
# dataloaders: 173it [00:34,  5.45it/s]
# dataloaders: 174it [00:35,  5.49it/s]
# dataloaders: 175it [00:35,  5.53it/s]
# dataloaders: 176it [00:35,  5.59it/s]
# dataloaders: 177it [00:35,  5.54it/s]
# dataloaders: 178it [00:35,  5.61it/s]
# dataloaders: 179it [00:35,  5.64it/s]
# dataloaders: 180it [00:36,  5.65it/s]
# dataloaders: 181it [00:36,  5.63it/s]
# dataloaders: 182it [00:36,  5.37it/s]
# dataloaders: 183it [00:36,  5.18it/s]
# dataloaders: 184it [00:36,  5.21it/s]
# dataloaders: 185it [00:37,  5.05it/s]
# dataloaders: 186it [00:37,  4.98it/s]
# epoch:  20%|██        | 4/20 [02:28<09:57, 37.32s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.46it/s]
# dataloaders: 2it [00:00,  4.89it/s]
# dataloaders: 3it [00:00,  4.98it/s]
# dataloaders: 4it [00:00,  5.14it/s]
# dataloaders: 5it [00:00,  5.16it/s]
# dataloaders: 6it [00:01,  5.25it/s]
# dataloaders: 7it [00:01,  5.36it/s]
# dataloaders: 8it [00:01,  5.25it/s]
# dataloaders: 9it [00:01,  5.31it/s]
# dataloaders: 10it [00:01,  5.38it/s]
# dataloaders: 11it [00:02,  5.47it/s]
# dataloaders: 12it [00:02,  5.52it/s]
# dataloaders: 13it [00:02,  5.55it/s]
# dataloaders: 14it [00:02,  5.62it/s]
# dataloaders: 15it [00:02,  5.60it/s]
# dataloaders: 16it [00:02,  5.59it/s]
# dataloaders: 17it [00:03,  5.60it/s]
# dataloaders: 18it [00:03,  5.51it/s]
# dataloaders: 19it [00:03,  5.45it/s]
# dataloaders: 20it [00:03,  5.31it/s]
# dataloaders: 21it [00:03,  5.14it/s]
# dataloaders: 22it [00:04,  5.21it/s]
# dataloaders: 23it [00:04,  5.25it/s]
# dataloaders: 24it [00:04,  5.33it/s]
# dataloaders: 25it [00:04,  5.43it/s]
# dataloaders: 26it [00:04,  5.40it/s]
# dataloaders: 27it [00:05,  5.46it/s]
# dataloaders: 28it [00:05,  5.50it/s]
# dataloaders: 29it [00:05,  5.55it/s]
# dataloaders: 30it [00:05,  5.56it/s]
# dataloaders: 31it [00:05,  5.59it/s]
# dataloaders: 32it [00:05,  5.54it/s]
# dataloaders: 33it [00:06,  5.52it/s]
# dataloaders: 34it [00:06,  5.55it/s]
# dataloaders: 35it [00:06,  5.48it/s]
# dataloaders: 36it [00:06,  5.23it/s]
# dataloaders: 37it [00:06,  5.26it/s]
# dataloaders: 38it [00:07,  5.13it/s]
# dataloaders: 39it [00:07,  5.16it/s]
# dataloaders: 40it [00:07,  5.18it/s]
# dataloaders: 41it [00:07,  5.21it/s]
# dataloaders: 42it [00:07,  5.17it/s]
# dataloaders: 43it [00:08,  5.22it/s]
# dataloaders: 44it [00:08,  5.15it/s]
# dataloaders: 45it [00:08,  5.23it/s]
# dataloaders: 46it [00:08,  5.24it/s]
# dataloaders: 47it [00:08,  5.13it/s]
# dataloaders: 48it [00:09,  5.11it/s]
# dataloaders: 49it [00:09,  5.02it/s]
# dataloaders: 50it [00:09,  4.95it/s]
# dataloaders: 51it [00:09,  5.11it/s]
# dataloaders: 52it [00:09,  5.27it/s]
# dataloaders: 53it [00:09,  5.23it/s]
# dataloaders: 54it [00:10,  5.27it/s]
# dataloaders: 55it [00:10,  5.40it/s]
# dataloaders: 56it [00:10,  5.40it/s]
# dataloaders: 57it [00:10,  5.47it/s]
# dataloaders: 58it [00:10,  5.51it/s]
# dataloaders: 59it [00:11,  5.56it/s]
# dataloaders: 60it [00:11,  5.60it/s]
# dataloaders: 61it [00:11,  5.62it/s]
# dataloaders: 62it [00:11,  5.64it/s]
# dataloaders: 63it [00:11,  5.55it/s]
# dataloaders: 64it [00:11,  5.43it/s]
# dataloaders: 65it [00:12,  5.47it/s]
# dataloaders: 66it [00:12,  5.53it/s]
# dataloaders: 67it [00:12,  5.36it/s]
# dataloaders: 68it [00:12,  5.33it/s]
# dataloaders: 69it [00:12,  5.39it/s]
# dataloaders: 70it [00:13,  5.46it/s]
# dataloaders: 71it [00:13,  5.47it/s]
# dataloaders: 72it [00:13,  5.54it/s]
# dataloaders: 73it [00:13,  4.62it/s]
# dataloaders: 74it [00:13,  4.56it/s]
# dataloaders: 75it [00:14,  4.29it/s]
# dataloaders: 76it [00:14,  4.40it/s]
# dataloaders: 77it [00:14,  4.61it/s]
# dataloaders: 78it [00:14,  4.75it/s]
# dataloaders: 79it [00:15,  4.72it/s]
# dataloaders: 80it [00:15,  4.62it/s]
# dataloaders: 81it [00:15,  4.83it/s]
# dataloaders: 82it [00:15,  4.92it/s]
# dataloaders: 83it [00:15,  5.05it/s]
# dataloaders: 84it [00:16,  5.11it/s]
# dataloaders: 85it [00:16,  5.18it/s]
# dataloaders: 86it [00:16,  5.10it/s]
# dataloaders: 87it [00:16,  5.09it/s]
# dataloaders: 88it [00:16,  5.08it/s]
# dataloaders: 89it [00:17,  4.99it/s]
# dataloaders: 90it [00:17,  4.93it/s]
# dataloaders: 91it [00:17,  5.09it/s]
# dataloaders: 92it [00:17,  5.26it/s]
# dataloaders: 93it [00:17,  5.38it/s]
# dataloaders: 94it [00:17,  5.43it/s]
# dataloaders: 95it [00:18,  5.49it/s]
# dataloaders: 96it [00:18,  5.49it/s]
# dataloaders: 97it [00:18,  5.51it/s]
# dataloaders: 98it [00:18,  5.53it/s]
# dataloaders: 99it [00:18,  5.54it/s]
# dataloaders: 100it [00:19,  5.51it/s]
# dataloaders: 101it [00:19,  5.49it/s]
# dataloaders: 102it [00:19,  5.53it/s]
# dataloaders: 103it [00:19,  5.51it/s]
# dataloaders: 104it [00:19,  5.53it/s]
# dataloaders: 105it [00:19,  5.53it/s]
# dataloaders: 106it [00:20,  5.56it/s]
# dataloaders: 107it [00:20,  5.51it/s]
# dataloaders: 108it [00:20,  5.29it/s]
# dataloaders: 109it [00:20,  5.21it/s]
# dataloaders: 110it [00:20,  5.17it/s]
# dataloaders: 111it [00:21,  5.10it/s]
# dataloaders: 112it [00:21,  5.18it/s]
# dataloaders: 113it [00:21,  5.19it/s]
# dataloaders: 114it [00:21,  4.57it/s]
# dataloaders: 115it [00:21,  4.43it/s]
# dataloaders: 116it [00:22,  4.33it/s]
# dataloaders: 117it [00:22,  3.92it/s]
# dataloaders: 118it [00:22,  3.97it/s]
# dataloaders: 119it [00:23,  3.99it/s]
# dataloaders: 120it [00:23,  4.29it/s]
# dataloaders: 121it [00:23,  4.51it/s]
# dataloaders: 122it [00:23,  4.65it/s]
# dataloaders: 123it [00:23,  4.78it/s]
# dataloaders: 124it [00:24,  4.55it/s]
# dataloaders: 125it [00:24,  4.48it/s]
# dataloaders: 126it [00:24,  4.56it/s]
# dataloaders: 127it [00:24,  4.62it/s]
# dataloaders: 128it [00:24,  4.67it/s]
# dataloaders: 129it [00:25,  4.69it/s]
# dataloaders: 130it [00:25,  4.64it/s]
# dataloaders: 131it [00:25,  4.78it/s]
# dataloaders: 132it [00:25,  4.88it/s]
# dataloaders: 133it [00:25,  4.85it/s]
# dataloaders: 134it [00:26,  4.99it/s]
# dataloaders: 135it [00:26,  5.07it/s]
# dataloaders: 136it [00:26,  5.23it/s]
# dataloaders: 137it [00:26,  5.16it/s]
# dataloaders: 138it [00:26,  5.22it/s]
# dataloaders: 139it [00:27,  5.19it/s]
# dataloaders: 140it [00:27,  5.23it/s]
# dataloaders: 141it [00:27,  5.20it/s]
# dataloaders: 142it [00:27,  5.23it/s]
# dataloaders: 143it [00:27,  5.24it/s]
# dataloaders: 144it [00:28,  5.23it/s]
# dataloaders: 145it [00:28,  5.24it/s]
# dataloaders: 146it [00:28,  5.27it/s]
# dataloaders: 147it [00:28,  5.27it/s]
# dataloaders: 148it [00:28,  5.27it/s]
# dataloaders: 149it [00:28,  5.27it/s]
# dataloaders: 150it [00:29,  5.18it/s]
# dataloaders: 151it [00:29,  5.08it/s]
# dataloaders: 152it [00:29,  5.14it/s]
# dataloaders: 153it [00:29,  5.23it/s]
# dataloaders: 154it [00:29,  5.15it/s]
# dataloaders: 155it [00:30,  4.99it/s]
# dataloaders: 156it [00:30,  4.97it/s]
# dataloaders: 157it [00:30,  4.86it/s]
# dataloaders: 158it [00:31,  3.66it/s]
# dataloaders: 159it [00:31,  3.98it/s]
# dataloaders: 160it [00:31,  4.26it/s]
# dataloaders: 161it [00:31,  4.47it/s]
# dataloaders: 162it [00:31,  4.62it/s]
# dataloaders: 163it [00:32,  4.70it/s]
# dataloaders: 164it [00:32,  4.70it/s]
# dataloaders: 165it [00:32,  4.71it/s]
# dataloaders: 166it [00:32,  4.68it/s]
# dataloaders: 167it [00:32,  4.76it/s]
# dataloaders: 168it [00:33,  4.80it/s]
# dataloaders: 169it [00:33,  4.75it/s]
# dataloaders: 170it [00:33,  4.76it/s]
# dataloaders: 171it [00:33,  4.88it/s]
# dataloaders: 172it [00:33,  4.82it/s]
# dataloaders: 173it [00:34,  4.93it/s]
# dataloaders: 174it [00:34,  5.00it/s]
# dataloaders: 175it [00:34,  4.87it/s]
# dataloaders: 176it [00:34,  4.86it/s]
# dataloaders: 177it [00:34,  4.87it/s]
# dataloaders: 178it [00:35,  4.63it/s]
# dataloaders: 179it [00:35,  4.59it/s]
# dataloaders: 180it [00:35,  4.51it/s]
# dataloaders: 181it [00:35,  4.48it/s]
# dataloaders: 182it [00:36,  4.55it/s]
# dataloaders: 183it [00:36,  4.64it/s]
# dataloaders: 184it [00:36,  4.65it/s]
# dataloaders: 185it [00:36,  4.63it/s]
# dataloaders: 186it [00:36,  5.04it/s]
# epoch:  25%|██▌       | 5/20 [03:05<09:19, 37.27s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.21it/s]
# dataloaders: 2it [00:00,  4.44it/s]
# dataloaders: 3it [00:00,  4.35it/s]
# dataloaders: 4it [00:00,  4.34it/s]
# dataloaders: 5it [00:01,  4.30it/s]
# dataloaders: 6it [00:01,  3.07it/s]
# dataloaders: 7it [00:01,  3.38it/s]
# dataloaders: 8it [00:02,  3.62it/s]
# dataloaders: 9it [00:02,  3.84it/s]
# dataloaders: 10it [00:02,  3.93it/s]
# dataloaders: 11it [00:02,  3.74it/s]
# dataloaders: 12it [00:03,  3.82it/s]
# dataloaders: 13it [00:03,  4.03it/s]
# dataloaders: 14it [00:03,  4.04it/s]
# dataloaders: 15it [00:03,  4.19it/s]
# dataloaders: 16it [00:04,  4.26it/s]
# dataloaders: 17it [00:04,  4.28it/s]
# dataloaders: 18it [00:04,  4.22it/s]
# dataloaders: 19it [00:04,  4.13it/s]
# dataloaders: 20it [00:05,  4.22it/s]
# dataloaders: 21it [00:05,  4.34it/s]
# dataloaders: 22it [00:05,  4.39it/s]
# dataloaders: 23it [00:05,  4.54it/s]
# dataloaders: 24it [00:05,  4.68it/s]
# dataloaders: 25it [00:06,  4.80it/s]
# dataloaders: 26it [00:06,  4.96it/s]
# dataloaders: 27it [00:06,  4.99it/s]
# dataloaders: 28it [00:06,  4.97it/s]
# dataloaders: 29it [00:06,  4.99it/s]
# dataloaders: 30it [00:07,  5.05it/s]
# dataloaders: 31it [00:07,  4.82it/s]
# dataloaders: 32it [00:07,  4.84it/s]
# dataloaders: 33it [00:07,  4.81it/s]
# dataloaders: 34it [00:07,  4.86it/s]
# dataloaders: 35it [00:08,  4.91it/s]
# dataloaders: 36it [00:08,  4.93it/s]
# dataloaders: 37it [00:08,  4.93it/s]
# dataloaders: 38it [00:08,  4.89it/s]
# dataloaders: 39it [00:08,  4.99it/s]
# dataloaders: 40it [00:09,  5.01it/s]
# dataloaders: 41it [00:09,  4.97it/s]
# dataloaders: 42it [00:09,  4.74it/s]
# dataloaders: 43it [00:09,  4.84it/s]
# dataloaders: 44it [00:09,  4.86it/s]
# dataloaders: 45it [00:10,  4.83it/s]
# dataloaders: 46it [00:10,  4.93it/s]
# dataloaders: 47it [00:10,  4.98it/s]
# dataloaders: 48it [00:10,  5.05it/s]
# dataloaders: 49it [00:10,  5.04it/s]
# dataloaders: 50it [00:11,  5.07it/s]
# dataloaders: 51it [00:11,  5.09it/s]
# dataloaders: 52it [00:11,  4.31it/s]
# dataloaders: 53it [00:11,  4.51it/s]
# dataloaders: 54it [00:12,  4.52it/s]
# dataloaders: 55it [00:12,  4.64it/s]
# dataloaders: 56it [00:12,  4.71it/s]
# dataloaders: 57it [00:12,  4.76it/s]
# dataloaders: 58it [00:12,  4.87it/s]
# dataloaders: 59it [00:13,  4.97it/s]
# dataloaders: 60it [00:13,  5.04it/s]
# dataloaders: 61it [00:13,  5.05it/s]
# dataloaders: 62it [00:13,  4.98it/s]
# dataloaders: 63it [00:13,  5.02it/s]
# dataloaders: 64it [00:13,  5.03it/s]
# dataloaders: 65it [00:14,  4.88it/s]
# dataloaders: 66it [00:14,  4.92it/s]
# dataloaders: 67it [00:14,  4.96it/s]
# dataloaders: 68it [00:14,  4.98it/s]
# dataloaders: 69it [00:15,  5.02it/s]
# dataloaders: 70it [00:15,  4.93it/s]
# dataloaders: 71it [00:15,  4.77it/s]
# dataloaders: 72it [00:15,  4.75it/s]
# dataloaders: 73it [00:15,  4.73it/s]
# dataloaders: 74it [00:16,  4.63it/s]
# dataloaders: 75it [00:16,  4.64it/s]
# dataloaders: 76it [00:16,  4.68it/s]
# dataloaders: 77it [00:16,  4.73it/s]
# dataloaders: 78it [00:16,  4.86it/s]
# dataloaders: 79it [00:17,  4.72it/s]
# dataloaders: 80it [00:17,  4.71it/s]
# dataloaders: 81it [00:17,  4.69it/s]
# dataloaders: 82it [00:17,  4.68it/s]
# dataloaders: 83it [00:17,  4.75it/s]
# dataloaders: 84it [00:18,  4.71it/s]
# dataloaders: 85it [00:18,  4.78it/s]
# dataloaders: 86it [00:18,  4.81it/s]
# dataloaders: 87it [00:18,  4.63it/s]
# dataloaders: 88it [00:19,  4.65it/s]
# dataloaders: 89it [00:19,  4.57it/s]
# dataloaders: 90it [00:19,  4.51it/s]
# dataloaders: 91it [00:19,  4.53it/s]
# dataloaders: 92it [00:19,  4.55it/s]
# dataloaders: 93it [00:20,  4.53it/s]
# dataloaders: 94it [00:20,  4.47it/s]
# dataloaders: 95it [00:20,  4.52it/s]
# dataloaders: 96it [00:20,  4.53it/s]
# dataloaders: 97it [00:21,  4.50it/s]
# dataloaders: 98it [00:21,  4.55it/s]
# dataloaders: 99it [00:21,  4.67it/s]
# dataloaders: 100it [00:21,  4.65it/s]
# dataloaders: 101it [00:21,  4.66it/s]
# dataloaders: 102it [00:22,  4.74it/s]
# dataloaders: 103it [00:22,  4.86it/s]
# dataloaders: 104it [00:22,  4.83it/s]
# dataloaders: 105it [00:22,  4.81it/s]
# dataloaders: 106it [00:22,  4.90it/s]
# dataloaders: 107it [00:23,  4.81it/s]
# dataloaders: 108it [00:23,  4.67it/s]
# dataloaders: 109it [00:23,  4.76it/s]
# dataloaders: 110it [00:23,  4.81it/s]
# dataloaders: 111it [00:23,  4.80it/s]
# dataloaders: 112it [00:24,  4.91it/s]
# dataloaders: 113it [00:24,  4.97it/s]
# dataloaders: 114it [00:24,  5.01it/s]
# dataloaders: 115it [00:24,  5.03it/s]
# dataloaders: 116it [00:24,  5.05it/s]
# dataloaders: 117it [00:25,  5.09it/s]
# dataloaders: 118it [00:25,  5.12it/s]
# dataloaders: 119it [00:25,  4.91it/s]
# dataloaders: 120it [00:25,  4.25it/s]
# dataloaders: 121it [00:26,  3.99it/s]
# dataloaders: 122it [00:26,  4.14it/s]
# dataloaders: 123it [00:26,  4.35it/s]
# dataloaders: 124it [00:26,  3.66it/s]
# dataloaders: 125it [00:27,  3.98it/s]
# dataloaders: 126it [00:27,  4.26it/s]
# dataloaders: 127it [00:27,  4.43it/s]
# dataloaders: 128it [00:27,  4.49it/s]
# dataloaders: 129it [00:27,  4.56it/s]
# dataloaders: 130it [00:28,  4.71it/s]
# dataloaders: 131it [00:28,  4.84it/s]
# dataloaders: 132it [00:28,  4.94it/s]
# dataloaders: 133it [00:28,  4.98it/s]
# dataloaders: 134it [00:28,  5.00it/s]
# dataloaders: 135it [00:29,  4.95it/s]
# dataloaders: 136it [00:29,  4.94it/s]
# dataloaders: 137it [00:29,  4.86it/s]
# dataloaders: 138it [00:29,  4.94it/s]
# dataloaders: 139it [00:30,  4.72it/s]
# dataloaders: 140it [00:30,  4.74it/s]
# dataloaders: 141it [00:30,  4.33it/s]
# dataloaders: 142it [00:30,  4.33it/s]
# dataloaders: 143it [00:30,  4.35it/s]
# dataloaders: 144it [00:31,  4.30it/s]
# dataloaders: 145it [00:31,  4.52it/s]
# dataloaders: 146it [00:31,  4.58it/s]
# dataloaders: 147it [00:31,  4.63it/s]
# dataloaders: 148it [00:32,  4.61it/s]
# dataloaders: 149it [00:32,  4.58it/s]
# dataloaders: 150it [00:32,  4.72it/s]
# dataloaders: 151it [00:32,  4.79it/s]
# dataloaders: 152it [00:32,  4.72it/s]
# dataloaders: 153it [00:33,  4.77it/s]
# dataloaders: 154it [00:33,  4.78it/s]
# dataloaders: 155it [00:33,  4.65it/s]
# dataloaders: 156it [00:33,  4.57it/s]
# dataloaders: 157it [00:33,  4.58it/s]
# dataloaders: 158it [00:34,  4.49it/s]
# dataloaders: 159it [00:34,  3.52it/s]
# dataloaders: 160it [00:34,  3.81it/s]
# dataloaders: 161it [00:35,  4.04it/s]
# dataloaders: 162it [00:35,  4.09it/s]
# dataloaders: 163it [00:35,  4.22it/s]
# dataloaders: 164it [00:35,  4.35it/s]
# dataloaders: 165it [00:35,  4.48it/s]
# dataloaders: 166it [00:36,  4.56it/s]
# dataloaders: 167it [00:36,  4.58it/s]
# dataloaders: 168it [00:36,  4.51it/s]
# dataloaders: 169it [00:36,  4.52it/s]
# dataloaders: 170it [00:37,  4.62it/s]
# dataloaders: 171it [00:37,  4.57it/s]
# dataloaders: 172it [00:37,  4.64it/s]
# dataloaders: 173it [00:37,  4.68it/s]
# dataloaders: 174it [00:37,  4.64it/s]
# dataloaders: 175it [00:38,  4.67it/s]
# dataloaders: 176it [00:38,  4.66it/s]
# dataloaders: 177it [00:38,  4.52it/s]
# dataloaders: 178it [00:38,  4.62it/s]
# dataloaders: 179it [00:38,  4.75it/s]
# dataloaders: 180it [00:39,  4.74it/s]
# dataloaders: 181it [00:39,  4.78it/s]
# dataloaders: 182it [00:39,  4.81it/s]
# dataloaders: 183it [00:39,  4.89it/s]
# dataloaders: 184it [00:39,  5.00it/s]
# dataloaders: 185it [00:40,  5.02it/s]
# dataloaders: 186it [00:40,  4.61it/s]
# epoch:  30%|███       | 6/20 [03:46<08:57, 38.40s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.63it/s]
# dataloaders: 2it [00:00,  4.94it/s]
# dataloaders: 3it [00:00,  5.08it/s]
# dataloaders: 4it [00:00,  5.01it/s]
# dataloaders: 5it [00:00,  5.09it/s]
# dataloaders: 6it [00:01,  5.15it/s]
# dataloaders: 7it [00:01,  5.19it/s]
# dataloaders: 8it [00:01,  5.23it/s]
# dataloaders: 9it [00:01,  5.23it/s]
# dataloaders: 10it [00:01,  5.21it/s]
# dataloaders: 11it [00:02,  5.15it/s]
# dataloaders: 12it [00:02,  5.17it/s]
# dataloaders: 13it [00:02,  5.19it/s]
# dataloaders: 14it [00:02,  5.20it/s]
# dataloaders: 15it [00:02,  5.21it/s]
# dataloaders: 16it [00:03,  5.08it/s]
# dataloaders: 17it [00:03,  5.07it/s]
# dataloaders: 18it [00:03,  5.12it/s]
# dataloaders: 19it [00:03,  5.11it/s]
# dataloaders: 20it [00:03,  5.06it/s]
# dataloaders: 21it [00:04,  5.02it/s]
# dataloaders: 22it [00:04,  5.06it/s]
# dataloaders: 23it [00:04,  5.05it/s]
# dataloaders: 24it [00:04,  5.08it/s]
# dataloaders: 25it [00:04,  5.09it/s]
# dataloaders: 26it [00:05,  5.13it/s]
# dataloaders: 27it [00:05,  5.11it/s]
# dataloaders: 28it [00:05,  5.09it/s]
# dataloaders: 29it [00:05,  5.13it/s]
# dataloaders: 30it [00:05,  5.17it/s]
# dataloaders: 31it [00:06,  5.21it/s]
# dataloaders: 32it [00:06,  5.12it/s]
# dataloaders: 33it [00:06,  5.06it/s]
# dataloaders: 34it [00:06,  5.09it/s]
# dataloaders: 35it [00:06,  5.10it/s]
# dataloaders: 36it [00:07,  5.15it/s]
# dataloaders: 37it [00:07,  5.01it/s]
# dataloaders: 38it [00:07,  5.01it/s]
# dataloaders: 39it [00:07,  4.96it/s]
# dataloaders: 40it [00:07,  5.06it/s]
# dataloaders: 41it [00:08,  5.10it/s]
# dataloaders: 42it [00:08,  5.10it/s]
# dataloaders: 43it [00:08,  5.14it/s]
# dataloaders: 44it [00:08,  5.05it/s]
# dataloaders: 45it [00:08,  5.00it/s]
# dataloaders: 46it [00:09,  4.87it/s]
# dataloaders: 47it [00:09,  4.82it/s]
# dataloaders: 48it [00:09,  4.72it/s]
# dataloaders: 49it [00:09,  4.74it/s]
# dataloaders: 50it [00:09,  4.77it/s]
# dataloaders: 51it [00:10,  4.76it/s]
# dataloaders: 52it [00:10,  4.77it/s]
# dataloaders: 53it [00:10,  4.82it/s]
# dataloaders: 54it [00:10,  4.71it/s]
# dataloaders: 55it [00:10,  4.69it/s]
# dataloaders: 56it [00:11,  4.70it/s]
# dataloaders: 57it [00:11,  4.69it/s]
# dataloaders: 58it [00:11,  4.60it/s]
# dataloaders: 59it [00:11,  4.63it/s]
# dataloaders: 60it [00:12,  4.77it/s]
# dataloaders: 61it [00:12,  4.85it/s]
# dataloaders: 62it [00:12,  4.94it/s]
# dataloaders: 63it [00:12,  5.01it/s]
# dataloaders: 64it [00:12,  5.03it/s]
# dataloaders: 65it [00:12,  5.06it/s]
# dataloaders: 66it [00:13,  5.07it/s]
# dataloaders: 67it [00:13,  4.99it/s]
# dataloaders: 68it [00:13,  4.75it/s]
# dataloaders: 69it [00:13,  4.58it/s]
# dataloaders: 70it [00:14,  4.60it/s]
# dataloaders: 71it [00:14,  4.72it/s]
# dataloaders: 72it [00:14,  4.76it/s]
# dataloaders: 73it [00:14,  4.81it/s]
# dataloaders: 74it [00:14,  4.86it/s]
# dataloaders: 75it [00:15,  4.84it/s]
# dataloaders: 76it [00:15,  4.95it/s]
# dataloaders: 77it [00:15,  5.05it/s]
# dataloaders: 78it [00:15,  5.10it/s]
# dataloaders: 79it [00:15,  4.49it/s]
# dataloaders: 80it [00:16,  4.78it/s]
# dataloaders: 81it [00:16,  5.01it/s]
# dataloaders: 82it [00:16,  4.87it/s]
# dataloaders: 83it [00:16,  4.79it/s]
# dataloaders: 84it [00:16,  4.88it/s]
# dataloaders: 85it [00:17,  5.06it/s]
# dataloaders: 86it [00:17,  5.08it/s]
# dataloaders: 87it [00:17,  5.10it/s]
# dataloaders: 88it [00:17,  5.20it/s]
# dataloaders: 89it [00:17,  5.31it/s]
# dataloaders: 90it [00:18,  5.41it/s]
# dataloaders: 91it [00:18,  5.44it/s]
# dataloaders: 92it [00:18,  5.46it/s]
# dataloaders: 93it [00:18,  5.48it/s]
# dataloaders: 94it [00:18,  5.42it/s]
# dataloaders: 95it [00:18,  5.30it/s]
# dataloaders: 96it [00:19,  5.36it/s]
# dataloaders: 97it [00:19,  5.43it/s]
# dataloaders: 98it [00:19,  5.35it/s]
# dataloaders: 99it [00:19,  5.42it/s]
# dataloaders: 100it [00:19,  5.46it/s]
# dataloaders: 101it [00:20,  5.50it/s]
# dataloaders: 102it [00:20,  5.54it/s]
# dataloaders: 103it [00:20,  5.56it/s]
# dataloaders: 104it [00:20,  5.41it/s]
# dataloaders: 105it [00:20,  5.45it/s]
# dataloaders: 106it [00:20,  5.42it/s]
# dataloaders: 107it [00:21,  5.41it/s]
# dataloaders: 108it [00:21,  5.47it/s]
# dataloaders: 109it [00:21,  5.50it/s]
# dataloaders: 110it [00:21,  5.45it/s]
# dataloaders: 111it [00:21,  5.36it/s]
# dataloaders: 112it [00:22,  5.28it/s]
# dataloaders: 113it [00:22,  5.35it/s]
# dataloaders: 114it [00:22,  5.41it/s]
# dataloaders: 115it [00:22,  5.43it/s]
# dataloaders: 116it [00:22,  5.47it/s]
# dataloaders: 117it [00:23,  5.52it/s]
# dataloaders: 118it [00:23,  5.39it/s]
# dataloaders: 119it [00:23,  5.27it/s]
# dataloaders: 120it [00:23,  5.20it/s]
# dataloaders: 121it [00:23,  5.22it/s]
# dataloaders: 122it [00:24,  5.03it/s]
# dataloaders: 123it [00:24,  5.03it/s]
# dataloaders: 124it [00:24,  5.10it/s]
# dataloaders: 125it [00:24,  5.13it/s]
# dataloaders: 126it [00:24,  5.18it/s]
# dataloaders: 127it [00:24,  5.09it/s]
# dataloaders: 128it [00:25,  4.86it/s]
# dataloaders: 129it [00:25,  4.97it/s]
# dataloaders: 130it [00:25,  4.93it/s]
# dataloaders: 131it [00:25,  4.85it/s]
# dataloaders: 132it [00:26,  4.97it/s]
# dataloaders: 133it [00:26,  4.95it/s]
# dataloaders: 134it [00:26,  4.81it/s]
# dataloaders: 135it [00:26,  4.75it/s]
# dataloaders: 136it [00:26,  4.62it/s]
# dataloaders: 137it [00:27,  4.37it/s]
# dataloaders: 138it [00:27,  4.37it/s]
# dataloaders: 139it [00:27,  4.36it/s]
# dataloaders: 140it [00:27,  4.14it/s]
# dataloaders: 141it [00:28,  4.07it/s]
# dataloaders: 142it [00:28,  4.29it/s]
# dataloaders: 143it [00:28,  4.48it/s]
# dataloaders: 144it [00:28,  3.86it/s]
# dataloaders: 145it [00:29,  4.11it/s]
# dataloaders: 146it [00:29,  4.44it/s]
# dataloaders: 147it [00:29,  4.65it/s]
# dataloaders: 148it [00:29,  4.80it/s]
# dataloaders: 149it [00:29,  4.78it/s]
# dataloaders: 150it [00:30,  4.75it/s]
# ...
# dataloaders: 141it [00:30,  4.47it/s]
# dataloaders: 142it [00:31,  4.30it/s]
# dataloaders: 143it [00:31,  4.40it/s]
# dataloaders: 144it [00:31,  4.45it/s]
# dataloaders: 145it [00:31,  4.52it/s]
# dataloaders: 146it [00:32,  4.43it/s]
# dataloaders: 147it [00:32,  4.39it/s]
# dataloaders: 148it [00:32,  4.51it/s]
# dataloaders: 149it [00:32,  4.53it/s]
# dataloaders: 150it [00:33,  3.62it/s]
# dataloaders: 151it [00:33,  3.86it/s]
# dataloaders: 152it [00:33,  4.00it/s]
# dataloaders: 153it [00:33,  4.20it/s]
# dataloaders: 154it [00:34,  4.47it/s]
# dataloaders: 155it [00:34,  4.72it/s]
# dataloaders: 156it [00:34,  4.77it/s]
# dataloaders: 157it [00:34,  4.63it/s]
# dataloaders: 158it [00:34,  4.47it/s]
# dataloaders: 159it [00:35,  4.52it/s]
# dataloaders: 160it [00:35,  4.62it/s]
# dataloaders: 161it [00:35,  4.53it/s]
# dataloaders: 162it [00:35,  4.52it/s]
# dataloaders: 163it [00:35,  4.53it/s]
# dataloaders: 164it [00:36,  4.25it/s]
# dataloaders: 165it [00:36,  4.11it/s]
# dataloaders: 166it [00:36,  3.98it/s]
# dataloaders: 167it [00:37,  3.97it/s]
# dataloaders: 168it [00:37,  3.96it/s]
# dataloaders: 169it [00:37,  4.12it/s]
# dataloaders: 170it [00:37,  4.21it/s]
# dataloaders: 171it [00:37,  4.20it/s]
# dataloaders: 172it [00:38,  4.09it/s]
# dataloaders: 173it [00:38,  3.97it/s]
# dataloaders: 174it [00:38,  3.93it/s]
# dataloaders: 175it [00:38,  4.10it/s]
# dataloaders: 176it [00:39,  4.25it/s]
# dataloaders: 177it [00:39,  4.35it/s]
# dataloaders: 178it [00:39,  4.49it/s]
# dataloaders: 179it [00:39,  4.54it/s]
# dataloaders: 180it [00:40,  4.69it/s]
# dataloaders: 181it [00:40,  4.66it/s]
# dataloaders: 182it [00:40,  4.70it/s]
# dataloaders: 183it [00:40,  4.65it/s]
# dataloaders: 184it [00:40,  4.53it/s]
# dataloaders: 185it [00:41,  4.64it/s]
# dataloaders: 186it [00:41,  4.50it/s]
# epoch:  90%|█████████ | 18/20 [11:45<01:22, 41.50s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  4.26it/s]
# dataloaders: 2it [00:00,  4.81it/s]
# dataloaders: 3it [00:00,  4.88it/s]
# dataloaders: 4it [00:00,  4.82it/s]
# dataloaders: 5it [00:01,  4.33it/s]
# dataloaders: 6it [00:01,  4.19it/s]
# dataloaders: 7it [00:01,  4.42it/s]
# dataloaders: 8it [00:01,  4.59it/s]
# dataloaders: 9it [00:01,  4.63it/s]
# dataloaders: 10it [00:02,  4.82it/s]
# dataloaders: 11it [00:02,  5.01it/s]
# dataloaders: 12it [00:02,  5.11it/s]
# dataloaders: 13it [00:02,  5.16it/s]
# dataloaders: 14it [00:02,  5.24it/s]
# dataloaders: 15it [00:03,  5.01it/s]
# dataloaders: 16it [00:03,  5.01it/s]
# dataloaders: 17it [00:03,  4.98it/s]
# dataloaders: 18it [00:03,  4.90it/s]
# dataloaders: 19it [00:03,  4.88it/s]
# dataloaders: 20it [00:04,  4.66it/s]
# dataloaders: 21it [00:04,  4.69it/s]
# dataloaders: 22it [00:04,  4.83it/s]
# dataloaders: 23it [00:04,  4.93it/s]
# dataloaders: 24it [00:04,  4.94it/s]
# dataloaders: 25it [00:05,  4.98it/s]
# dataloaders: 26it [00:05,  4.76it/s]
# dataloaders: 27it [00:05,  4.57it/s]
# dataloaders: 28it [00:05,  3.96it/s]
# dataloaders: 29it [00:06,  4.23it/s]
# dataloaders: 30it [00:06,  4.48it/s]
# dataloaders: 31it [00:06,  4.62it/s]
# dataloaders: 32it [00:06,  4.67it/s]
# dataloaders: 33it [00:06,  4.79it/s]
# dataloaders: 34it [00:07,  4.86it/s]
# dataloaders: 35it [00:07,  4.94it/s]
# dataloaders: 36it [00:07,  5.06it/s]
# dataloaders: 37it [00:07,  5.16it/s]
# dataloaders: 38it [00:07,  5.16it/s]
# dataloaders: 39it [00:08,  5.23it/s]
# dataloaders: 40it [00:08,  5.14it/s]
# dataloaders: 41it [00:08,  5.13it/s]
# dataloaders: 42it [00:08,  5.06it/s]
# dataloaders: 43it [00:08,  5.04it/s]
# dataloaders: 44it [00:09,  5.06it/s]
# dataloaders: 45it [00:09,  4.81it/s]
# dataloaders: 46it [00:09,  4.72it/s]
# dataloaders: 47it [00:09,  4.76it/s]
# dataloaders: 48it [00:10,  4.60it/s]
# dataloaders: 49it [00:10,  4.22it/s]
# dataloaders: 50it [00:10,  3.95it/s]
# dataloaders: 51it [00:11,  3.22it/s]
# dataloaders: 52it [00:11,  3.38it/s]
# dataloaders: 53it [00:11,  3.57it/s]
# dataloaders: 54it [00:11,  3.83it/s]
# dataloaders: 55it [00:11,  3.92it/s]
# dataloaders: 56it [00:12,  3.95it/s]
# dataloaders: 57it [00:12,  4.17it/s]
# dataloaders: 58it [00:12,  4.33it/s]
# dataloaders: 59it [00:12,  4.32it/s]
# dataloaders: 60it [00:13,  4.47it/s]
# dataloaders: 61it [00:13,  4.57it/s]
# dataloaders: 62it [00:13,  4.47it/s]
# dataloaders: 63it [00:13,  4.51it/s]
# dataloaders: 64it [00:13,  4.73it/s]
# dataloaders: 65it [00:14,  4.79it/s]
# dataloaders: 66it [00:14,  4.88it/s]
# dataloaders: 67it [00:14,  5.02it/s]
# dataloaders: 68it [00:14,  5.05it/s]
# dataloaders: 69it [00:14,  4.88it/s]
# dataloaders: 70it [00:15,  4.58it/s]
# dataloaders: 71it [00:15,  4.60it/s]
# dataloaders: 72it [00:15,  4.66it/s]
# dataloaders: 73it [00:15,  4.75it/s]
# dataloaders: 74it [00:16,  4.67it/s]
# dataloaders: 75it [00:16,  4.67it/s]
# dataloaders: 76it [00:16,  4.82it/s]
# dataloaders: 77it [00:16,  4.89it/s]
# dataloaders: 78it [00:16,  4.99it/s]
# dataloaders: 79it [00:17,  4.88it/s]
# dataloaders: 80it [00:17,  4.91it/s]
# dataloaders: 81it [00:17,  4.96it/s]
# dataloaders: 82it [00:17,  4.84it/s]
# dataloaders: 83it [00:17,  4.84it/s]
# dataloaders: 84it [00:18,  4.69it/s]
# dataloaders: 85it [00:18,  4.43it/s]
# dataloaders: 86it [00:18,  4.43it/s]
# dataloaders: 87it [00:18,  4.45it/s]
# dataloaders: 88it [00:19,  4.48it/s]
# dataloaders: 89it [00:19,  4.68it/s]
# dataloaders: 90it [00:19,  4.66it/s]
# dataloaders: 91it [00:19,  4.64it/s]
# dataloaders: 92it [00:19,  4.78it/s]
# dataloaders: 93it [00:20,  4.84it/s]
# dataloaders: 94it [00:20,  4.69it/s]
# dataloaders: 95it [00:20,  4.61it/s]
# dataloaders: 96it [00:20,  4.60it/s]
# dataloaders: 97it [00:20,  4.55it/s]
# dataloaders: 98it [00:21,  4.55it/s]
# dataloaders: 99it [00:21,  4.56it/s]
# dataloaders: 100it [00:21,  4.39it/s]
# dataloaders: 101it [00:21,  4.43it/s]
# dataloaders: 102it [00:22,  4.53it/s]
# dataloaders: 103it [00:22,  4.71it/s]
# dataloaders: 104it [00:22,  4.82it/s]
# dataloaders: 105it [00:22,  4.56it/s]
# dataloaders: 106it [00:22,  4.59it/s]
# dataloaders: 107it [00:23,  4.63it/s]
# dataloaders: 108it [00:23,  4.59it/s]
# dataloaders: 109it [00:23,  4.56it/s]
# dataloaders: 110it [00:23,  4.52it/s]
# dataloaders: 111it [00:24,  4.45it/s]
# dataloaders: 112it [00:24,  4.48it/s]
# dataloaders: 113it [00:24,  4.66it/s]
# dataloaders: 114it [00:24,  4.80it/s]
# dataloaders: 115it [00:24,  4.78it/s]
# dataloaders: 116it [00:25,  4.73it/s]
# dataloaders: 117it [00:25,  4.62it/s]
# dataloaders: 118it [00:25,  4.61it/s]
# dataloaders: 119it [00:25,  4.76it/s]
# dataloaders: 120it [00:25,  4.76it/s]
# dataloaders: 121it [00:26,  4.70it/s]
# dataloaders: 122it [00:26,  4.47it/s]
# dataloaders: 123it [00:26,  4.54it/s]
# dataloaders: 124it [00:26,  4.30it/s]
# dataloaders: 125it [00:27,  4.28it/s]
# dataloaders: 126it [00:27,  4.13it/s]
# dataloaders: 127it [00:27,  4.03it/s]
# dataloaders: 128it [00:27,  4.02it/s]
# dataloaders: 129it [00:28,  4.11it/s]
# dataloaders: 130it [00:28,  4.14it/s]
# dataloaders: 131it [00:28,  4.12it/s]
# dataloaders: 132it [00:29,  3.32it/s]
# dataloaders: 133it [00:29,  3.45it/s]
# dataloaders: 134it [00:29,  3.58it/s]
# dataloaders: 135it [00:29,  3.73it/s]
# dataloaders: 136it [00:30,  3.81it/s]
# dataloaders: 137it [00:30,  3.90it/s]
# dataloaders: 138it [00:30,  3.90it/s]
# dataloaders: 139it [00:30,  3.96it/s]
# dataloaders: 140it [00:31,  3.93it/s]
# dataloaders: 141it [00:31,  3.89it/s]
# dataloaders: 142it [00:31,  4.07it/s]
# dataloaders: 143it [00:31,  4.07it/s]
# dataloaders: 144it [00:32,  3.94it/s]
# dataloaders: 145it [00:32,  3.91it/s]
# dataloaders: 146it [00:32,  4.00it/s]
# dataloaders: 147it [00:32,  3.99it/s]
# dataloaders: 148it [00:33,  3.99it/s]
# dataloaders: 149it [00:33,  4.01it/s]
# dataloaders: 150it [00:33,  4.16it/s]
# dataloaders: 151it [00:33,  4.31it/s]
# dataloaders: 152it [00:33,  4.36it/s]
# dataloaders: 153it [00:34,  4.40it/s]
# dataloaders: 154it [00:34,  4.36it/s]
# dataloaders: 155it [00:34,  4.42it/s]
# dataloaders: 156it [00:34,  4.60it/s]
# dataloaders: 157it [00:34,  4.74it/s]
# dataloaders: 158it [00:35,  4.66it/s]
# dataloaders: 159it [00:35,  4.52it/s]
# dataloaders: 160it [00:35,  4.35it/s]
# dataloaders: 161it [00:35,  4.37it/s]
# dataloaders: 162it [00:36,  4.41it/s]
# dataloaders: 163it [00:36,  4.41it/s]
# dataloaders: 164it [00:36,  4.46it/s]
# dataloaders: 165it [00:36,  4.51it/s]
# dataloaders: 166it [00:37,  4.54it/s]
# dataloaders: 167it [00:37,  4.45it/s]
# dataloaders: 168it [00:37,  4.48it/s]
# dataloaders: 169it [00:37,  4.52it/s]
# dataloaders: 170it [00:37,  4.49it/s]
# dataloaders: 171it [00:38,  4.50it/s]
# dataloaders: 172it [00:38,  4.52it/s]
# dataloaders: 173it [00:38,  4.54it/s]
# dataloaders: 174it [00:38,  4.47it/s]
# dataloaders: 175it [00:39,  4.48it/s]
# dataloaders: 176it [00:39,  4.48it/s]
# dataloaders: 177it [00:39,  4.45it/s]
# dataloaders: 178it [00:39,  4.47it/s]
# dataloaders: 179it [00:39,  4.51it/s]
# dataloaders: 180it [00:40,  4.53it/s]
# dataloaders: 181it [00:40,  4.46it/s]
# dataloaders: 182it [00:40,  4.51it/s]
# dataloaders: 183it [00:40,  4.55it/s]
# dataloaders: 184it [00:41,  4.56it/s]
# dataloaders: 185it [00:41,  4.44it/s]
# dataloaders: 186it [00:41,  4.47it/s]
# epoch:  95%|█████████▌| 19/20 [12:26<00:41, 41.60s/it]
# dataloaders: 0it [00:00, ?it/s]
# dataloaders: 1it [00:00,  3.42it/s]
# dataloaders: 2it [00:00,  3.45it/s]
# dataloaders: 3it [00:00,  3.78it/s]
# dataloaders: 4it [00:01,  3.87it/s]
# dataloaders: 5it [00:01,  4.11it/s]
# dataloaders: 6it [00:01,  4.23it/s]
# dataloaders: 7it [00:01,  4.26it/s]
# dataloaders: 8it [00:01,  4.32it/s]
# dataloaders: 9it [00:02,  3.53it/s]
# dataloaders: 10it [00:02,  3.64it/s]
# dataloaders: 11it [00:02,  3.86it/s]
# dataloaders: 12it [00:03,  4.06it/s]
# dataloaders: 13it [00:03,  4.12it/s]
# dataloaders: 14it [00:03,  4.19it/s]
# dataloaders: 15it [00:03,  4.34it/s]
# dataloaders: 16it [00:03,  4.55it/s]
# dataloaders: 17it [00:04,  4.71it/s]
# dataloaders: 18it [00:04,  4.80it/s]
# dataloaders: 19it [00:04,  4.84it/s]
# dataloaders: 20it [00:04,  4.94it/s]
# dataloaders: 21it [00:04,  4.91it/s]
# dataloaders: 22it [00:05,  4.99it/s]
# dataloaders: 23it [00:05,  5.05it/s]
# dataloaders: 24it [00:05,  5.03it/s]
# dataloaders: 25it [00:05,  5.05it/s]
# dataloaders: 26it [00:05,  5.05it/s]
# dataloaders: 27it [00:06,  5.11it/s]
# dataloaders: 28it [00:06,  5.09it/s]
# dataloaders: 29it [00:06,  4.93it/s]
# dataloaders: 30it [00:06,  4.77it/s]
# dataloaders: 31it [00:06,  4.64it/s]
# dataloaders: 32it [00:07,  4.54it/s]
# dataloaders: 33it [00:07,  4.46it/s]
# dataloaders: 34it [00:07,  4.43it/s]
# dataloaders: 35it [00:07,  4.41it/s]
# dataloaders: 36it [00:08,  4.43it/s]
# dataloaders: 37it [00:08,  4.42it/s]
# dataloaders: 38it [00:08,  4.51it/s]
# dataloaders: 39it [00:08,  4.51it/s]
# dataloaders: 40it [00:08,  4.46it/s]
# dataloaders: 41it [00:09,  4.37it/s]
# dataloaders: 42it [00:09,  4.13it/s]
# dataloaders: 43it [00:09,  4.17it/s]
# dataloaders: 44it [00:10,  3.30it/s]
# dataloaders: 45it [00:10,  3.59it/s]
# dataloaders: 46it [00:10,  3.74it/s]
# dataloaders: 47it [00:10,  3.97it/s]
# dataloaders: 48it [00:11,  4.18it/s]
# dataloaders: 49it [00:11,  4.35it/s]
# dataloaders: 50it [00:11,  4.49it/s]
# dataloaders: 51it [00:11,  4.49it/s]
# dataloaders: 52it [00:11,  4.55it/s]
# dataloaders: 53it [00:12,  4.63it/s]
# dataloaders: 54it [00:12,  4.64it/s]
# dataloaders: 55it [00:12,  4.63it/s]
# dataloaders: 56it [00:12,  4.50it/s]
# dataloaders: 57it [00:13,  4.61it/s]
# dataloaders: 58it [00:13,  4.70it/s]
# dataloaders: 59it [00:13,  4.75it/s]
# dataloaders: 60it [00:13,  4.76it/s]
# dataloaders: 61it [00:13,  4.77it/s]
# dataloaders: 62it [00:14,  4.68it/s]
# dataloaders: 63it [00:14,  4.71it/s]
# dataloaders: 64it [00:14,  4.75it/s]
# dataloaders: 65it [00:14,  4.79it/s]
# dataloaders: 66it [00:14,  4.78it/s]
# dataloaders: 67it [00:15,  4.82it/s]
# dataloaders: 68it [00:15,  4.74it/s]
# dataloaders: 69it [00:15,  4.79it/s]
# dataloaders: 70it [00:15,  4.79it/s]
# dataloaders: 71it [00:15,  4.91it/s]
# dataloaders: 72it [00:16,  4.91it/s]
# dataloaders: 73it [00:16,  4.85it/s]
# dataloaders: 74it [00:16,  4.89it/s]
# dataloaders: 75it [00:16,  4.73it/s]
# dataloaders: 76it [00:16,  4.72it/s]
# dataloaders: 77it [00:17,  4.52it/s]
# dataloaders: 78it [00:17,  4.32it/s]
# dataloaders: 79it [00:17,  4.28it/s]
# dataloaders: 80it [00:17,  4.22it/s]
# dataloaders: 81it [00:18,  4.20it/s]
# dataloaders: 82it [00:18,  4.12it/s]
# dataloaders: 83it [00:18,  3.29it/s]
# dataloaders: 84it [00:19,  3.53it/s]
# dataloaders: 85it [00:19,  3.66it/s]
# dataloaders: 86it [00:19,  3.89it/s]
# dataloaders: 87it [00:19,  4.10it/s]
# dataloaders: 88it [00:20,  4.20it/s]
# dataloaders: 89it [00:20,  4.46it/s]
# dataloaders: 90it [00:20,  4.66it/s]
# dataloaders: 91it [00:20,  4.74it/s]
# dataloaders: 92it [00:20,  4.76it/s]
# dataloaders: 93it [00:21,  4.65it/s]
# dataloaders: 94it [00:21,  4.75it/s]
# dataloaders: 95it [00:21,  4.67it/s]
# dataloaders: 96it [00:21,  4.78it/s]
# dataloaders: 97it [00:21,  4.88it/s]
# dataloaders: 98it [00:22,  4.80it/s]
# dataloaders: 99it [00:22,  4.70it/s]
# dataloaders: 100it [00:22,  4.58it/s]
# dataloaders: 101it [00:22,  4.52it/s]
# dataloaders: 102it [00:22,  4.59it/s]
# dataloaders: 103it [00:23,  4.75it/s]
# dataloaders: 104it [00:23,  4.84it/s]
# dataloaders: 105it [00:23,  4.89it/s]
# dataloaders: 106it [00:23,  4.91it/s]
# dataloaders: 107it [00:23,  4.99it/s]
# dataloaders: 108it [00:24,  5.05it/s]
# dataloaders: 109it [00:24,  5.11it/s]
# dataloaders: 110it [00:24,  5.13it/s]
# dataloaders: 111it [00:24,  5.15it/s]
# dataloaders: 112it [00:24,  5.18it/s]
# dataloaders: 113it [00:25,  4.85it/s]
# dataloaders: 114it [00:25,  4.71it/s]
# dataloaders: 115it [00:25,  4.62it/s]
# dataloaders: 116it [00:25,  4.58it/s]
# dataloaders: 117it [00:26,  4.58it/s]
# dataloaders: 118it [00:26,  4.60it/s]
# dataloaders: 119it [00:26,  4.54it/s]
# dataloaders: 120it [00:26,  4.54it/s]
# dataloaders: 121it [00:26,  4.51it/s]
# dataloaders: 122it [00:27,  4.49it/s]
# dataloaders: 123it [00:27,  4.49it/s]
# dataloaders: 124it [00:27,  4.52it/s]
# dataloaders: 125it [00:27,  4.54it/s]
# dataloaders: 126it [00:28,  4.50it/s]
# dataloaders: 127it [00:28,  4.56it/s]
# dataloaders: 128it [00:28,  4.61it/s]
# dataloaders: 129it [00:28,  4.75it/s]
# dataloaders: 130it [00:28,  4.73it/s]
# dataloaders: 131it [00:29,  4.77it/s]
# dataloaders: 132it [00:29,  4.60it/s]
# dataloaders: 133it [00:29,  4.54it/s]
# dataloaders: 134it [00:29,  4.48it/s]
# dataloaders: 135it [00:30,  4.37it/s]
# dataloaders: 136it [00:30,  4.55it/s]
# dataloaders: 137it [00:30,  4.54it/s]
# dataloaders: 138it [00:30,  4.70it/s]
# dataloaders: 139it [00:30,  4.89it/s]
# dataloaders: 140it [00:31,  4.94it/s]
# dataloaders: 141it [00:31,  4.90it/s]
# dataloaders: 142it [00:31,  4.88it/s]
# dataloaders: 143it [00:31,  4.94it/s]
# dataloaders: 144it [00:31,  4.82it/s]
# dataloaders: 145it [00:32,  4.59it/s]
# dataloaders: 146it [00:32,  4.46it/s]
# dataloaders: 147it [00:32,  4.19it/s]
# dataloaders: 148it [00:32,  4.30it/s]
# dataloaders: 149it [00:33,  4.36it/s]
# dataloaders: 150it [00:33,  4.49it/s]
# dataloaders: 151it [00:33,  4.56it/s]
# dataloaders: 152it [00:33,  4.63it/s]
# dataloaders: 153it [00:33,  4.61it/s]
# dataloaders: 154it [00:34,  4.72it/s]
# dataloaders: 155it [00:34,  4.67it/s]
# dataloaders: 156it [00:34,  4.71it/s]
# dataloaders: 157it [00:34,  4.75it/s]
# dataloaders: 158it [00:34,  4.85it/s]
# dataloaders: 159it [00:35,  4.82it/s]
# dataloaders: 160it [00:35,  4.51it/s]
# dataloaders: 161it [00:35,  4.60it/s]
# dataloaders: 162it [00:35,  4.70it/s]
# dataloaders: 163it [00:36,  4.63it/s]
# dataloaders: 164it [00:36,  4.67it/s]
# dataloaders: 165it [00:36,  4.73it/s]
# dataloaders: 166it [00:36,  4.76it/s]
# dataloaders: 167it [00:36,  4.78it/s]
# dataloaders: 168it [00:37,  4.88it/s]
# dataloaders: 169it [00:37,  4.96it/s]
# dataloaders: 170it [00:37,  4.89it/s]
# dataloaders: 171it [00:37,  4.85it/s]
# dataloaders: 172it [00:37,  4.62it/s]
# dataloaders: 173it [00:38,  4.63it/s]
# dataloaders: 174it [00:38,  4.70it/s]
# dataloaders: 175it [00:38,  4.72it/s]
# dataloaders: 176it [00:38,  4.76it/s]
# dataloaders: 177it [00:38,  4.78it/s]
# dataloaders: 178it [00:39,  4.70it/s]
# dataloaders: 179it [00:39,  4.73it/s]
# dataloaders: 180it [00:39,  4.70it/s]
# dataloaders: 181it [00:39,  4.67it/s]
# dataloaders: 182it [00:40,  4.69it/s]
# dataloaders: 183it [00:40,  4.71it/s]
# dataloaders: 184it [00:40,  4.72it/s]
# dataloaders: 185it [00:40,  4.68it/s]
# dataloaders: 186it [00:40,  4.55it/s]
# epoch: 100%|██████████| 20/20 [13:08<00:00, 39.41s/it]
# After training, Spearman Correlation: 0.4712
# After training, Spearman Correlation: 0.4712

# %% [markdown]
# #### 5.2 Courbes d'entraînement (4 points)
#
# Affichez la perte moyenne sur le jeu d'entraînement et la corrélation de Spearman sur le jeu de validation à chaque époque.

# %%
# Create some mock data
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.plot(losses, color=color)
ax1.set_xlabel("Iteration")
ax1.set_ylabel("Loss over iteration", color = color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second Axes that shares the same x-axis

color = 'tab:blue'
ax2.plot(spearman_corrList, color=color)
ax2.set_ylabel("Spearman Correlation over iteration",color = color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# #### 5.3 Vérification sur un exemple (3 points)
#
# Avec le modèle `model_fine_tuned`, calculez la similarité cosinus entre 'fast' et 'slow' et entre 'fast' et 'rapid'. Commentez les résultats en les comparant avec ceux de la partie 1.4.

# %%
nDim = 300
fastEmbedding = torch.reshape(model_fine_tuned.embeddings.weight[word_to_index['fast']],(1,nDim))
slowEmbedding = torch.reshape(model_fine_tuned.embeddings.weight[word_to_index['slow']],(1,nDim))
rapidEmbedding = torch.reshape(model_fine_tuned.embeddings.weight[word_to_index['rapid']],(1,nDim))

fastSlowRapidSimilarity = cosine_similarity(fastEmbedding, torch.cat((slowEmbedding,rapidEmbedding),0))

print(f'{"":^10} |{"slow":^10} |{"rapid":^10}')
fastSlowStr = f'{float(fastSlowRapidSimilarity[0,0]):.5f}'
fastRapidStr = f'{float(fastSlowRapidSimilarity[0,1]):.5f}'
print(f'{"fast":^10} |{fastSlowStr:^10} |{fastRapidStr:^10}')
# Out:
#            |   slow    |  rapid
#    fast    | 0.15316   | 0.32510

# %% [markdown]
# #### 5.4 Analyse, comparaison, conclusion (5 points)
#
# Comparez les performances des trois modèles (GloVe, zéro, fine-tuned). Quelle méthode est la plus performante ? Pourquoi ?

# %% [markdown]
# ## Livrables
# Vous devez remettre votre notebook sur Moodle et Gradescope en ipynb et pdf. Pour Gradescope vous devez associer les numéros de questions avec vos réponses dans le pdf grâce à l'outil que fournit Gradescope.
#
#
# ## Évaluation
# Votre TP sera évalué selon les critères suivants :
# 1. Exécution correcte du code et obtention des sorties attendues
# 2. Réponses correctes aux questions d'analyse
# 3. Qualité du code (noms significatifs, structure, performance, gestion d’exception, etc.)
# 4. Commentaires clairs et informatifs
